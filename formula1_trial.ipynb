# %%
import requests
import json

# %%
url = "http://ergast.com/api/f1/{}/drivers".format(2010)+".json"
payload={}
headers = {}

# %%
response = requests.request("GET", url, headers=headers, data=payload)

# %%
db=json.dumps(response.text)
type(db)
b=json.loads(db)
type(b)
# Out:
# str

# %%
db=eval(db)

# %%
for key in db:
    print(key)
# Out:
# {
# "
# M
# R
# D
# a
# t
# a
# "
# :
# {
# "
# x
# m
# l
# n
# s
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# r
# g
# a
# s
# t
# .
# c
# o
# m
# \
# /
# m
# r
# d
# \
# /
# 1
# .
# 4
# "
# ,
# "
# s
# e
# r
# i
# e
# s
# "
# :
# "
# f
# 1
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# /
# /
# e
# r
# g
# a
# s
# t
# .
# c
# o
# m
# /
# a
# p
# i
# /
# f
# 1
# /
# 2
# 0
# 2
# 1
# /
# d
# r
# i
# v
# e
# r
# s
# .
# j
# s
# o
# n
# "
# ,
# "
# l
# i
# m
# i
# t
# "
# :
# "
# 3
# 0
# "
# ,
# "
# o
# f
# f
# s
# e
# t
# "
# :
# "
# 0
# "
# ,
# "
# t
# o
# t
# a
# l
# "
# :
# "
# 2
# 0
# "
# ,
# "
# D
# r
# i
# v
# e
# r
# T
# a
# b
# l
# e
# "
# :
# {
# "
# s
# e
# a
# s
# o
# n
# "
# :
# "
# 2
# 0
# 2
# 1
# "
# ,
# "
# D
# r
# i
# v
# e
# r
# s
# "
# :
# [
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# a
# l
# o
# n
# s
# o
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 1
# 4
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# A
# L
# O
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# F
# e
# r
# n
# a
# n
# d
# o
# _
# A
# l
# o
# n
# s
# o
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# F
# e
# r
# n
# a
# n
# d
# o
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# A
# l
# o
# n
# s
# o
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 8
# 1
# -
# 0
# 7
# -
# 2
# 9
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# S
# p
# a
# n
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# b
# o
# t
# t
# a
# s
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 7
# 7
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# B
# O
# T
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# V
# a
# l
# t
# t
# e
# r
# i
# _
# B
# o
# t
# t
# a
# s
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# V
# a
# l
# t
# t
# e
# r
# i
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# B
# o
# t
# t
# a
# s
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 8
# 9
# -
# 0
# 8
# -
# 2
# 8
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# F
# i
# n
# n
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# g
# a
# s
# l
# y
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 1
# 0
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# G
# A
# S
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# P
# i
# e
# r
# r
# e
# _
# G
# a
# s
# l
# y
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# P
# i
# e
# r
# r
# e
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# G
# a
# s
# l
# y
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 6
# -
# 0
# 2
# -
# 0
# 7
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# F
# r
# e
# n
# c
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# g
# i
# o
# v
# i
# n
# a
# z
# z
# i
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 9
# 9
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# G
# I
# O
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# A
# n
# t
# o
# n
# i
# o
# _
# G
# i
# o
# v
# i
# n
# a
# z
# z
# i
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# A
# n
# t
# o
# n
# i
# o
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# G
# i
# o
# v
# i
# n
# a
# z
# z
# i
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 3
# -
# 1
# 2
# -
# 1
# 4
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# I
# t
# a
# l
# i
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# h
# a
# m
# i
# l
# t
# o
# n
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 4
# 4
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# H
# A
# M
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# L
# e
# w
# i
# s
# _
# H
# a
# m
# i
# l
# t
# o
# n
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# L
# e
# w
# i
# s
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# H
# a
# m
# i
# l
# t
# o
# n
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 8
# 5
# -
# 0
# 1
# -
# 0
# 7
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# B
# r
# i
# t
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# l
# a
# t
# i
# f
# i
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 6
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# L
# A
# T
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# N
# i
# c
# h
# o
# l
# a
# s
# _
# L
# a
# t
# i
# f
# i
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# N
# i
# c
# h
# o
# l
# a
# s
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# L
# a
# t
# i
# f
# i
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 5
# -
# 0
# 6
# -
# 2
# 9
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# C
# a
# n
# a
# d
# i
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# l
# e
# c
# l
# e
# r
# c
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 1
# 6
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# L
# E
# C
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# C
# h
# a
# r
# l
# e
# s
# _
# L
# e
# c
# l
# e
# r
# c
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# C
# h
# a
# r
# l
# e
# s
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# L
# e
# c
# l
# e
# r
# c
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 7
# -
# 1
# 0
# -
# 1
# 6
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# M
# o
# n
# e
# g
# a
# s
# q
# u
# e
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# m
# a
# z
# e
# p
# i
# n
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 9
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# M
# A
# Z
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# N
# i
# k
# i
# t
# a
# _
# M
# a
# z
# e
# p
# i
# n
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# N
# i
# k
# i
# t
# a
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# M
# a
# z
# e
# p
# i
# n
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 9
# -
# 0
# 3
# -
# 0
# 2
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# R
# u
# s
# s
# i
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# n
# o
# r
# r
# i
# s
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 4
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# N
# O
# R
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# L
# a
# n
# d
# o
# _
# N
# o
# r
# r
# i
# s
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# L
# a
# n
# d
# o
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# N
# o
# r
# r
# i
# s
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 9
# -
# 1
# 1
# -
# 1
# 3
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# B
# r
# i
# t
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# o
# c
# o
# n
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 3
# 1
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# O
# C
# O
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# E
# s
# t
# e
# b
# a
# n
# _
# O
# c
# o
# n
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# E
# s
# t
# e
# b
# a
# n
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# O
# c
# o
# n
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 6
# -
# 0
# 9
# -
# 1
# 7
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# F
# r
# e
# n
# c
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# p
# e
# r
# e
# z
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 1
# 1
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# P
# E
# R
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# S
# e
# r
# g
# i
# o
# _
# P
# %
# C
# 3
# %
# A
# 9
# r
# e
# z
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# S
# e
# r
# g
# i
# o
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# P
# é
# r
# e
# z
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 0
# -
# 0
# 1
# -
# 2
# 6
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# M
# e
# x
# i
# c
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# r
# a
# i
# k
# k
# o
# n
# e
# n
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 7
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# R
# A
# I
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# K
# i
# m
# i
# _
# R
# %
# C
# 3
# %
# A
# 4
# i
# k
# k
# %
# C
# 3
# %
# B
# 6
# n
# e
# n
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# K
# i
# m
# i
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# R
# ä
# i
# k
# k
# ö
# n
# e
# n
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 7
# 9
# -
# 1
# 0
# -
# 1
# 7
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# F
# i
# n
# n
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# r
# i
# c
# c
# i
# a
# r
# d
# o
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 3
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# R
# I
# C
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# D
# a
# n
# i
# e
# l
# _
# R
# i
# c
# c
# i
# a
# r
# d
# o
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# D
# a
# n
# i
# e
# l
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# R
# i
# c
# c
# i
# a
# r
# d
# o
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 8
# 9
# -
# 0
# 7
# -
# 0
# 1
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# A
# u
# s
# t
# r
# a
# l
# i
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# r
# u
# s
# s
# e
# l
# l
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 6
# 3
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# R
# U
# S
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# G
# e
# o
# r
# g
# e
# _
# R
# u
# s
# s
# e
# l
# l
# _
# %
# 2
# 8
# r
# a
# c
# i
# n
# g
# _
# d
# r
# i
# v
# e
# r
# %
# 2
# 9
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# G
# e
# o
# r
# g
# e
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# R
# u
# s
# s
# e
# l
# l
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 8
# -
# 0
# 2
# -
# 1
# 5
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# B
# r
# i
# t
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# s
# a
# i
# n
# z
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 5
# 5
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# S
# A
# I
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# C
# a
# r
# l
# o
# s
# _
# S
# a
# i
# n
# z
# _
# J
# r
# .
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# C
# a
# r
# l
# o
# s
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# S
# a
# i
# n
# z
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 4
# -
# 0
# 9
# -
# 0
# 1
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# S
# p
# a
# n
# i
# s
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# m
# i
# c
# k
# _
# s
# c
# h
# u
# m
# a
# c
# h
# e
# r
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 4
# 7
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# M
# S
# C
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# M
# i
# c
# k
# _
# S
# c
# h
# u
# m
# a
# c
# h
# e
# r
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# M
# i
# c
# k
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# S
# c
# h
# u
# m
# a
# c
# h
# e
# r
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 9
# -
# 0
# 3
# -
# 2
# 2
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# G
# e
# r
# m
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# s
# t
# r
# o
# l
# l
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 1
# 8
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# S
# T
# R
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# L
# a
# n
# c
# e
# _
# S
# t
# r
# o
# l
# l
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# L
# a
# n
# c
# e
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# S
# t
# r
# o
# l
# l
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 8
# -
# 1
# 0
# -
# 2
# 9
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# C
# a
# n
# a
# d
# i
# a
# n
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# t
# s
# u
# n
# o
# d
# a
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 2
# 2
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# T
# S
# U
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# Y
# u
# k
# i
# _
# T
# s
# u
# n
# o
# d
# a
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# Y
# u
# k
# i
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# T
# s
# u
# n
# o
# d
# a
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 2
# 0
# 0
# 0
# -
# 0
# 5
# -
# 1
# 1
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# J
# a
# p
# a
# n
# e
# s
# e
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# m
# a
# x
# _
# v
# e
# r
# s
# t
# a
# p
# p
# e
# n
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 3
# 3
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# V
# E
# R
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# M
# a
# x
# _
# V
# e
# r
# s
# t
# a
# p
# p
# e
# n
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# M
# a
# x
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# V
# e
# r
# s
# t
# a
# p
# p
# e
# n
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 9
# 7
# -
# 0
# 9
# -
# 3
# 0
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# D
# u
# t
# c
# h
# "
# }
# ,
# {
# "
# d
# r
# i
# v
# e
# r
# I
# d
# "
# :
# "
# v
# e
# t
# t
# e
# l
# "
# ,
# "
# p
# e
# r
# m
# a
# n
# e
# n
# t
# N
# u
# m
# b
# e
# r
# "
# :
# "
# 5
# "
# ,
# "
# c
# o
# d
# e
# "
# :
# "
# V
# E
# T
# "
# ,
# "
# u
# r
# l
# "
# :
# "
# h
# t
# t
# p
# :
# \
# /
# \
# /
# e
# n
# .
# w
# i
# k
# i
# p
# e
# d
# i
# a
# .
# o
# r
# g
# \
# /
# w
# i
# k
# i
# \
# /
# S
# e
# b
# a
# s
# t
# i
# a
# n
# _
# V
# e
# t
# t
# e
# l
# "
# ,
# "
# g
# i
# v
# e
# n
# N
# a
# m
# e
# "
# :
# "
# S
# e
# b
# a
# s
# t
# i
# a
# n
# "
# ,
# "
# f
# a
# m
# i
# l
# y
# N
# a
# m
# e
# "
# :
# "
# V
# e
# t
# t
# e
# l
# "
# ,
# "
# d
# a
# t
# e
# O
# f
# B
# i
# r
# t
# h
# "
# :
# "
# 1
# 9
# 8
# 7
# -
# 0
# 7
# -
# 0
# 3
# "
# ,
# "
# n
# a
# t
# i
# o
# n
# a
# l
# i
# t
# y
# "
# :
# "
# G
# e
# r
# m
# a
# n
# "
# }
# ]
# }
# }
# }

# %%
type(db)
# Out:
# str

# %%
len(db)
# Out:
# 4442

# %%
ini_string=response.text
print ("type of ini_object", type(ini_string))
  
# converting string to json
final_dictionary = eval(ini_string)
  
# printing final result

print ("type of final_dictionary", type(final_dictionary))
# Out:
# type of ini_object <class 'str'>
# Traceback (most recent call last):
#
#   File "C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-13-d5c00052aafe>", line 5, in <module>
#     final_dictionary = eval(ini_string)
#
#   File "<string>", line 1
#     <?xml version="1.0" encoding="utf-8"?>
#     ^
# SyntaxError: invalid syntax

# %%
z=final_dictionary['MRData']['DriverTable']['Drivers']

# %%
z
# Out:
# [{'driverId': 'alguersuari',
#   'code': 'ALG',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Jaime_Alguersuari',
#   'givenName': 'Jaime',
#   'familyName': 'Alguersuari',
#   'dateOfBirth': '1990-03-23',
#   'nationality': 'Spanish'},
#  {'driverId': 'alonso',
#   'permanentNumber': '14',
#   'code': 'ALO',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Fernando_Alonso',
#   'givenName': 'Fernando',
#   'familyName': 'Alonso',
#   'dateOfBirth': '1981-07-29',
#   'nationality': 'Spanish'},
#  {'driverId': 'barrichello',
#   'code': 'BAR',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Rubens_Barrichello',
#   'givenName': 'Rubens',
#   'familyName': 'Barrichello',
#   'dateOfBirth': '1972-05-23',
#   'nationality': 'Brazilian'},
#  {'driverId': 'buemi',
#   'code': 'BUE',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/S%C3%A9bastien_Buemi',
#   'givenName': 'Sébastien',
#   'familyName': 'Buemi',
#   'dateOfBirth': '1988-10-31',
#   'nationality': 'Swiss'},
#  {'driverId': 'button',
#   'permanentNumber': '22',
#   'code': 'BUT',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Jenson_Button',
#   'givenName': 'Jenson',
#   'familyName': 'Button',
#   'dateOfBirth': '1980-01-19',
#   'nationality': 'British'},
#  {'driverId': 'chandhok',
#   'code': 'CHA',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Karun_Chandhok',
#   'givenName': 'Karun',
#   'familyName': 'Chandhok',
#   'dateOfBirth': '1984-01-19',
#   'nationality': 'Indian'},
#  {'driverId': 'rosa',
#   'code': 'DLR',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Pedro_de_la_Rosa',
#   'givenName': 'Pedro',
#   'familyName': 'de la Rosa',
#   'dateOfBirth': '1971-02-24',
#   'nationality': 'Spanish'},
#  {'driverId': 'grassi',
#   'code': 'DIG',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lucas_di_Grassi',
#   'givenName': 'Lucas',
#   'familyName': 'di Grassi',
#   'dateOfBirth': '1984-08-11',
#   'nationality': 'Brazilian'},
#  {'driverId': 'glock',
#   'code': 'GLO',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Timo_Glock',
#   'givenName': 'Timo',
#   'familyName': 'Glock',
#   'dateOfBirth': '1982-03-18',
#   'nationality': 'German'},
#  {'driverId': 'hamilton',
#   'permanentNumber': '44',
#   'code': 'HAM',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lewis_Hamilton',
#   'givenName': 'Lewis',
#   'familyName': 'Hamilton',
#   'dateOfBirth': '1985-01-07',
#   'nationality': 'British'},
#  {'driverId': 'heidfeld',
#   'code': 'HEI',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nick_Heidfeld',
#   'givenName': 'Nick',
#   'familyName': 'Heidfeld',
#   'dateOfBirth': '1977-05-10',
#   'nationality': 'German'},
#  {'driverId': 'hulkenberg',
#   'permanentNumber': '27',
#   'code': 'HUL',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nico_H%C3%BClkenberg',
#   'givenName': 'Nico',
#   'familyName': 'Hülkenberg',
#   'dateOfBirth': '1987-08-19',
#   'nationality': 'German'},
#  {'driverId': 'klien',
#   'code': 'KLI',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Christian_Klien',
#   'givenName': 'Christian',
#   'familyName': 'Klien',
#   'dateOfBirth': '1983-02-07',
#   'nationality': 'Austrian'},
#  {'driverId': 'kobayashi',
#   'permanentNumber': '10',
#   'code': 'KOB',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Kamui_Kobayashi',
#   'givenName': 'Kamui',
#   'familyName': 'Kobayashi',
#   'dateOfBirth': '1986-09-13',
#   'nationality': 'Japanese'},
#  {'driverId': 'kovalainen',
#   'code': 'KOV',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Heikki_Kovalainen',
#   'givenName': 'Heikki',
#   'familyName': 'Kovalainen',
#   'dateOfBirth': '1981-10-19',
#   'nationality': 'Finnish'},
#  {'driverId': 'kubica',
#   'permanentNumber': '88',
#   'code': 'KUB',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Robert_Kubica',
#   'givenName': 'Robert',
#   'familyName': 'Kubica',
#   'dateOfBirth': '1984-12-07',
#   'nationality': 'Polish'},
#  {'driverId': 'liuzzi',
#   'code': 'LIU',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Vitantonio_Liuzzi',
#   'givenName': 'Vitantonio',
#   'familyName': 'Liuzzi',
#   'dateOfBirth': '1980-08-06',
#   'nationality': 'Italian'},
#  {'driverId': 'massa',
#   'permanentNumber': '19',
#   'code': 'MAS',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Felipe_Massa',
#   'givenName': 'Felipe',
#   'familyName': 'Massa',
#   'dateOfBirth': '1981-04-25',
#   'nationality': 'Brazilian'},
#  {'driverId': 'petrov',
#   'code': 'PET',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Vitaly_Petrov',
#   'givenName': 'Vitaly',
#   'familyName': 'Petrov',
#   'dateOfBirth': '1984-09-08',
#   'nationality': 'Russian'},
#  {'driverId': 'rosberg',
#   'permanentNumber': '6',
#   'code': 'ROS',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nico_Rosberg',
#   'givenName': 'Nico',
#   'familyName': 'Rosberg',
#   'dateOfBirth': '1985-06-27',
#   'nationality': 'German'},
#  {'driverId': 'michael_schumacher',
#   'code': 'MSC',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Michael_Schumacher',
#   'givenName': 'Michael',
#   'familyName': 'Schumacher',
#   'dateOfBirth': '1969-01-03',
#   'nationality': 'German'},
#  {'driverId': 'bruno_senna',
#   'code': 'SEN',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Bruno_Senna',
#   'givenName': 'Bruno',
#   'familyName': 'Senna',
#   'dateOfBirth': '1983-10-15',
#   'nationality': 'Brazilian'},
#  {'driverId': 'sutil',
#   'permanentNumber': '99',
#   'code': 'SUT',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Adrian_Sutil',
#   'givenName': 'Adrian',
#   'familyName': 'Sutil',
#   'dateOfBirth': '1983-01-11',
#   'nationality': 'German'},
#  {'driverId': 'trulli',
#   'code': 'TRU',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Jarno_Trulli',
#   'givenName': 'Jarno',
#   'familyName': 'Trulli',
#   'dateOfBirth': '1974-07-13',
#   'nationality': 'Italian'},
#  {'driverId': 'vettel',
#   'permanentNumber': '5',
#   'code': 'VET',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Sebastian_Vettel',
#   'givenName': 'Sebastian',
#   'familyName': 'Vettel',
#   'dateOfBirth': '1987-07-03',
#   'nationality': 'German'},
#  {'driverId': 'webber',
#   'code': 'WEB',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mark_Webber',
#   'givenName': 'Mark',
#   'familyName': 'Webber',
#   'dateOfBirth': '1976-08-27',
#   'nationality': 'Australian'},
#  {'driverId': 'yamamoto',
#   'code': 'YAM',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Sakon_Yamamoto',
#   'givenName': 'Sakon',
#   'familyName': 'Yamamoto',
#   'dateOfBirth': '1982-07-09',
#   'nationality': 'Japanese'}]

# %%
for key in z:
    print(key['givenName']+" "+key['familyName']+"  :"+key['code']+" "+key['permanentNumber'])
# Out:
# Fernando Alonso  :ALO 14
# Valtteri Bottas  :BOT 77
# Pierre Gasly  :GAS 10
# Antonio Giovinazzi  :GIO 99
# Lewis Hamilton  :HAM 44
# Nicholas Latifi  :LAT 6
# Charles Leclerc  :LEC 16
# Nikita Mazepin  :MAZ 9
# Lando Norris  :NOR 4
# Esteban Ocon  :OCO 31
# Sergio Pérez  :PER 11
# Kimi Räikkönen  :RAI 7
# Daniel Ricciardo  :RIC 3
# George Russell  :RUS 63
# Carlos Sainz  :SAI 55
# Mick Schumacher  :MSC 47
# Lance Stroll  :STR 18
# Yuki Tsunoda  :TSU 22
# Max Verstappen  :VER 33
# Sebastian Vettel  :VET 5

# %%
url = "http://ergast.com/api/f1/drivers?=123"+".json"

# %%
response = requests.request("GET", url, headers=headers, data=payload)

# %%
import requests

url = "http://ergast.com/api/f1/drivers?limit=1000&offset=20.json"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet type="text/xsl" href="/schemas/mrd-1.4.xsl"?>
# <MRData xmlns="http://ergast.com/mrd/1.4" series="f1" url="http://ergast.com/api/f1/drivers" limit="1000" offset="20" total="853">
# 	<DriverTable>
# 		<Driver driverId="amon" url="http://en.wikipedia.org/wiki/Chris_Amon">
# 			<GivenName>Chris</GivenName>
# 			<FamilyName>Amon</FamilyName>
# 			<DateOfBirth>1943-07-20</DateOfBirth>
# 			<Nationality>New Zealander</Nationality>
# 		</Driver>
# 		<Driver driverId="anderson" url="http://en.wikipedia.org/wiki/Bob_Anderson_(racing_driver)">
# 			<GivenName>Bob</GivenName>
# 			<FamilyName>Anderson</FamilyName>
# 			<DateOfBirth>1931-05-19</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="andersson" url="http://en.wikipedia.org/wiki/Conny_Andersson_(racing_driver)">
# 			<GivenName>Conny</GivenName>
# 			<FamilyName>Andersson</FamilyName>
# 			<DateOfBirth>1939-12-28</DateOfBirth>
# 			<Nationality>Swedish</Nationality>
# 		</Driver>
# 		<Driver driverId="andretti" url="http://en.wikipedia.org/wiki/Michael_Andretti">
# 			<GivenName>Michael</GivenName>
# 			<FamilyName>Andretti</FamilyName>
# 			<DateOfBirth>1962-10-05</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="mario_andretti" url="http://en.wikipedia.org/wiki/Mario_Andretti">
# 			<GivenName>Mario</GivenName>
# 			<FamilyName>Andretti</FamilyName>
# 			<DateOfBirth>1940-02-28</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="andrews" url="http://en.wikipedia.org/wiki/Keith_Andrews_(driver)">
# 			<GivenName>Keith</GivenName>
# 			<FamilyName>Andrews</FamilyName>
# 			<DateOfBirth>1920-06-15</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="apicella" url="http://en.wikipedia.org/wiki/Marco_Apicella">
# 			<GivenName>Marco</GivenName>
# 			<FamilyName>Apicella</FamilyName>
# 			<DateOfBirth>1965-10-07</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="armi" url="http://en.wikipedia.org/wiki/Frank_Armi">
# 			<GivenName>Frank</GivenName>
# 			<FamilyName>Armi</FamilyName>
# 			<DateOfBirth>1918-10-12</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="arnold" url="http://en.wikipedia.org/wiki/Chuck_Arnold">
# 			<GivenName>Chuck</GivenName>
# 			<FamilyName>Arnold</FamilyName>
# 			<DateOfBirth>1926-05-30</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="arnoux" url="http://en.wikipedia.org/wiki/Ren%C3%A9_Arnoux">
# 			<GivenName>René</GivenName>
# 			<FamilyName>Arnoux</FamilyName>
# 			<DateOfBirth>1948-07-04</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="arundell" url="http://en.wikipedia.org/wiki/Peter_Arundell">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Arundell</FamilyName>
# 			<DateOfBirth>1933-11-08</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="ascari" url="http://en.wikipedia.org/wiki/Alberto_Ascari">
# 			<GivenName>Alberto</GivenName>
# 			<FamilyName>Ascari</FamilyName>
# 			<DateOfBirth>1918-07-13</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="ashdown" url="http://en.wikipedia.org/wiki/Peter_Ashdown">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Ashdown</FamilyName>
# 			<DateOfBirth>1934-10-16</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="ashley" url="http://en.wikipedia.org/wiki/Ian_Ashley">
# 			<GivenName>Ian</GivenName>
# 			<FamilyName>Ashley</FamilyName>
# 			<DateOfBirth>1947-10-26</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="ashmore" url="http://en.wikipedia.org/wiki/Gerry_Ashmore">
# 			<GivenName>Gerry</GivenName>
# 			<FamilyName>Ashmore</FamilyName>
# 			<DateOfBirth>1936-07-25</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="aston" url="http://en.wikipedia.org/wiki/Bill_Aston">
# 			<GivenName>Bill</GivenName>
# 			<FamilyName>Aston</FamilyName>
# 			<DateOfBirth>1900-03-29</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="attwood" url="http://en.wikipedia.org/wiki/Richard_Attwood">
# 			<GivenName>Richard</GivenName>
# 			<FamilyName>Attwood</FamilyName>
# 			<DateOfBirth>1940-04-04</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="ayulo" url="http://en.wikipedia.org/wiki/Manny_Ayulo">
# 			<GivenName>Manny</GivenName>
# 			<FamilyName>Ayulo</FamilyName>
# 			<DateOfBirth>1921-10-20</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="badoer" code="BAD" url="http://en.wikipedia.org/wiki/Luca_Badoer">
# 			<GivenName>Luca</GivenName>
# 			<FamilyName>Badoer</FamilyName>
# 			<DateOfBirth>1971-01-25</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="baghetti" url="http://en.wikipedia.org/wiki/Giancarlo_Baghetti">
# 			<GivenName>Giancarlo</GivenName>
# 			<FamilyName>Baghetti</FamilyName>
# 			<DateOfBirth>1934-12-25</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bailey" url="http://en.wikipedia.org/wiki/Julian_Bailey">
# 			<GivenName>Julian</GivenName>
# 			<FamilyName>Bailey</FamilyName>
# 			<DateOfBirth>1961-10-09</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="baldi" url="http://en.wikipedia.org/wiki/Mauro_Baldi">
# 			<GivenName>Mauro</GivenName>
# 			<FamilyName>Baldi</FamilyName>
# 			<DateOfBirth>1954-01-31</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="ball" url="http://en.wikipedia.org/wiki/Bobby_Ball_(auto_racer)">
# 			<GivenName>Bobby</GivenName>
# 			<FamilyName>Ball</FamilyName>
# 			<DateOfBirth>1925-08-26</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="balsa" url="http://en.wikipedia.org/wiki/Marcel_Balsa">
# 			<GivenName>Marcel</GivenName>
# 			<FamilyName>Balsa</FamilyName>
# 			<DateOfBirth>1909-01-01</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="bandini" url="http://en.wikipedia.org/wiki/Lorenzo_Bandini">
# 			<GivenName>Lorenzo</GivenName>
# 			<FamilyName>Bandini</FamilyName>
# 			<DateOfBirth>1935-12-21</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="banks" url="http://en.wikipedia.org/wiki/Henry_Banks">
# 			<GivenName>Henry</GivenName>
# 			<FamilyName>Banks</FamilyName>
# 			<DateOfBirth>1913-06-14</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="barbazza" url="http://en.wikipedia.org/wiki/Fabrizio_Barbazza">
# 			<GivenName>Fabrizio</GivenName>
# 			<FamilyName>Barbazza</FamilyName>
# 			<DateOfBirth>1963-04-02</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="barber" url="http://en.wikipedia.org/wiki/Skip_Barber">
# 			<GivenName>Skip</GivenName>
# 			<FamilyName>Barber</FamilyName>
# 			<DateOfBirth>1936-11-16</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="john_barber" url="http://en.wikipedia.org/wiki/John_Barber_(racing_driver)">
# 			<GivenName>John</GivenName>
# 			<FamilyName>Barber</FamilyName>
# 			<DateOfBirth>1929-07-22</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="barilla" url="http://en.wikipedia.org/wiki/Paolo_Barilla">
# 			<GivenName>Paolo</GivenName>
# 			<FamilyName>Barilla</FamilyName>
# 			<DateOfBirth>1961-04-20</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="barrichello" code="BAR" url="http://en.wikipedia.org/wiki/Rubens_Barrichello">
# 			<GivenName>Rubens</GivenName>
# 			<FamilyName>Barrichello</FamilyName>
# 			<DateOfBirth>1972-05-23</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="bartels" url="http://en.wikipedia.org/wiki/Michael_Bartels">
# 			<GivenName>Michael</GivenName>
# 			<FamilyName>Bartels</FamilyName>
# 			<DateOfBirth>1968-03-08</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="barth" url="http://en.wikipedia.org/wiki/Edgar_Barth">
# 			<GivenName>Edgar</GivenName>
# 			<FamilyName>Barth</FamilyName>
# 			<DateOfBirth>1917-01-26</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="bassi" url="http://en.wikipedia.org/wiki/Giorgio_Bassi">
# 			<GivenName>Giorgio</GivenName>
# 			<FamilyName>Bassi</FamilyName>
# 			<DateOfBirth>1934-01-20</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bauer" url="http://en.wikipedia.org/wiki/Erwin_Bauer">
# 			<GivenName>Erwin</GivenName>
# 			<FamilyName>Bauer</FamilyName>
# 			<DateOfBirth>1912-07-17</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="baumgartner" url="http://en.wikipedia.org/wiki/Zsolt_Baumgartner">
# 			<GivenName>Zsolt</GivenName>
# 			<FamilyName>Baumgartner</FamilyName>
# 			<DateOfBirth>1981-01-01</DateOfBirth>
# 			<Nationality>Hungarian</Nationality>
# 		</Driver>
# 		<Driver driverId="bayol" url="http://en.wikipedia.org/wiki/%C3%89lie_Bayol">
# 			<GivenName>Élie</GivenName>
# 			<FamilyName>Bayol</FamilyName>
# 			<DateOfBirth>1914-02-28</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="beauman" url="http://en.wikipedia.org/wiki/Don_Beauman">
# 			<GivenName>Don</GivenName>
# 			<FamilyName>Beauman</FamilyName>
# 			<DateOfBirth>1928-07-26</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="bechem" url="http://en.wikipedia.org/wiki/G%C3%BCnther_Bechem">
# 			<GivenName>Günther</GivenName>
# 			<FamilyName>Bechem</FamilyName>
# 			<DateOfBirth>1921-12-21</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="behra" url="http://en.wikipedia.org/wiki/Jean_Behra">
# 			<GivenName>Jean</GivenName>
# 			<FamilyName>Behra</FamilyName>
# 			<DateOfBirth>1921-02-16</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="bell" url="http://en.wikipedia.org/wiki/Derek_Bell_(auto_racer)">
# 			<GivenName>Derek</GivenName>
# 			<FamilyName>Bell</FamilyName>
# 			<DateOfBirth>1941-10-31</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="bellof" url="http://en.wikipedia.org/wiki/Stefan_Bellof">
# 			<GivenName>Stefan</GivenName>
# 			<FamilyName>Bellof</FamilyName>
# 			<DateOfBirth>1957-11-20</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="belmondo" url="http://en.wikipedia.org/wiki/Paul_Belmondo">
# 			<GivenName>Paul</GivenName>
# 			<FamilyName>Belmondo</FamilyName>
# 			<DateOfBirth>1963-04-23</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="belso" url="http://en.wikipedia.org/wiki/Tom_Bels%C3%B8">
# 			<GivenName>Tom</GivenName>
# 			<FamilyName>Belsø</FamilyName>
# 			<DateOfBirth>1942-08-27</DateOfBirth>
# 			<Nationality>Danish</Nationality>
# 		</Driver>
# 		<Driver driverId="beltoise" url="http://en.wikipedia.org/wiki/Jean-Pierre_Beltoise">
# 			<GivenName>Jean-Pierre</GivenName>
# 			<FamilyName>Beltoise</FamilyName>
# 			<DateOfBirth>1937-04-26</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="beretta" url="http://en.wikipedia.org/wiki/Olivier_Beretta">
# 			<GivenName>Olivier</GivenName>
# 			<FamilyName>Beretta</FamilyName>
# 			<DateOfBirth>1969-11-23</DateOfBirth>
# 			<Nationality>Monegasque</Nationality>
# 		</Driver>
# 		<Driver driverId="berg" url="http://en.wikipedia.org/wiki/Allen_Berg">
# 			<GivenName>Allen</GivenName>
# 			<FamilyName>Berg</FamilyName>
# 			<DateOfBirth>1961-08-01</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="berger" url="http://en.wikipedia.org/wiki/Gerhard_Berger">
# 			<GivenName>Gerhard</GivenName>
# 			<FamilyName>Berger</FamilyName>
# 			<DateOfBirth>1959-08-27</DateOfBirth>
# 			<Nationality>Austrian</Nationality>
# 		</Driver>
# 		<Driver driverId="georges_berger" url="http://en.wikipedia.org/wiki/Georges_Berger">
# 			<GivenName>Georges</GivenName>
# 			<FamilyName>Berger</FamilyName>
# 			<DateOfBirth>1918-09-14</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="bernard" url="http://en.wikipedia.org/wiki/%C3%89ric_Bernard">
# 			<GivenName>Éric</GivenName>
# 			<FamilyName>Bernard</FamilyName>
# 			<DateOfBirth>1964-08-24</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="bernoldi" url="http://en.wikipedia.org/wiki/Enrique_Bernoldi">
# 			<GivenName>Enrique</GivenName>
# 			<FamilyName>Bernoldi</FamilyName>
# 			<DateOfBirth>1978-10-19</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="bertaggia" url="http://en.wikipedia.org/wiki/Enrico_Bertaggia">
# 			<GivenName>Enrico</GivenName>
# 			<FamilyName>Bertaggia</FamilyName>
# 			<DateOfBirth>1964-09-19</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bettenhausen" url="http://en.wikipedia.org/wiki/Tony_Bettenhausen">
# 			<GivenName>Tony</GivenName>
# 			<FamilyName>Bettenhausen</FamilyName>
# 			<DateOfBirth>1916-09-12</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="beuttler" url="http://en.wikipedia.org/wiki/Mike_Beuttler">
# 			<GivenName>Mike</GivenName>
# 			<FamilyName>Beuttler</FamilyName>
# 			<DateOfBirth>1940-04-13</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="bianchi" code="BIA" url="http://en.wikipedia.org/wiki/Lucien_Bianchi">
# 			<GivenName>Lucien</GivenName>
# 			<FamilyName>Bianchi</FamilyName>
# 			<DateOfBirth>1934-11-10</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="jules_bianchi" code="BIA" url="http://en.wikipedia.org/wiki/Jules_Bianchi">
# 			<PermanentNumber>17</PermanentNumber>
# 			<GivenName>Jules</GivenName>
# 			<FamilyName>Bianchi</FamilyName>
# 			<DateOfBirth>1989-08-03</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="bianco" url="http://en.wikipedia.org/wiki/Gino_Bianco">
# 			<GivenName>Gino</GivenName>
# 			<FamilyName>Bianco</FamilyName>
# 			<DateOfBirth>1916-07-22</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="binder" url="http://en.wikipedia.org/wiki/Hans_Binder">
# 			<GivenName>Hans</GivenName>
# 			<FamilyName>Binder</FamilyName>
# 			<DateOfBirth>1948-06-12</DateOfBirth>
# 			<Nationality>Austrian</Nationality>
# 		</Driver>
# 		<Driver driverId="biondetti" url="http://en.wikipedia.org/wiki/Clemente_Biondetti">
# 			<GivenName>Clemente</GivenName>
# 			<FamilyName>Biondetti</FamilyName>
# 			<DateOfBirth>1898-08-18</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bira" url="http://en.wikipedia.org/wiki/Prince_Bira">
# 			<GivenName>Prince</GivenName>
# 			<FamilyName>Bira</FamilyName>
# 			<DateOfBirth>1914-07-15</DateOfBirth>
# 			<Nationality>Thai</Nationality>
# 		</Driver>
# 		<Driver driverId="birger" url="http://en.wikipedia.org/wiki/Pablo_Birger">
# 			<GivenName>Pablo</GivenName>
# 			<FamilyName>Birger</FamilyName>
# 			<DateOfBirth>1924-01-07</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="bisch" url="http://en.wikipedia.org/wiki/Art_Bisch">
# 			<GivenName>Art</GivenName>
# 			<FamilyName>Bisch</FamilyName>
# 			<DateOfBirth>1926-11-10</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="blanchard" url="http://en.wikipedia.org/wiki/Harry_Blanchard">
# 			<GivenName>Harry</GivenName>
# 			<FamilyName>Blanchard</FamilyName>
# 			<DateOfBirth>1929-06-13</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="bleekemolen" url="http://en.wikipedia.org/wiki/Michael_Bleekemolen">
# 			<GivenName>Michael</GivenName>
# 			<FamilyName>Bleekemolen</FamilyName>
# 			<DateOfBirth>1949-10-02</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="blignaut" url="http://en.wikipedia.org/wiki/Alex_Blignaut">
# 			<GivenName>Alex</GivenName>
# 			<FamilyName>Blignaut</FamilyName>
# 			<DateOfBirth>1932-11-30</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="blokdyk" url="http://en.wikipedia.org/wiki/Trevor_Blokdyk">
# 			<GivenName>Trevor</GivenName>
# 			<FamilyName>Blokdyk</FamilyName>
# 			<DateOfBirth>1935-11-30</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="blundell" url="http://en.wikipedia.org/wiki/Mark_Blundell">
# 			<GivenName>Mark</GivenName>
# 			<FamilyName>Blundell</FamilyName>
# 			<DateOfBirth>1966-04-08</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="boesel" url="http://en.wikipedia.org/wiki/Raul_Boesel">
# 			<GivenName>Raul</GivenName>
# 			<FamilyName>Boesel</FamilyName>
# 			<DateOfBirth>1957-12-04</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="boffa" url="http://en.wikipedia.org/wiki/Menato_Boffa">
# 			<GivenName>Menato</GivenName>
# 			<FamilyName>Boffa</FamilyName>
# 			<DateOfBirth>1930-01-04</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bondurant" url="http://en.wikipedia.org/wiki/Bob_Bondurant">
# 			<GivenName>Bob</GivenName>
# 			<FamilyName>Bondurant</FamilyName>
# 			<DateOfBirth>1933-04-27</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="bonetto" url="http://en.wikipedia.org/wiki/Felice_Bonetto">
# 			<GivenName>Felice</GivenName>
# 			<FamilyName>Bonetto</FamilyName>
# 			<DateOfBirth>1903-06-09</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bonnier" url="http://en.wikipedia.org/wiki/Joakim_Bonnier">
# 			<GivenName>Jo</GivenName>
# 			<FamilyName>Bonnier</FamilyName>
# 			<DateOfBirth>1930-01-31</DateOfBirth>
# 			<Nationality>Swedish</Nationality>
# 		</Driver>
# 		<Driver driverId="bonomi" url="http://en.wikipedia.org/wiki/Roberto_Bonomi">
# 			<GivenName>Roberto</GivenName>
# 			<FamilyName>Bonomi</FamilyName>
# 			<DateOfBirth>1919-09-30</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="bordeu" url="http://en.wikipedia.org/wiki/Juan_Manuel_Bordeu">
# 			<GivenName>Juan Manuel</GivenName>
# 			<FamilyName>Bordeu</FamilyName>
# 			<DateOfBirth>1934-01-28</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="borgudd" url="http://en.wikipedia.org/wiki/Slim_Borgudd">
# 			<GivenName>Slim</GivenName>
# 			<FamilyName>Borgudd</FamilyName>
# 			<DateOfBirth>1946-11-25</DateOfBirth>
# 			<Nationality>Swedish</Nationality>
# 		</Driver>
# 		<Driver driverId="botha" url="http://en.wikipedia.org/wiki/Luki_Botha">
# 			<GivenName>Luki</GivenName>
# 			<FamilyName>Botha</FamilyName>
# 			<DateOfBirth>1930-01-16</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="bottas" code="BOT" url="http://en.wikipedia.org/wiki/Valtteri_Bottas">
# 			<PermanentNumber>77</PermanentNumber>
# 			<GivenName>Valtteri</GivenName>
# 			<FamilyName>Bottas</FamilyName>
# 			<DateOfBirth>1989-08-28</DateOfBirth>
# 			<Nationality>Finnish</Nationality>
# 		</Driver>
# 		<Driver driverId="boullion" url="http://en.wikipedia.org/wiki/Jean-Christophe_Boullion">
# 			<GivenName>Jean-Christophe</GivenName>
# 			<FamilyName>Boullion</FamilyName>
# 			<DateOfBirth>1969-12-27</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="bourdais" code="BOU" url="http://en.wikipedia.org/wiki/S%C3%A9bastien_Bourdais">
# 			<GivenName>Sébastien</GivenName>
# 			<FamilyName>Bourdais</FamilyName>
# 			<DateOfBirth>1979-02-28</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="boutsen" url="http://en.wikipedia.org/wiki/Thierry_Boutsen">
# 			<GivenName>Thierry</GivenName>
# 			<FamilyName>Boutsen</FamilyName>
# 			<DateOfBirth>1957-07-13</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="boyd" url="http://en.wikipedia.org/wiki/Johnny_Boyd">
# 			<GivenName>Johnny</GivenName>
# 			<FamilyName>Boyd</FamilyName>
# 			<DateOfBirth>1926-08-19</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="brabham" url="http://en.wikipedia.org/wiki/David_Brabham">
# 			<GivenName>David</GivenName>
# 			<FamilyName>Brabham</FamilyName>
# 			<DateOfBirth>1965-09-05</DateOfBirth>
# 			<Nationality>Australian</Nationality>
# 		</Driver>
# 		<Driver driverId="gary_brabham" url="http://en.wikipedia.org/wiki/Gary_Brabham">
# 			<GivenName>Gary</GivenName>
# 			<FamilyName>Brabham</FamilyName>
# 			<DateOfBirth>1961-03-29</DateOfBirth>
# 			<Nationality>Australian</Nationality>
# 		</Driver>
# 		<Driver driverId="jack_brabham" url="http://en.wikipedia.org/wiki/Jack_Brabham">
# 			<GivenName>Jack</GivenName>
# 			<FamilyName>Brabham</FamilyName>
# 			<DateOfBirth>1926-04-02</DateOfBirth>
# 			<Nationality>Australian</Nationality>
# 		</Driver>
# 		<Driver driverId="brack" url="http://en.wikipedia.org/wiki/Bill_Brack">
# 			<GivenName>Bill</GivenName>
# 			<FamilyName>Brack</FamilyName>
# 			<DateOfBirth>1935-12-26</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="brambilla" url="http://en.wikipedia.org/wiki/Vittorio_Brambilla">
# 			<GivenName>Vittorio</GivenName>
# 			<FamilyName>Brambilla</FamilyName>
# 			<DateOfBirth>1937-11-11</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="ernesto_brambilla" url="http://en.wikipedia.org/wiki/Ernesto_Brambilla">
# 			<GivenName>Ernesto</GivenName>
# 			<FamilyName>Brambilla</FamilyName>
# 			<DateOfBirth>1934-01-31</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="branca" url="http://en.wikipedia.org/wiki/Toni_Branca">
# 			<GivenName>Toni</GivenName>
# 			<FamilyName>Branca</FamilyName>
# 			<DateOfBirth>1916-09-15</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="brancatelli" url="http://en.wikipedia.org/wiki/Gianfranco_Brancatelli">
# 			<GivenName>Gianfranco</GivenName>
# 			<FamilyName>Brancatelli</FamilyName>
# 			<DateOfBirth>1950-01-18</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="brandon" url="http://en.wikipedia.org/wiki/Eric_Brandon">
# 			<GivenName>Eric</GivenName>
# 			<FamilyName>Brandon</FamilyName>
# 			<DateOfBirth>1920-07-18</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="branson" url="http://en.wikipedia.org/wiki/Don_Branson">
# 			<GivenName>Don</GivenName>
# 			<FamilyName>Branson</FamilyName>
# 			<DateOfBirth>1920-06-02</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="bridger" url="http://en.wikipedia.org/wiki/Tom_Bridger">
# 			<GivenName>Tom</GivenName>
# 			<FamilyName>Bridger</FamilyName>
# 			<DateOfBirth>1934-06-24</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="brise" url="http://en.wikipedia.org/wiki/Tony_Brise">
# 			<GivenName>Tony</GivenName>
# 			<FamilyName>Brise</FamilyName>
# 			<DateOfBirth>1952-03-28</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="bristow" url="http://en.wikipedia.org/wiki/Chris_Bristow">
# 			<GivenName>Chris</GivenName>
# 			<FamilyName>Bristow</FamilyName>
# 			<DateOfBirth>1937-12-02</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="broeker" url="http://en.wikipedia.org/wiki/Peter_Broeker">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Broeker</FamilyName>
# 			<DateOfBirth>1926-05-15</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="brooks" url="http://en.wikipedia.org/wiki/Tony_Brooks">
# 			<GivenName>Tony</GivenName>
# 			<FamilyName>Brooks</FamilyName>
# 			<DateOfBirth>1932-02-25</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="brown" url="http://en.wikipedia.org/wiki/Warwick_Brown">
# 			<GivenName>Warwick</GivenName>
# 			<FamilyName>Brown</FamilyName>
# 			<DateOfBirth>1949-12-24</DateOfBirth>
# 			<Nationality>Australian</Nationality>
# 		</Driver>
# 		<Driver driverId="alan_brown" url="http://en.wikipedia.org/wiki/Alan_Brown_(racing_driver)">
# 			<GivenName>Alan</GivenName>
# 			<FamilyName>Brown</FamilyName>
# 			<DateOfBirth>1919-11-20</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="walt_brown" url="http://en.wikipedia.org/wiki/Walt_Brown_(auto_racer)">
# 			<GivenName>Walt</GivenName>
# 			<FamilyName>Brown</FamilyName>
# 			<DateOfBirth>1911-12-30</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="brudes" url="http://en.wikipedia.org/wiki/Adolf_Brudes">
# 			<GivenName>Adolf</GivenName>
# 			<FamilyName>Brudes</FamilyName>
# 			<DateOfBirth>1899-10-15</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="brundle" url="http://en.wikipedia.org/wiki/Martin_Brundle">
# 			<GivenName>Martin</GivenName>
# 			<FamilyName>Brundle</FamilyName>
# 			<DateOfBirth>1959-06-01</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="bruni" url="http://en.wikipedia.org/wiki/Gianmaria_Bruni">
# 			<GivenName>Gianmaria</GivenName>
# 			<FamilyName>Bruni</FamilyName>
# 			<DateOfBirth>1981-05-30</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="bryan" url="http://en.wikipedia.org/wiki/Jimmy_Bryan">
# 			<GivenName>Jimmy</GivenName>
# 			<FamilyName>Bryan</FamilyName>
# 			<DateOfBirth>1926-01-28</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="bucci" url="http://en.wikipedia.org/wiki/Clemar_Bucci">
# 			<GivenName>Clemar</GivenName>
# 			<FamilyName>Bucci</FamilyName>
# 			<DateOfBirth>1920-09-04</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="bucknum" url="http://en.wikipedia.org/wiki/Ronnie_Bucknum">
# 			<GivenName>Ronnie</GivenName>
# 			<FamilyName>Bucknum</FamilyName>
# 			<DateOfBirth>1936-04-05</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="bueb" url="http://en.wikipedia.org/wiki/Ivor_Bueb">
# 			<GivenName>Ivor</GivenName>
# 			<FamilyName>Bueb</FamilyName>
# 			<DateOfBirth>1923-06-06</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="buemi" code="BUE" url="http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi">
# 			<GivenName>Sébastien</GivenName>
# 			<FamilyName>Buemi</FamilyName>
# 			<DateOfBirth>1988-10-31</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="bueno" url="http://en.wikipedia.org/wiki/Luiz_Bueno">
# 			<GivenName>Luiz</GivenName>
# 			<FamilyName>Bueno</FamilyName>
# 			<DateOfBirth>1937-01-16</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="burgess" url="http://en.wikipedia.org/wiki/Ian_Burgess">
# 			<GivenName>Ian</GivenName>
# 			<FamilyName>Burgess</FamilyName>
# 			<DateOfBirth>1930-07-06</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="burti" url="http://en.wikipedia.org/wiki/Luciano_Burti">
# 			<GivenName>Luciano</GivenName>
# 			<FamilyName>Burti</FamilyName>
# 			<DateOfBirth>1975-03-05</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="bussinello" url="http://en.wikipedia.org/wiki/Roberto_Bussinello">
# 			<GivenName>Roberto</GivenName>
# 			<FamilyName>Bussinello</FamilyName>
# 			<DateOfBirth>1927-10-04</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="button" code="BUT" url="http://en.wikipedia.org/wiki/Jenson_Button">
# 			<PermanentNumber>22</PermanentNumber>
# 			<GivenName>Jenson</GivenName>
# 			<FamilyName>Button</FamilyName>
# 			<DateOfBirth>1980-01-19</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="byrne" url="http://en.wikipedia.org/wiki/Tommy_Byrne_%28racing_driver%29">
# 			<GivenName>Tommy</GivenName>
# 			<FamilyName>Byrne</FamilyName>
# 			<DateOfBirth>1958-05-06</DateOfBirth>
# 			<Nationality>Irish</Nationality>
# 		</Driver>
# 		<Driver driverId="cabantous" url="http://en.wikipedia.org/wiki/Yves_Giraud_Cabantous">
# 			<GivenName>Yves</GivenName>
# 			<FamilyName>Cabantous</FamilyName>
# 			<DateOfBirth>1904-10-08</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="cabianca" url="http://en.wikipedia.org/wiki/Giulio_Cabianca">
# 			<GivenName>Giulio</GivenName>
# 			<FamilyName>Cabianca</FamilyName>
# 			<DateOfBirth>1923-02-19</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="cabral" url="http://en.wikipedia.org/wiki/Mario_de_Araujo_Cabral">
# 			<GivenName>Mário de Araújo</GivenName>
# 			<FamilyName>Cabral</FamilyName>
# 			<DateOfBirth>1934-01-15</DateOfBirth>
# 			<Nationality>Portuguese</Nationality>
# 		</Driver>
# 		<Driver driverId="cade" url="http://en.wikipedia.org/wiki/Phil_Cade">
# 			<GivenName>Phil</GivenName>
# 			<FamilyName>Cade</FamilyName>
# 			<DateOfBirth>1916-06-12</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="caffi" url="http://en.wikipedia.org/wiki/Alex_Caffi">
# 			<GivenName>Alex</GivenName>
# 			<FamilyName>Caffi</FamilyName>
# 			<DateOfBirth>1964-03-18</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="campbell-jones" url="http://en.wikipedia.org/wiki/John_Campbell-Jones">
# 			<GivenName>John</GivenName>
# 			<FamilyName>Campbell-Jones</FamilyName>
# 			<DateOfBirth>1930-01-21</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="campos" url="http://en.wikipedia.org/wiki/Adri%C3%A1n_Campos">
# 			<GivenName>Adrián</GivenName>
# 			<FamilyName>Campos</FamilyName>
# 			<DateOfBirth>1960-06-17</DateOfBirth>
# 			<Nationality>Spanish</Nationality>
# 		</Driver>
# 		<Driver driverId="Cannoc" url="http://en.wikipedia.org/wiki/John_Cannon_(auto_racer)">
# 			<GivenName>John</GivenName>
# 			<FamilyName>Cannon</FamilyName>
# 			<DateOfBirth>1933-06-21</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="cantoni" url="http://en.wikipedia.org/wiki/Eitel_Cantoni">
# 			<GivenName>Eitel</GivenName>
# 			<FamilyName>Cantoni</FamilyName>
# 			<DateOfBirth>1906-10-04</DateOfBirth>
# 			<Nationality>Uruguayan</Nationality>
# 		</Driver>
# 		<Driver driverId="cantrell" url="http://en.wikipedia.org/wiki/William_Cantrell">
# 			<GivenName>Bill</GivenName>
# 			<FamilyName>Cantrell</FamilyName>
# 			<DateOfBirth>1908-01-31</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="capelli" url="http://en.wikipedia.org/wiki/Ivan_Capelli">
# 			<GivenName>Ivan</GivenName>
# 			<FamilyName>Capelli</FamilyName>
# 			<DateOfBirth>1963-05-24</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="carini" url="http://en.wikipedia.org/wiki/Piero_Carini">
# 			<GivenName>Piero</GivenName>
# 			<FamilyName>Carini</FamilyName>
# 			<DateOfBirth>1921-03-06</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="darter" url="http://en.wikipedia.org/wiki/Duane_Carter">
# 			<GivenName>Duane</GivenName>
# 			<FamilyName>Carter</FamilyName>
# 			<DateOfBirth>1913-05-05</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="castellotti" url="http://en.wikipedia.org/wiki/Eugenio_Castellotti">
# 			<GivenName>Eugenio</GivenName>
# 			<FamilyName>Castellotti</FamilyName>
# 			<DateOfBirth>1930-10-10</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="cecotto" url="http://en.wikipedia.org/wiki/Johnny_Cecotto">
# 			<GivenName>Johnny</GivenName>
# 			<FamilyName>Cecotto</FamilyName>
# 			<DateOfBirth>1956-01-25</DateOfBirth>
# 			<Nationality>Venezuelan</Nationality>
# 		</Driver>
# 		<Driver driverId="cevert" url="http://en.wikipedia.org/wiki/Fran%C3%A7ois_Cevert">
# 			<GivenName>François</GivenName>
# 			<FamilyName>Cevert</FamilyName>
# 			<DateOfBirth>1944-02-25</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="chaboud" url="http://en.wikipedia.org/wiki/Eug%C3%A8ne_Chaboud">
# 			<GivenName>Eugène</GivenName>
# 			<FamilyName>Chaboud</FamilyName>
# 			<DateOfBirth>1907-04-12</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="chamberlain" url="http://en.wikipedia.org/wiki/Jay_Chamberlain">
# 			<GivenName>Jay</GivenName>
# 			<FamilyName>Chamberlain</FamilyName>
# 			<DateOfBirth>1925-12-29</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="chandhok" code="CHA" url="http://en.wikipedia.org/wiki/Karun_Chandhok">
# 			<GivenName>Karun</GivenName>
# 			<FamilyName>Chandhok</FamilyName>
# 			<DateOfBirth>1984-01-19</DateOfBirth>
# 			<Nationality>Indian</Nationality>
# 		</Driver>
# 		<Driver driverId="chapman" url="http://en.wikipedia.org/wiki/Colin_Chapman">
# 			<GivenName>Colin</GivenName>
# 			<FamilyName>Chapman</FamilyName>
# 			<DateOfBirth>1928-05-19</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="charlton" url="http://en.wikipedia.org/wiki/Dave_Charlton">
# 			<GivenName>Dave</GivenName>
# 			<FamilyName>Charlton</FamilyName>
# 			<DateOfBirth>1936-10-27</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="chaves" url="http://en.wikipedia.org/wiki/Pedro_Chaves">
# 			<GivenName>Pedro</GivenName>
# 			<FamilyName>Chaves</FamilyName>
# 			<DateOfBirth>1965-02-27</DateOfBirth>
# 			<Nationality>Portuguese</Nationality>
# 		</Driver>
# 		<Driver driverId="cheesbourg" url="http://en.wikipedia.org/wiki/Bill_Cheesbourg">
# 			<GivenName>Bill</GivenName>
# 			<FamilyName>Cheesbourg</FamilyName>
# 			<DateOfBirth>1927-06-12</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="cheever" url="http://en.wikipedia.org/wiki/Eddie_Cheever">
# 			<GivenName>Eddie</GivenName>
# 			<FamilyName>Cheever</FamilyName>
# 			<DateOfBirth>1958-01-10</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="chiesa" url="http://en.wikipedia.org/wiki/Andrea_Chiesa">
# 			<GivenName>Andrea</GivenName>
# 			<FamilyName>Chiesa</FamilyName>
# 			<DateOfBirth>1964-05-06</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="chilton" code="CHI" url="http://en.wikipedia.org/wiki/Max_Chilton">
# 			<PermanentNumber>4</PermanentNumber>
# 			<GivenName>Max</GivenName>
# 			<FamilyName>Chilton</FamilyName>
# 			<DateOfBirth>1991-04-21</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="chimeri" url="http://en.wikipedia.org/wiki/Ettore_Chimeri">
# 			<GivenName>Ettore</GivenName>
# 			<FamilyName>Chimeri</FamilyName>
# 			<DateOfBirth>1921-06-04</DateOfBirth>
# 			<Nationality>Venezuelan</Nationality>
# 		</Driver>
# 		<Driver driverId="chiron" url="http://en.wikipedia.org/wiki/Louis_Chiron">
# 			<GivenName>Louis</GivenName>
# 			<FamilyName>Chiron</FamilyName>
# 			<DateOfBirth>1899-08-03</DateOfBirth>
# 			<Nationality>Monegasque</Nationality>
# 		</Driver>
# 		<Driver driverId="chitwood" url="http://en.wikipedia.org/wiki/Joie_Chitwood">
# 			<GivenName>Joie</GivenName>
# 			<FamilyName>Chitwood</FamilyName>
# 			<DateOfBirth>1912-04-14</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="christie" url="http://en.wikipedia.org/wiki/Bob_Christie_(racing_driver)">
# 			<GivenName>Bob</GivenName>
# 			<FamilyName>Christie</FamilyName>
# 			<DateOfBirth>1924-04-04</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="claes" url="http://en.wikipedia.org/wiki/Johnny_Claes">
# 			<GivenName>Johnny</GivenName>
# 			<FamilyName>Claes</FamilyName>
# 			<DateOfBirth>1916-08-11</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="clapham" url="http://en.wikipedia.org/wiki/David_Clapham">
# 			<GivenName>David</GivenName>
# 			<FamilyName>Clapham</FamilyName>
# 			<DateOfBirth>1931-05-18</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="clark" url="http://en.wikipedia.org/wiki/Jim_Clark">
# 			<GivenName>Jim</GivenName>
# 			<FamilyName>Clark</FamilyName>
# 			<DateOfBirth>1936-03-04</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="cogan" url="http://en.wikipedia.org/wiki/Kevin_Cogan">
# 			<GivenName>Kevin</GivenName>
# 			<FamilyName>Cogan</FamilyName>
# 			<DateOfBirth>1956-03-31</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="collins" url="http://en.wikipedia.org/wiki/Peter_Collins_(racing_driver)">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Collins</FamilyName>
# 			<DateOfBirth>1931-11-06</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="collomb" url="http://en.wikipedia.org/wiki/Bernard_Collomb">
# 			<GivenName>Bernard</GivenName>
# 			<FamilyName>Collomb</FamilyName>
# 			<DateOfBirth>1930-10-07</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="colombo" url="http://en.wikipedia.org/wiki/Alberto_Colombo">
# 			<GivenName>Alberto</GivenName>
# 			<FamilyName>Colombo</FamilyName>
# 			<DateOfBirth>1946-02-23</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="comas" url="http://en.wikipedia.org/wiki/%C3%89rik_Comas">
# 			<GivenName>Érik</GivenName>
# 			<FamilyName>Comas</FamilyName>
# 			<DateOfBirth>1963-09-28</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="comotti" url="http://en.wikipedia.org/wiki/Franco_Comotti">
# 			<GivenName>Franco</GivenName>
# 			<FamilyName>Comotti</FamilyName>
# 			<DateOfBirth>1906-07-24</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="george_connor" url="http://en.wikipedia.org/wiki/George_Connor_(driver)">
# 			<GivenName>George</GivenName>
# 			<FamilyName>Connor</FamilyName>
# 			<DateOfBirth>1906-08-16</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="constantine" url="http://en.wikipedia.org/wiki/George_Constantine">
# 			<GivenName>George</GivenName>
# 			<FamilyName>Constantine</FamilyName>
# 			<DateOfBirth>1918-02-22</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="cordts" url="http://en.wikipedia.org/wiki/John_Cordts">
# 			<GivenName>John</GivenName>
# 			<FamilyName>Cordts</FamilyName>
# 			<DateOfBirth>1935-07-23</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="coulthard" code="COU" url="http://en.wikipedia.org/wiki/David_Coulthard">
# 			<GivenName>David</GivenName>
# 			<FamilyName>Coulthard</FamilyName>
# 			<DateOfBirth>1971-03-27</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="courage" url="http://en.wikipedia.org/wiki/Piers_Courage">
# 			<GivenName>Piers</GivenName>
# 			<FamilyName>Courage</FamilyName>
# 			<DateOfBirth>1942-05-27</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="craft" url="http://en.wikipedia.org/wiki/Chris_Craft_(racing_driver)">
# 			<GivenName>Chris</GivenName>
# 			<FamilyName>Craft</FamilyName>
# 			<DateOfBirth>1939-11-17</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="crawford" url="http://en.wikipedia.org/wiki/Jim_Crawford_(driver)">
# 			<GivenName>Jim</GivenName>
# 			<FamilyName>Crawford</FamilyName>
# 			<DateOfBirth>1948-02-13</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="ray_crawford" url="http://en.wikipedia.org/wiki/Ray_Crawford">
# 			<GivenName>Ray</GivenName>
# 			<FamilyName>Crawford</FamilyName>
# 			<DateOfBirth>1915-10-26</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="crespo" url="http://en.wikipedia.org/wiki/Alberto_Crespo">
# 			<GivenName>Alberto</GivenName>
# 			<FamilyName>Crespo</FamilyName>
# 			<DateOfBirth>1920-01-16</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="creus" url="http://en.wikipedia.org/wiki/Antonio_Creus">
# 			<GivenName>Antonio</GivenName>
# 			<FamilyName>Creus</FamilyName>
# 			<DateOfBirth>1924-10-28</DateOfBirth>
# 			<Nationality>Spanish</Nationality>
# 		</Driver>
# 		<Driver driverId="crockett" url="http://en.wikipedia.org/wiki/Larry_Crockett">
# 			<GivenName>Larry</GivenName>
# 			<FamilyName>Crockett</FamilyName>
# 			<DateOfBirth>1926-10-23</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="crook" url="http://en.wikipedia.org/wiki/Tony_Crook">
# 			<GivenName>Tony</GivenName>
# 			<FamilyName>Crook</FamilyName>
# 			<DateOfBirth>1920-02-16</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="cross" url="http://en.wikipedia.org/wiki/Art_Cross">
# 			<GivenName>Art</GivenName>
# 			<FamilyName>Cross</FamilyName>
# 			<DateOfBirth>1918-01-24</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="crossley" url="http://en.wikipedia.org/wiki/Geoff_Crossley">
# 			<GivenName>Geoff</GivenName>
# 			<FamilyName>Crossley</FamilyName>
# 			<DateOfBirth>1921-05-11</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="cruz" url="http://en.wikipedia.org/wiki/Adolfo_Schewelm_Cruz">
# 			<GivenName>Adolfo</GivenName>
# 			<FamilyName>Cruz</FamilyName>
# 			<DateOfBirth>1923-06-28</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="ambrosio" code="DAM" url="http://en.wikipedia.org/wiki/J%C3%A9r%C3%B4me_d%27Ambrosio">
# 			<GivenName>Jérôme</GivenName>
# 			<FamilyName>d'Ambrosio</FamilyName>
# 			<DateOfBirth>1985-12-27</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="orey" url="http://en.wikipedia.org/wiki/Fritz_d%27Orey">
# 			<GivenName>Fritz</GivenName>
# 			<FamilyName>d'Orey</FamilyName>
# 			<DateOfBirth>1938-03-25</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="matta" url="http://en.wikipedia.org/wiki/Cristiano_da_Matta">
# 			<GivenName>Cristiano</GivenName>
# 			<FamilyName>da Matta</FamilyName>
# 			<DateOfBirth>1973-09-19</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="ramos" url="http://en.wikipedia.org/wiki/Hernando_da_Silva_Ramos">
# 			<GivenName>Hernando</GivenName>
# 			<FamilyName>da Silva Ramos</FamilyName>
# 			<DateOfBirth>1925-12-07</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="daigh" url="http://en.wikipedia.org/wiki/Chuck_Daigh">
# 			<GivenName>Chuck</GivenName>
# 			<FamilyName>Daigh</FamilyName>
# 			<DateOfBirth>1923-11-29</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="dalmas" url="http://en.wikipedia.org/wiki/Yannick_Dalmas">
# 			<GivenName>Yannick</GivenName>
# 			<FamilyName>Dalmas</FamilyName>
# 			<DateOfBirth>1961-07-28</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="daly" url="http://en.wikipedia.org/wiki/Derek_Daly">
# 			<GivenName>Derek</GivenName>
# 			<FamilyName>Daly</FamilyName>
# 			<DateOfBirth>1953-03-11</DateOfBirth>
# 			<Nationality>Irish</Nationality>
# 		</Driver>
# 		<Driver driverId="danner" url="http://en.wikipedia.org/wiki/Christian_Danner">
# 			<GivenName>Christian</GivenName>
# 			<FamilyName>Danner</FamilyName>
# 			<DateOfBirth>1958-04-04</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="daponte" url="http://en.wikipedia.org/wiki/Jorge_Daponte">
# 			<GivenName>Jorge</GivenName>
# 			<FamilyName>Daponte</FamilyName>
# 			<DateOfBirth>1923-06-05</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 		<Driver driverId="davidson" code="DAV" url="http://en.wikipedia.org/wiki/Anthony_Davidson">
# 			<GivenName>Anthony</GivenName>
# 			<FamilyName>Davidson</FamilyName>
# 			<DateOfBirth>1979-04-18</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="davies" url="http://en.wikipedia.org/wiki/Jimmy_Davies">
# 			<GivenName>Jimmy</GivenName>
# 			<FamilyName>Davies</FamilyName>
# 			<DateOfBirth>1929-08-08</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="davis" url="http://en.wikipedia.org/wiki/Colin_Davis_(driver)">
# 			<GivenName>Colin</GivenName>
# 			<FamilyName>Davis</FamilyName>
# 			<DateOfBirth>1933-07-29</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="daywalt" url="http://en.wikipedia.org/wiki/Jimmy_Daywalt">
# 			<GivenName>Jimmy</GivenName>
# 			<FamilyName>Daywalt</FamilyName>
# 			<DateOfBirth>1924-08-28</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="adamich" url="http://en.wikipedia.org/wiki/Andrea_de_Adamich">
# 			<GivenName>Andrea</GivenName>
# 			<FamilyName>de Adamich</FamilyName>
# 			<DateOfBirth>1941-10-03</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="angelis" url="http://en.wikipedia.org/wiki/Elio_de_Angelis">
# 			<GivenName>Elio</GivenName>
# 			<FamilyName>de Angelis</FamilyName>
# 			<DateOfBirth>1958-03-26</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="beaufort" url="http://en.wikipedia.org/wiki/Carel_Godin_de_Beaufort">
# 			<GivenName>Carel Godin</GivenName>
# 			<FamilyName>de Beaufort</FamilyName>
# 			<DateOfBirth>1934-04-10</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="cesaris" url="http://en.wikipedia.org/wiki/Andrea_de_Cesaris">
# 			<GivenName>Andrea</GivenName>
# 			<FamilyName>de Cesaris</FamilyName>
# 			<DateOfBirth>1959-05-31</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="Changy" url="http://en.wikipedia.org/wiki/Alain_de_Changy">
# 			<GivenName>Alain</GivenName>
# 			<FamilyName>de Changy</FamilyName>
# 			<DateOfBirth>1922-02-05</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="dryver" url="http://en.wikipedia.org/wiki/Bernard_de_Dryver">
# 			<GivenName>Bernard</GivenName>
# 			<FamilyName>de Dryver</FamilyName>
# 			<DateOfBirth>1952-09-19</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="filippis" url="http://en.wikipedia.org/wiki/Maria_Teresa_de_Filippis">
# 			<GivenName>Maria</GivenName>
# 			<FamilyName>de Filippis</FamilyName>
# 			<DateOfBirth>1926-11-11</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="graffenried" url="http://en.wikipedia.org/wiki/Toulo_de_Graffenried">
# 			<GivenName>Toulo</GivenName>
# 			<FamilyName>de Graffenried</FamilyName>
# 			<DateOfBirth>1914-05-18</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="klerk" url="http://en.wikipedia.org/wiki/Peter_de_Klerk">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>de Klerk</FamilyName>
# 			<DateOfBirth>1935-03-16</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="rosa" code="DLR" url="http://en.wikipedia.org/wiki/Pedro_de_la_Rosa">
# 			<GivenName>Pedro</GivenName>
# 			<FamilyName>de la Rosa</FamilyName>
# 			<DateOfBirth>1971-02-24</DateOfBirth>
# 			<Nationality>Spanish</Nationality>
# 		</Driver>
# 		<Driver driverId="portago" url="http://en.wikipedia.org/wiki/Alfonso_de_Portago">
# 			<GivenName>Alfonso</GivenName>
# 			<FamilyName>de Portago</FamilyName>
# 			<DateOfBirth>1928-10-11</DateOfBirth>
# 			<Nationality>Spanish</Nationality>
# 		</Driver>
# 		<Driver driverId="riu" url="http://en.wikipedia.org/wiki/Giovanni_de_Riu">
# 			<GivenName>Giovanni</GivenName>
# 			<FamilyName>de Riu</FamilyName>
# 			<DateOfBirth>1925-03-10</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="terra" url="http://en.wikipedia.org/wiki/Max_de_Terra">
# 			<GivenName>Max</GivenName>
# 			<FamilyName>de Terra</FamilyName>
# 			<DateOfBirth>1918-10-06</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="tomaso" url="http://en.wikipedia.org/wiki/Alessandro_de_Tomaso">
# 			<GivenName>Alessandro</GivenName>
# 			<FamilyName>de Tomaso</FamilyName>
# 			<DateOfBirth>1928-07-10</DateOfBirth>
# 			<Nationality>Argentine-Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="tornaco" url="http://en.wikipedia.org/wiki/Charles_de_Tornaco">
# 			<GivenName>Charles</GivenName>
# 			<FamilyName>de Tornaco</FamilyName>
# 			<DateOfBirth>1927-06-07</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="villota" url="http://en.wikipedia.org/wiki/Emilio_de_Villota">
# 			<GivenName>Emilio</GivenName>
# 			<FamilyName>de Villota</FamilyName>
# 			<DateOfBirth>1946-07-26</DateOfBirth>
# 			<Nationality>Spanish</Nationality>
# 		</Driver>
# 		<Driver driverId="vos" url="http://en.wikipedia.org/wiki/Ernie_de_Vos">
# 			<GivenName>Ernie</GivenName>
# 			<FamilyName>de Vos</FamilyName>
# ...
# 		</Driver>
# 		<Driver driverId="garde" code="VDG" url="http://en.wikipedia.org/wiki/Giedo_van_der_Garde">
# 			<GivenName>Giedo</GivenName>
# 			<FamilyName>van der Garde</FamilyName>
# 			<DateOfBirth>1985-04-25</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="lof" url="http://en.wikipedia.org/wiki/Dries_van_der_Lof">
# 			<GivenName>Dries</GivenName>
# 			<FamilyName>van der Lof</FamilyName>
# 			<DateOfBirth>1919-08-23</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="vyver" url="http://en.wikipedia.org/wiki/Syd_van_der_Vyver">
# 			<GivenName>Syd</GivenName>
# 			<FamilyName>van der Vyver</FamilyName>
# 			<DateOfBirth>1920-06-01</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="lennep" url="http://en.wikipedia.org/wiki/Gijs_Van_Lennep">
# 			<GivenName>Gijs</GivenName>
# 			<FamilyName>van Lennep</FamilyName>
# 			<DateOfBirth>1942-03-16</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="rooyen" url="http://en.wikipedia.org/wiki/Basil_van_Rooyen">
# 			<GivenName>Basil</GivenName>
# 			<FamilyName>van Rooyen</FamilyName>
# 			<DateOfBirth>1939-04-19</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="vandoorne" code="VAN" url="http://en.wikipedia.org/wiki/Stoffel_Vandoorne">
# 			<PermanentNumber>2</PermanentNumber>
# 			<GivenName>Stoffel</GivenName>
# 			<FamilyName>Vandoorne</FamilyName>
# 			<DateOfBirth>1992-03-26</DateOfBirth>
# 			<Nationality>Belgian</Nationality>
# 		</Driver>
# 		<Driver driverId="veith" url="http://en.wikipedia.org/wiki/Bob_Veith">
# 			<GivenName>Bob</GivenName>
# 			<FamilyName>Veith</FamilyName>
# 			<DateOfBirth>1926-11-01</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="vergne" code="VER" url="http://en.wikipedia.org/wiki/Jean-%C3%89ric_Vergne">
# 			<PermanentNumber>25</PermanentNumber>
# 			<GivenName>Jean-Éric</GivenName>
# 			<FamilyName>Vergne</FamilyName>
# 			<DateOfBirth>1990-04-25</DateOfBirth>
# 			<Nationality>French</Nationality>
# 		</Driver>
# 		<Driver driverId="verstappen" url="http://en.wikipedia.org/wiki/Jos_Verstappen">
# 			<GivenName>Jos</GivenName>
# 			<FamilyName>Verstappen</FamilyName>
# 			<DateOfBirth>1972-03-04</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="max_verstappen" code="VER" url="http://en.wikipedia.org/wiki/Max_Verstappen">
# 			<PermanentNumber>33</PermanentNumber>
# 			<GivenName>Max</GivenName>
# 			<FamilyName>Verstappen</FamilyName>
# 			<DateOfBirth>1997-09-30</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="vettel" code="VET" url="http://en.wikipedia.org/wiki/Sebastian_Vettel">
# 			<PermanentNumber>5</PermanentNumber>
# 			<GivenName>Sebastian</GivenName>
# 			<FamilyName>Vettel</FamilyName>
# 			<DateOfBirth>1987-07-03</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="villeneuve" code="VIL" url="http://en.wikipedia.org/wiki/Jacques_Villeneuve">
# 			<GivenName>Jacques</GivenName>
# 			<FamilyName>Villeneuve</FamilyName>
# 			<DateOfBirth>1971-04-09</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="gilles_villeneuve" url="http://en.wikipedia.org/wiki/Gilles_Villeneuve">
# 			<GivenName>Gilles</GivenName>
# 			<FamilyName>Villeneuve</FamilyName>
# 			<DateOfBirth>1950-01-18</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="villeneuve_sr" url="http://en.wikipedia.org/wiki/Jacques_Villeneuve_(elder)">
# 			<GivenName>Jacques</GivenName>
# 			<FamilyName>Villeneuve Sr.</FamilyName>
# 			<DateOfBirth>1953-11-04</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="villoresi" url="http://en.wikipedia.org/wiki/Luigi_Villoresi">
# 			<GivenName>Luigi</GivenName>
# 			<FamilyName>Villoresi</FamilyName>
# 			<DateOfBirth>1909-05-16</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="volonterio" url="http://en.wikipedia.org/wiki/Ottorino_Volonterio">
# 			<GivenName>Ottorino</GivenName>
# 			<FamilyName>Volonterio</FamilyName>
# 			<DateOfBirth>1917-12-07</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="opel" url="http://en.wikipedia.org/wiki/Rikky_von_Opel">
# 			<GivenName>Rikky</GivenName>
# 			<FamilyName>von Opel</FamilyName>
# 			<DateOfBirth>1947-10-14</DateOfBirth>
# 			<Nationality>Liechtensteiner</Nationality>
# 		</Driver>
# 		<Driver driverId="hans_stuck" url="http://en.wikipedia.org/wiki/Hans_Von_Stuck">
# 			<GivenName>Hans</GivenName>
# 			<FamilyName>von Stuck</FamilyName>
# 			<DateOfBirth>1900-12-27</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="trips" url="http://en.wikipedia.org/wiki/Wolfgang_Graf_Berghe_von_Trips">
# 			<GivenName>Wolfgang</GivenName>
# 			<FamilyName>von Trips</FamilyName>
# 			<DateOfBirth>1928-05-04</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="vonlanthen" url="http://en.wikipedia.org/wiki/Jo_Vonlanthen">
# 			<GivenName>Jo</GivenName>
# 			<FamilyName>Vonlanthen</FamilyName>
# 			<DateOfBirth>1942-05-31</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="vukovich" url="http://en.wikipedia.org/wiki/Bill_Vukovich">
# 			<GivenName>Bill</GivenName>
# 			<FamilyName>Vukovich</FamilyName>
# 			<DateOfBirth>1918-12-13</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="wacker" url="http://en.wikipedia.org/wiki/Fred_Wacker">
# 			<GivenName>Fred</GivenName>
# 			<FamilyName>Wacker</FamilyName>
# 			<DateOfBirth>1918-07-10</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="walker" url="http://en.wikipedia.org/wiki/David_Walker_(racing_driver)">
# 			<GivenName>David</GivenName>
# 			<FamilyName>Walker</FamilyName>
# 			<DateOfBirth>1941-06-10</DateOfBirth>
# 			<Nationality>Australian</Nationality>
# 		</Driver>
# 		<Driver driverId="peter_walker" url="http://en.wikipedia.org/wiki/Peter_Walker_(driver)">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Walker</FamilyName>
# 			<DateOfBirth>1912-10-07</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="wallard" url="http://en.wikipedia.org/wiki/Lee_Wallard">
# 			<GivenName>Lee</GivenName>
# 			<FamilyName>Wallard</FamilyName>
# 			<DateOfBirth>1910-09-07</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="walter" url="http://en.wikipedia.org/wiki/Heini_Walter">
# 			<GivenName>Heini</GivenName>
# 			<FamilyName>Walter</FamilyName>
# 			<DateOfBirth>1927-07-28</DateOfBirth>
# 			<Nationality>Swiss</Nationality>
# 		</Driver>
# 		<Driver driverId="ward" url="http://en.wikipedia.org/wiki/Rodger_Ward">
# 			<GivenName>Rodger</GivenName>
# 			<FamilyName>Ward</FamilyName>
# 			<DateOfBirth>1921-01-10</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="warwick" url="http://en.wikipedia.org/wiki/Derek_Warwick">
# 			<GivenName>Derek</GivenName>
# 			<FamilyName>Warwick</FamilyName>
# 			<DateOfBirth>1954-08-27</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="watson" url="http://en.wikipedia.org/wiki/John_Watson_(racing_driver)">
# 			<GivenName>John</GivenName>
# 			<FamilyName>Watson</FamilyName>
# 			<DateOfBirth>1946-05-04</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="webb" url="http://en.wikipedia.org/wiki/Travis_Webb">
# 			<GivenName>Travis</GivenName>
# 			<FamilyName>Webb</FamilyName>
# 			<DateOfBirth>1910-10-08</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="webber" code="WEB" url="http://en.wikipedia.org/wiki/Mark_Webber">
# 			<GivenName>Mark</GivenName>
# 			<FamilyName>Webber</FamilyName>
# 			<DateOfBirth>1976-08-27</DateOfBirth>
# 			<Nationality>Australian</Nationality>
# 		</Driver>
# 		<Driver driverId="wehrlein" code="WEH" url="http://en.wikipedia.org/wiki/Pascal_Wehrlein">
# 			<PermanentNumber>94</PermanentNumber>
# 			<GivenName>Pascal</GivenName>
# 			<FamilyName>Wehrlein</FamilyName>
# 			<DateOfBirth>1994-10-18</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="weidler" url="http://en.wikipedia.org/wiki/Volker_Weidler">
# 			<GivenName>Volker</GivenName>
# 			<FamilyName>Weidler</FamilyName>
# 			<DateOfBirth>1962-03-18</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="weiler" url="http://en.wikipedia.org/wiki/Wayne_Weiler">
# 			<GivenName>Wayne</GivenName>
# 			<FamilyName>Weiler</FamilyName>
# 			<DateOfBirth>1934-12-09</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="wendlinger" url="http://en.wikipedia.org/wiki/Karl_Wendlinger">
# 			<GivenName>Karl</GivenName>
# 			<FamilyName>Wendlinger</FamilyName>
# 			<DateOfBirth>1968-12-20</DateOfBirth>
# 			<Nationality>Austrian</Nationality>
# 		</Driver>
# 		<Driver driverId="westbury" url="http://en.wikipedia.org/wiki/Peter_Westbury">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Westbury</FamilyName>
# 			<DateOfBirth>1938-05-26</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="weyant" url="http://en.wikipedia.org/wiki/Chuck_Weyant">
# 			<GivenName>Chuck</GivenName>
# 			<FamilyName>Weyant</FamilyName>
# 			<DateOfBirth>1923-04-03</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="wharton" url="http://en.wikipedia.org/wiki/Ken_Wharton">
# 			<GivenName>Ken</GivenName>
# 			<FamilyName>Wharton</FamilyName>
# 			<DateOfBirth>1916-03-21</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="whiteaway" url="http://en.wikipedia.org/wiki/Ted_Whiteaway">
# 			<GivenName>Ted</GivenName>
# 			<FamilyName>Whiteaway</FamilyName>
# 			<DateOfBirth>1928-11-01</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="whitehead" url="http://en.wikipedia.org/wiki/Peter_Whitehead_(racing_driver)">
# 			<GivenName>Peter</GivenName>
# 			<FamilyName>Whitehead</FamilyName>
# 			<DateOfBirth>1914-11-12</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="graham_whitehead" url="http://en.wikipedia.org/wiki/Graham_Whitehead">
# 			<GivenName>Graham</GivenName>
# 			<FamilyName>Whitehead</FamilyName>
# 			<DateOfBirth>1922-04-15</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="whitehouse" url="http://en.wikipedia.org/wiki/Bill_Whitehouse">
# 			<GivenName>Bill</GivenName>
# 			<FamilyName>Whitehouse</FamilyName>
# 			<DateOfBirth>1909-04-01</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="widdows" url="http://en.wikipedia.org/wiki/Robin_Widdows">
# 			<GivenName>Robin</GivenName>
# 			<FamilyName>Widdows</FamilyName>
# 			<DateOfBirth>1942-05-27</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="wietzes" url="http://en.wikipedia.org/wiki/Eppie_Wietzes">
# 			<GivenName>Eppie</GivenName>
# 			<FamilyName>Wietzes</FamilyName>
# 			<DateOfBirth>1938-05-28</DateOfBirth>
# 			<Nationality>Canadian</Nationality>
# 		</Driver>
# 		<Driver driverId="wilds" url="http://en.wikipedia.org/wiki/Mike_Wilds">
# 			<GivenName>Mike</GivenName>
# 			<FamilyName>Wilds</FamilyName>
# 			<DateOfBirth>1946-01-07</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="williams" url="http://en.wikipedia.org/wiki/Jonathan_Williams_(racing_driver)">
# 			<GivenName>Jonathan</GivenName>
# 			<FamilyName>Williams</FamilyName>
# 			<DateOfBirth>1942-10-26</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="williamson" url="http://en.wikipedia.org/wiki/Roger_Williamson">
# 			<GivenName>Roger</GivenName>
# 			<FamilyName>Williamson</FamilyName>
# 			<DateOfBirth>1948-02-02</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="wilson" url="http://en.wikipedia.org/wiki/Justin_Wilson_(racing_driver)">
# 			<GivenName>Justin</GivenName>
# 			<FamilyName>Wilson</FamilyName>
# 			<DateOfBirth>1978-07-31</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="desire_wilson" url="http://en.wikipedia.org/wiki/Desir%C3%A9_Wilson">
# 			<GivenName>Desiré</GivenName>
# 			<FamilyName>Wilson</FamilyName>
# 			<DateOfBirth>1953-11-26</DateOfBirth>
# 			<Nationality>South African</Nationality>
# 		</Driver>
# 		<Driver driverId="vic_wilson" url="http://en.wikipedia.org/wiki/Vic_Wilson_(motor_racing_driver)">
# 			<GivenName>Vic</GivenName>
# 			<FamilyName>Wilson</FamilyName>
# 			<DateOfBirth>1931-04-14</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="dempsey_wilson" url="http://en.wikipedia.org/wiki/Dempsey_Wilson">
# 			<GivenName>Dempsey</GivenName>
# 			<FamilyName>Wilson</FamilyName>
# 			<DateOfBirth>1927-03-11</DateOfBirth>
# 			<Nationality>American</Nationality>
# 		</Driver>
# 		<Driver driverId="markus_winkelhock" code="WIN" url="http://en.wikipedia.org/wiki/Markus_Winkelhock">
# 			<GivenName>Markus</GivenName>
# 			<FamilyName>Winkelhock</FamilyName>
# 			<DateOfBirth>1980-06-13</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="joachim_winkelhock" url="http://en.wikipedia.org/wiki/Joachim_Winkelhock">
# 			<GivenName>Joachim</GivenName>
# 			<FamilyName>Winkelhock</FamilyName>
# 			<DateOfBirth>1960-10-24</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="manfred_winkelhock" url="http://en.wikipedia.org/wiki/Manfred_Winkelhock">
# 			<GivenName>Manfred</GivenName>
# 			<FamilyName>Winkelhock</FamilyName>
# 			<DateOfBirth>1951-10-06</DateOfBirth>
# 			<Nationality>German</Nationality>
# 		</Driver>
# 		<Driver driverId="wisell" url="http://en.wikipedia.org/wiki/Reine_Wisell">
# 			<GivenName>Reine</GivenName>
# 			<FamilyName>Wisell</FamilyName>
# 			<DateOfBirth>1941-09-30</DateOfBirth>
# 			<Nationality>Swedish</Nationality>
# 		</Driver>
# 		<Driver driverId="wunderink" url="http://en.wikipedia.org/wiki/Roelof_Wunderink">
# 			<GivenName>Roelof</GivenName>
# 			<FamilyName>Wunderink</FamilyName>
# 			<DateOfBirth>1948-12-12</DateOfBirth>
# 			<Nationality>Dutch</Nationality>
# 		</Driver>
# 		<Driver driverId="wurz" code="WUR" url="http://en.wikipedia.org/wiki/Alexander_Wurz">
# 			<GivenName>Alexander</GivenName>
# 			<FamilyName>Wurz</FamilyName>
# 			<DateOfBirth>1974-02-15</DateOfBirth>
# 			<Nationality>Austrian</Nationality>
# 		</Driver>
# 		<Driver driverId="yamamoto" code="YAM" url="http://en.wikipedia.org/wiki/Sakon_Yamamoto">
# 			<GivenName>Sakon</GivenName>
# 			<FamilyName>Yamamoto</FamilyName>
# 			<DateOfBirth>1982-07-09</DateOfBirth>
# 			<Nationality>Japanese</Nationality>
# 		</Driver>
# 		<Driver driverId="yoong" url="http://en.wikipedia.org/wiki/Alex_Yoong">
# 			<GivenName>Alex</GivenName>
# 			<FamilyName>Yoong</FamilyName>
# 			<DateOfBirth>1976-07-20</DateOfBirth>
# 			<Nationality>Malaysian</Nationality>
# 		</Driver>
# 		<Driver driverId="zanardi" url="http://en.wikipedia.org/wiki/Alex_Zanardi">
# 			<GivenName>Alessandro</GivenName>
# 			<FamilyName>Zanardi</FamilyName>
# 			<DateOfBirth>1966-10-23</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="zapico" url="http://en.wikipedia.org/wiki/Emilio_Zapico">
# 			<GivenName>Emilio</GivenName>
# 			<FamilyName>Zapico</FamilyName>
# 			<DateOfBirth>1944-05-27</DateOfBirth>
# 			<Nationality>Spanish</Nationality>
# 		</Driver>
# 		<Driver driverId="zonta" code="ZON" url="http://en.wikipedia.org/wiki/Ricardo_Zonta">
# 			<GivenName>Ricardo</GivenName>
# 			<FamilyName>Zonta</FamilyName>
# 			<DateOfBirth>1976-03-23</DateOfBirth>
# 			<Nationality>Brazilian</Nationality>
# 		</Driver>
# 		<Driver driverId="zorzi" url="http://en.wikipedia.org/wiki/Renzo_Zorzi">
# 			<GivenName>Renzo</GivenName>
# 			<FamilyName>Zorzi</FamilyName>
# 			<DateOfBirth>1946-12-12</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="zunino" url="http://en.wikipedia.org/wiki/Ricardo_Zunino">
# 			<GivenName>Ricardo</GivenName>
# 			<FamilyName>Zunino</FamilyName>
# 			<DateOfBirth>1949-04-13</DateOfBirth>
# 			<Nationality>Argentine</Nationality>
# 		</Driver>
# 	</DriverTable>
# </MRData>

# %%
import xmltodict

# %%
import json

# %%
db=json.dumps(xmltodict.parse(response.text))

# %%
db = eval(db)

# %%
db['MRData']
# Out:
# {'@xmlns': 'http://ergast.com/mrd/1.4',
#  '@series': 'f1',
#  '@url': 'http://ergast.com/api/f1/drivers',
#  '@limit': '1000',
#  '@offset': '20',
#  '@total': '853',
#  'DriverTable': {'Driver': [{'@driverId': 'amon',
#     '@url': 'http://en.wikipedia.org/wiki/Chris_Amon',
#     'GivenName': 'Chris',
#     'FamilyName': 'Amon',
#     'DateOfBirth': '1943-07-20',
#     'Nationality': 'New Zealander'},
#    {'@driverId': 'anderson',
#     '@url': 'http://en.wikipedia.org/wiki/Bob_Anderson_(racing_driver)',
#     'GivenName': 'Bob',
#     'FamilyName': 'Anderson',
#     'DateOfBirth': '1931-05-19',
#     'Nationality': 'British'},
#    {'@driverId': 'andersson',
#     '@url': 'http://en.wikipedia.org/wiki/Conny_Andersson_(racing_driver)',
#     'GivenName': 'Conny',
#     'FamilyName': 'Andersson',
#     'DateOfBirth': '1939-12-28',
#     'Nationality': 'Swedish'},
#    {'@driverId': 'andretti',
#     '@url': 'http://en.wikipedia.org/wiki/Michael_Andretti',
#     'GivenName': 'Michael',
#     'FamilyName': 'Andretti',
#     'DateOfBirth': '1962-10-05',
#     'Nationality': 'American'},
#    {'@driverId': 'mario_andretti',
#     '@url': 'http://en.wikipedia.org/wiki/Mario_Andretti',
#     'GivenName': 'Mario',
#     'FamilyName': 'Andretti',
#     'DateOfBirth': '1940-02-28',
#     'Nationality': 'American'},
#    {'@driverId': 'andrews',
#     '@url': 'http://en.wikipedia.org/wiki/Keith_Andrews_(driver)',
#     'GivenName': 'Keith',
#     'FamilyName': 'Andrews',
#     'DateOfBirth': '1920-06-15',
#     'Nationality': 'American'},
#    {'@driverId': 'apicella',
#     '@url': 'http://en.wikipedia.org/wiki/Marco_Apicella',
#     'GivenName': 'Marco',
#     'FamilyName': 'Apicella',
#     'DateOfBirth': '1965-10-07',
#     'Nationality': 'Italian'},
#    {'@driverId': 'armi',
#     '@url': 'http://en.wikipedia.org/wiki/Frank_Armi',
#     'GivenName': 'Frank',
#     'FamilyName': 'Armi',
#     'DateOfBirth': '1918-10-12',
#     'Nationality': 'American'},
#    {'@driverId': 'arnold',
#     '@url': 'http://en.wikipedia.org/wiki/Chuck_Arnold',
#     'GivenName': 'Chuck',
#     'FamilyName': 'Arnold',
#     'DateOfBirth': '1926-05-30',
#     'Nationality': 'American'},
#    {'@driverId': 'arnoux',
#     '@url': 'http://en.wikipedia.org/wiki/Ren%C3%A9_Arnoux',
#     'GivenName': 'René',
#     'FamilyName': 'Arnoux',
#     'DateOfBirth': '1948-07-04',
#     'Nationality': 'French'},
#    {'@driverId': 'arundell',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Arundell',
#     'GivenName': 'Peter',
#     'FamilyName': 'Arundell',
#     'DateOfBirth': '1933-11-08',
#     'Nationality': 'British'},
#    {'@driverId': 'ascari',
#     '@url': 'http://en.wikipedia.org/wiki/Alberto_Ascari',
#     'GivenName': 'Alberto',
#     'FamilyName': 'Ascari',
#     'DateOfBirth': '1918-07-13',
#     'Nationality': 'Italian'},
#    {'@driverId': 'ashdown',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Ashdown',
#     'GivenName': 'Peter',
#     'FamilyName': 'Ashdown',
#     'DateOfBirth': '1934-10-16',
#     'Nationality': 'British'},
#    {'@driverId': 'ashley',
#     '@url': 'http://en.wikipedia.org/wiki/Ian_Ashley',
#     'GivenName': 'Ian',
#     'FamilyName': 'Ashley',
#     'DateOfBirth': '1947-10-26',
#     'Nationality': 'British'},
#    {'@driverId': 'ashmore',
#     '@url': 'http://en.wikipedia.org/wiki/Gerry_Ashmore',
#     'GivenName': 'Gerry',
#     'FamilyName': 'Ashmore',
#     'DateOfBirth': '1936-07-25',
#     'Nationality': 'British'},
#    {'@driverId': 'aston',
#     '@url': 'http://en.wikipedia.org/wiki/Bill_Aston',
#     'GivenName': 'Bill',
#     'FamilyName': 'Aston',
#     'DateOfBirth': '1900-03-29',
#     'Nationality': 'British'},
#    {'@driverId': 'attwood',
#     '@url': 'http://en.wikipedia.org/wiki/Richard_Attwood',
#     'GivenName': 'Richard',
#     'FamilyName': 'Attwood',
#     'DateOfBirth': '1940-04-04',
#     'Nationality': 'British'},
#    {'@driverId': 'ayulo',
#     '@url': 'http://en.wikipedia.org/wiki/Manny_Ayulo',
#     'GivenName': 'Manny',
#     'FamilyName': 'Ayulo',
#     'DateOfBirth': '1921-10-20',
#     'Nationality': 'American'},
#    {'@driverId': 'badoer',
#     '@code': 'BAD',
#     '@url': 'http://en.wikipedia.org/wiki/Luca_Badoer',
#     'GivenName': 'Luca',
#     'FamilyName': 'Badoer',
#     'DateOfBirth': '1971-01-25',
#     'Nationality': 'Italian'},
#    {'@driverId': 'baghetti',
#     '@url': 'http://en.wikipedia.org/wiki/Giancarlo_Baghetti',
#     'GivenName': 'Giancarlo',
#     'FamilyName': 'Baghetti',
#     'DateOfBirth': '1934-12-25',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bailey',
#     '@url': 'http://en.wikipedia.org/wiki/Julian_Bailey',
#     'GivenName': 'Julian',
#     'FamilyName': 'Bailey',
#     'DateOfBirth': '1961-10-09',
#     'Nationality': 'British'},
#    {'@driverId': 'baldi',
#     '@url': 'http://en.wikipedia.org/wiki/Mauro_Baldi',
#     'GivenName': 'Mauro',
#     'FamilyName': 'Baldi',
#     'DateOfBirth': '1954-01-31',
#     'Nationality': 'Italian'},
#    {'@driverId': 'ball',
#     '@url': 'http://en.wikipedia.org/wiki/Bobby_Ball_(auto_racer)',
#     'GivenName': 'Bobby',
#     'FamilyName': 'Ball',
#     'DateOfBirth': '1925-08-26',
#     'Nationality': 'American'},
#    {'@driverId': 'balsa',
#     '@url': 'http://en.wikipedia.org/wiki/Marcel_Balsa',
#     'GivenName': 'Marcel',
#     'FamilyName': 'Balsa',
#     'DateOfBirth': '1909-01-01',
#     'Nationality': 'French'},
#    {'@driverId': 'bandini',
#     '@url': 'http://en.wikipedia.org/wiki/Lorenzo_Bandini',
#     'GivenName': 'Lorenzo',
#     'FamilyName': 'Bandini',
#     'DateOfBirth': '1935-12-21',
#     'Nationality': 'Italian'},
#    {'@driverId': 'banks',
#     '@url': 'http://en.wikipedia.org/wiki/Henry_Banks',
#     'GivenName': 'Henry',
#     'FamilyName': 'Banks',
#     'DateOfBirth': '1913-06-14',
#     'Nationality': 'American'},
#    {'@driverId': 'barbazza',
#     '@url': 'http://en.wikipedia.org/wiki/Fabrizio_Barbazza',
#     'GivenName': 'Fabrizio',
#     'FamilyName': 'Barbazza',
#     'DateOfBirth': '1963-04-02',
#     'Nationality': 'Italian'},
#    {'@driverId': 'barber',
#     '@url': 'http://en.wikipedia.org/wiki/Skip_Barber',
#     'GivenName': 'Skip',
#     'FamilyName': 'Barber',
#     'DateOfBirth': '1936-11-16',
#     'Nationality': 'American'},
#    {'@driverId': 'john_barber',
#     '@url': 'http://en.wikipedia.org/wiki/John_Barber_(racing_driver)',
#     'GivenName': 'John',
#     'FamilyName': 'Barber',
#     'DateOfBirth': '1929-07-22',
#     'Nationality': 'British'},
#    {'@driverId': 'barilla',
#     '@url': 'http://en.wikipedia.org/wiki/Paolo_Barilla',
#     'GivenName': 'Paolo',
#     'FamilyName': 'Barilla',
#     'DateOfBirth': '1961-04-20',
#     'Nationality': 'Italian'},
#    {'@driverId': 'barrichello',
#     '@code': 'BAR',
#     '@url': 'http://en.wikipedia.org/wiki/Rubens_Barrichello',
#     'GivenName': 'Rubens',
#     'FamilyName': 'Barrichello',
#     'DateOfBirth': '1972-05-23',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'bartels',
#     '@url': 'http://en.wikipedia.org/wiki/Michael_Bartels',
#     'GivenName': 'Michael',
#     'FamilyName': 'Bartels',
#     'DateOfBirth': '1968-03-08',
#     'Nationality': 'German'},
#    {'@driverId': 'barth',
#     '@url': 'http://en.wikipedia.org/wiki/Edgar_Barth',
#     'GivenName': 'Edgar',
#     'FamilyName': 'Barth',
#     'DateOfBirth': '1917-01-26',
#     'Nationality': 'German'},
#    {'@driverId': 'bassi',
#     '@url': 'http://en.wikipedia.org/wiki/Giorgio_Bassi',
#     'GivenName': 'Giorgio',
#     'FamilyName': 'Bassi',
#     'DateOfBirth': '1934-01-20',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bauer',
#     '@url': 'http://en.wikipedia.org/wiki/Erwin_Bauer',
#     'GivenName': 'Erwin',
#     'FamilyName': 'Bauer',
#     'DateOfBirth': '1912-07-17',
#     'Nationality': 'German'},
#    {'@driverId': 'baumgartner',
#     '@url': 'http://en.wikipedia.org/wiki/Zsolt_Baumgartner',
#     'GivenName': 'Zsolt',
#     'FamilyName': 'Baumgartner',
#     'DateOfBirth': '1981-01-01',
#     'Nationality': 'Hungarian'},
#    {'@driverId': 'bayol',
#     '@url': 'http://en.wikipedia.org/wiki/%C3%89lie_Bayol',
#     'GivenName': 'Élie',
#     'FamilyName': 'Bayol',
#     'DateOfBirth': '1914-02-28',
#     'Nationality': 'French'},
#    {'@driverId': 'beauman',
#     '@url': 'http://en.wikipedia.org/wiki/Don_Beauman',
#     'GivenName': 'Don',
#     'FamilyName': 'Beauman',
#     'DateOfBirth': '1928-07-26',
#     'Nationality': 'British'},
#    {'@driverId': 'bechem',
#     '@url': 'http://en.wikipedia.org/wiki/G%C3%BCnther_Bechem',
#     'GivenName': 'Günther',
#     'FamilyName': 'Bechem',
#     'DateOfBirth': '1921-12-21',
#     'Nationality': 'German'},
#    {'@driverId': 'behra',
#     '@url': 'http://en.wikipedia.org/wiki/Jean_Behra',
#     'GivenName': 'Jean',
#     'FamilyName': 'Behra',
#     'DateOfBirth': '1921-02-16',
#     'Nationality': 'French'},
#    {'@driverId': 'bell',
#     '@url': 'http://en.wikipedia.org/wiki/Derek_Bell_(auto_racer)',
#     'GivenName': 'Derek',
#     'FamilyName': 'Bell',
#     'DateOfBirth': '1941-10-31',
#     'Nationality': 'British'},
#    {'@driverId': 'bellof',
#     '@url': 'http://en.wikipedia.org/wiki/Stefan_Bellof',
#     'GivenName': 'Stefan',
#     'FamilyName': 'Bellof',
#     'DateOfBirth': '1957-11-20',
#     'Nationality': 'German'},
#    {'@driverId': 'belmondo',
#     '@url': 'http://en.wikipedia.org/wiki/Paul_Belmondo',
#     'GivenName': 'Paul',
#     'FamilyName': 'Belmondo',
#     'DateOfBirth': '1963-04-23',
#     'Nationality': 'French'},
#    {'@driverId': 'belso',
#     '@url': 'http://en.wikipedia.org/wiki/Tom_Bels%C3%B8',
#     'GivenName': 'Tom',
#     'FamilyName': 'Belsø',
#     'DateOfBirth': '1942-08-27',
#     'Nationality': 'Danish'},
#    {'@driverId': 'beltoise',
#     '@url': 'http://en.wikipedia.org/wiki/Jean-Pierre_Beltoise',
#     'GivenName': 'Jean-Pierre',
#     'FamilyName': 'Beltoise',
#     'DateOfBirth': '1937-04-26',
#     'Nationality': 'French'},
#    {'@driverId': 'beretta',
#     '@url': 'http://en.wikipedia.org/wiki/Olivier_Beretta',
#     'GivenName': 'Olivier',
#     'FamilyName': 'Beretta',
#     'DateOfBirth': '1969-11-23',
#     'Nationality': 'Monegasque'},
#    {'@driverId': 'berg',
#     '@url': 'http://en.wikipedia.org/wiki/Allen_Berg',
#     'GivenName': 'Allen',
#     'FamilyName': 'Berg',
#     'DateOfBirth': '1961-08-01',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'berger',
#     '@url': 'http://en.wikipedia.org/wiki/Gerhard_Berger',
#     'GivenName': 'Gerhard',
#     'FamilyName': 'Berger',
#     'DateOfBirth': '1959-08-27',
#     'Nationality': 'Austrian'},
#    {'@driverId': 'georges_berger',
#     '@url': 'http://en.wikipedia.org/wiki/Georges_Berger',
#     'GivenName': 'Georges',
#     'FamilyName': 'Berger',
#     'DateOfBirth': '1918-09-14',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'bernard',
#     '@url': 'http://en.wikipedia.org/wiki/%C3%89ric_Bernard',
#     'GivenName': 'Éric',
#     'FamilyName': 'Bernard',
#     'DateOfBirth': '1964-08-24',
#     'Nationality': 'French'},
#    {'@driverId': 'bernoldi',
#     '@url': 'http://en.wikipedia.org/wiki/Enrique_Bernoldi',
#     'GivenName': 'Enrique',
#     'FamilyName': 'Bernoldi',
#     'DateOfBirth': '1978-10-19',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'bertaggia',
#     '@url': 'http://en.wikipedia.org/wiki/Enrico_Bertaggia',
#     'GivenName': 'Enrico',
#     'FamilyName': 'Bertaggia',
#     'DateOfBirth': '1964-09-19',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bettenhausen',
#     '@url': 'http://en.wikipedia.org/wiki/Tony_Bettenhausen',
#     'GivenName': 'Tony',
#     'FamilyName': 'Bettenhausen',
#     'DateOfBirth': '1916-09-12',
#     'Nationality': 'American'},
#    {'@driverId': 'beuttler',
#     '@url': 'http://en.wikipedia.org/wiki/Mike_Beuttler',
#     'GivenName': 'Mike',
#     'FamilyName': 'Beuttler',
#     'DateOfBirth': '1940-04-13',
#     'Nationality': 'British'},
#    {'@driverId': 'bianchi',
#     '@code': 'BIA',
#     '@url': 'http://en.wikipedia.org/wiki/Lucien_Bianchi',
#     'GivenName': 'Lucien',
#     'FamilyName': 'Bianchi',
#     'DateOfBirth': '1934-11-10',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'jules_bianchi',
#     '@code': 'BIA',
#     '@url': 'http://en.wikipedia.org/wiki/Jules_Bianchi',
#     'PermanentNumber': '17',
#     'GivenName': 'Jules',
#     'FamilyName': 'Bianchi',
#     'DateOfBirth': '1989-08-03',
#     'Nationality': 'French'},
#    {'@driverId': 'bianco',
#     '@url': 'http://en.wikipedia.org/wiki/Gino_Bianco',
#     'GivenName': 'Gino',
#     'FamilyName': 'Bianco',
#     'DateOfBirth': '1916-07-22',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'binder',
#     '@url': 'http://en.wikipedia.org/wiki/Hans_Binder',
#     'GivenName': 'Hans',
#     'FamilyName': 'Binder',
#     'DateOfBirth': '1948-06-12',
#     'Nationality': 'Austrian'},
#    {'@driverId': 'biondetti',
#     '@url': 'http://en.wikipedia.org/wiki/Clemente_Biondetti',
#     'GivenName': 'Clemente',
#     'FamilyName': 'Biondetti',
#     'DateOfBirth': '1898-08-18',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bira',
#     '@url': 'http://en.wikipedia.org/wiki/Prince_Bira',
#     'GivenName': 'Prince',
#     'FamilyName': 'Bira',
#     'DateOfBirth': '1914-07-15',
#     'Nationality': 'Thai'},
#    {'@driverId': 'birger',
#     '@url': 'http://en.wikipedia.org/wiki/Pablo_Birger',
#     'GivenName': 'Pablo',
#     'FamilyName': 'Birger',
#     'DateOfBirth': '1924-01-07',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'bisch',
#     '@url': 'http://en.wikipedia.org/wiki/Art_Bisch',
#     'GivenName': 'Art',
#     'FamilyName': 'Bisch',
#     'DateOfBirth': '1926-11-10',
#     'Nationality': 'American'},
#    {'@driverId': 'blanchard',
#     '@url': 'http://en.wikipedia.org/wiki/Harry_Blanchard',
#     'GivenName': 'Harry',
#     'FamilyName': 'Blanchard',
#     'DateOfBirth': '1929-06-13',
#     'Nationality': 'American'},
#    {'@driverId': 'bleekemolen',
#     '@url': 'http://en.wikipedia.org/wiki/Michael_Bleekemolen',
#     'GivenName': 'Michael',
#     'FamilyName': 'Bleekemolen',
#     'DateOfBirth': '1949-10-02',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'blignaut',
#     '@url': 'http://en.wikipedia.org/wiki/Alex_Blignaut',
#     'GivenName': 'Alex',
#     'FamilyName': 'Blignaut',
#     'DateOfBirth': '1932-11-30',
#     'Nationality': 'South African'},
#    {'@driverId': 'blokdyk',
#     '@url': 'http://en.wikipedia.org/wiki/Trevor_Blokdyk',
#     'GivenName': 'Trevor',
#     'FamilyName': 'Blokdyk',
#     'DateOfBirth': '1935-11-30',
#     'Nationality': 'South African'},
#    {'@driverId': 'blundell',
#     '@url': 'http://en.wikipedia.org/wiki/Mark_Blundell',
#     'GivenName': 'Mark',
#     'FamilyName': 'Blundell',
#     'DateOfBirth': '1966-04-08',
#     'Nationality': 'British'},
#    {'@driverId': 'boesel',
#     '@url': 'http://en.wikipedia.org/wiki/Raul_Boesel',
#     'GivenName': 'Raul',
#     'FamilyName': 'Boesel',
#     'DateOfBirth': '1957-12-04',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'boffa',
#     '@url': 'http://en.wikipedia.org/wiki/Menato_Boffa',
#     'GivenName': 'Menato',
#     'FamilyName': 'Boffa',
#     'DateOfBirth': '1930-01-04',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bondurant',
#     '@url': 'http://en.wikipedia.org/wiki/Bob_Bondurant',
#     'GivenName': 'Bob',
#     'FamilyName': 'Bondurant',
#     'DateOfBirth': '1933-04-27',
#     'Nationality': 'American'},
#    {'@driverId': 'bonetto',
#     '@url': 'http://en.wikipedia.org/wiki/Felice_Bonetto',
#     'GivenName': 'Felice',
#     'FamilyName': 'Bonetto',
#     'DateOfBirth': '1903-06-09',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bonnier',
#     '@url': 'http://en.wikipedia.org/wiki/Joakim_Bonnier',
#     'GivenName': 'Jo',
#     'FamilyName': 'Bonnier',
#     'DateOfBirth': '1930-01-31',
#     'Nationality': 'Swedish'},
#    {'@driverId': 'bonomi',
#     '@url': 'http://en.wikipedia.org/wiki/Roberto_Bonomi',
#     'GivenName': 'Roberto',
#     'FamilyName': 'Bonomi',
#     'DateOfBirth': '1919-09-30',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'bordeu',
#     '@url': 'http://en.wikipedia.org/wiki/Juan_Manuel_Bordeu',
#     'GivenName': 'Juan Manuel',
#     'FamilyName': 'Bordeu',
#     'DateOfBirth': '1934-01-28',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'borgudd',
#     '@url': 'http://en.wikipedia.org/wiki/Slim_Borgudd',
#     'GivenName': 'Slim',
#     'FamilyName': 'Borgudd',
#     'DateOfBirth': '1946-11-25',
#     'Nationality': 'Swedish'},
#    {'@driverId': 'botha',
#     '@url': 'http://en.wikipedia.org/wiki/Luki_Botha',
#     'GivenName': 'Luki',
#     'FamilyName': 'Botha',
#     'DateOfBirth': '1930-01-16',
#     'Nationality': 'South African'},
#    {'@driverId': 'bottas',
#     '@code': 'BOT',
#     '@url': 'http://en.wikipedia.org/wiki/Valtteri_Bottas',
#     'PermanentNumber': '77',
#     'GivenName': 'Valtteri',
#     'FamilyName': 'Bottas',
#     'DateOfBirth': '1989-08-28',
#     'Nationality': 'Finnish'},
#    {'@driverId': 'boullion',
#     '@url': 'http://en.wikipedia.org/wiki/Jean-Christophe_Boullion',
#     'GivenName': 'Jean-Christophe',
#     'FamilyName': 'Boullion',
#     'DateOfBirth': '1969-12-27',
#     'Nationality': 'French'},
#    {'@driverId': 'bourdais',
#     '@code': 'BOU',
#     '@url': 'http://en.wikipedia.org/wiki/S%C3%A9bastien_Bourdais',
#     'GivenName': 'Sébastien',
#     'FamilyName': 'Bourdais',
#     'DateOfBirth': '1979-02-28',
#     'Nationality': 'French'},
#    {'@driverId': 'boutsen',
#     '@url': 'http://en.wikipedia.org/wiki/Thierry_Boutsen',
#     'GivenName': 'Thierry',
#     'FamilyName': 'Boutsen',
#     'DateOfBirth': '1957-07-13',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'boyd',
#     '@url': 'http://en.wikipedia.org/wiki/Johnny_Boyd',
#     'GivenName': 'Johnny',
#     'FamilyName': 'Boyd',
#     'DateOfBirth': '1926-08-19',
#     'Nationality': 'American'},
#    {'@driverId': 'brabham',
#     '@url': 'http://en.wikipedia.org/wiki/David_Brabham',
#     'GivenName': 'David',
#     'FamilyName': 'Brabham',
#     'DateOfBirth': '1965-09-05',
#     'Nationality': 'Australian'},
#    {'@driverId': 'gary_brabham',
#     '@url': 'http://en.wikipedia.org/wiki/Gary_Brabham',
#     'GivenName': 'Gary',
#     'FamilyName': 'Brabham',
#     'DateOfBirth': '1961-03-29',
#     'Nationality': 'Australian'},
#    {'@driverId': 'jack_brabham',
#     '@url': 'http://en.wikipedia.org/wiki/Jack_Brabham',
#     'GivenName': 'Jack',
#     'FamilyName': 'Brabham',
#     'DateOfBirth': '1926-04-02',
#     'Nationality': 'Australian'},
#    {'@driverId': 'brack',
#     '@url': 'http://en.wikipedia.org/wiki/Bill_Brack',
#     'GivenName': 'Bill',
#     'FamilyName': 'Brack',
#     'DateOfBirth': '1935-12-26',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'brambilla',
#     '@url': 'http://en.wikipedia.org/wiki/Vittorio_Brambilla',
#     'GivenName': 'Vittorio',
#     'FamilyName': 'Brambilla',
#     'DateOfBirth': '1937-11-11',
#     'Nationality': 'Italian'},
#    {'@driverId': 'ernesto_brambilla',
#     '@url': 'http://en.wikipedia.org/wiki/Ernesto_Brambilla',
#     'GivenName': 'Ernesto',
#     'FamilyName': 'Brambilla',
#     'DateOfBirth': '1934-01-31',
#     'Nationality': 'Italian'},
#    {'@driverId': 'branca',
#     '@url': 'http://en.wikipedia.org/wiki/Toni_Branca',
#     'GivenName': 'Toni',
#     'FamilyName': 'Branca',
#     'DateOfBirth': '1916-09-15',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'brancatelli',
#     '@url': 'http://en.wikipedia.org/wiki/Gianfranco_Brancatelli',
#     'GivenName': 'Gianfranco',
#     'FamilyName': 'Brancatelli',
#     'DateOfBirth': '1950-01-18',
#     'Nationality': 'Italian'},
#    {'@driverId': 'brandon',
#     '@url': 'http://en.wikipedia.org/wiki/Eric_Brandon',
#     'GivenName': 'Eric',
#     'FamilyName': 'Brandon',
#     'DateOfBirth': '1920-07-18',
#     'Nationality': 'British'},
#    {'@driverId': 'branson',
#     '@url': 'http://en.wikipedia.org/wiki/Don_Branson',
#     'GivenName': 'Don',
#     'FamilyName': 'Branson',
#     'DateOfBirth': '1920-06-02',
#     'Nationality': 'American'},
#    {'@driverId': 'bridger',
#     '@url': 'http://en.wikipedia.org/wiki/Tom_Bridger',
#     'GivenName': 'Tom',
#     'FamilyName': 'Bridger',
#     'DateOfBirth': '1934-06-24',
#     'Nationality': 'British'},
#    {'@driverId': 'brise',
#     '@url': 'http://en.wikipedia.org/wiki/Tony_Brise',
#     'GivenName': 'Tony',
#     'FamilyName': 'Brise',
#     'DateOfBirth': '1952-03-28',
#     'Nationality': 'British'},
#    {'@driverId': 'bristow',
#     '@url': 'http://en.wikipedia.org/wiki/Chris_Bristow',
#     'GivenName': 'Chris',
#     'FamilyName': 'Bristow',
#     'DateOfBirth': '1937-12-02',
#     'Nationality': 'British'},
#    {'@driverId': 'broeker',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Broeker',
#     'GivenName': 'Peter',
#     'FamilyName': 'Broeker',
#     'DateOfBirth': '1926-05-15',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'brooks',
#     '@url': 'http://en.wikipedia.org/wiki/Tony_Brooks',
#     'GivenName': 'Tony',
#     'FamilyName': 'Brooks',
#     'DateOfBirth': '1932-02-25',
#     'Nationality': 'British'},
#    {'@driverId': 'brown',
#     '@url': 'http://en.wikipedia.org/wiki/Warwick_Brown',
#     'GivenName': 'Warwick',
#     'FamilyName': 'Brown',
#     'DateOfBirth': '1949-12-24',
#     'Nationality': 'Australian'},
#    {'@driverId': 'alan_brown',
#     '@url': 'http://en.wikipedia.org/wiki/Alan_Brown_(racing_driver)',
#     'GivenName': 'Alan',
#     'FamilyName': 'Brown',
#     'DateOfBirth': '1919-11-20',
#     'Nationality': 'British'},
#    {'@driverId': 'walt_brown',
#     '@url': 'http://en.wikipedia.org/wiki/Walt_Brown_(auto_racer)',
#     'GivenName': 'Walt',
#     'FamilyName': 'Brown',
#     'DateOfBirth': '1911-12-30',
#     'Nationality': 'American'},
#    {'@driverId': 'brudes',
#     '@url': 'http://en.wikipedia.org/wiki/Adolf_Brudes',
#     'GivenName': 'Adolf',
#     'FamilyName': 'Brudes',
#     'DateOfBirth': '1899-10-15',
#     'Nationality': 'German'},
#    {'@driverId': 'brundle',
#     '@url': 'http://en.wikipedia.org/wiki/Martin_Brundle',
#     'GivenName': 'Martin',
#     'FamilyName': 'Brundle',
#     'DateOfBirth': '1959-06-01',
#     'Nationality': 'British'},
#    {'@driverId': 'bruni',
#     '@url': 'http://en.wikipedia.org/wiki/Gianmaria_Bruni',
#     'GivenName': 'Gianmaria',
#     'FamilyName': 'Bruni',
#     'DateOfBirth': '1981-05-30',
#     'Nationality': 'Italian'},
#    {'@driverId': 'bryan',
#     '@url': 'http://en.wikipedia.org/wiki/Jimmy_Bryan',
#     'GivenName': 'Jimmy',
#     'FamilyName': 'Bryan',
#     'DateOfBirth': '1926-01-28',
#     'Nationality': 'American'},
#    {'@driverId': 'bucci',
#     '@url': 'http://en.wikipedia.org/wiki/Clemar_Bucci',
#     'GivenName': 'Clemar',
#     'FamilyName': 'Bucci',
#     'DateOfBirth': '1920-09-04',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'bucknum',
#     '@url': 'http://en.wikipedia.org/wiki/Ronnie_Bucknum',
#     'GivenName': 'Ronnie',
#     'FamilyName': 'Bucknum',
#     'DateOfBirth': '1936-04-05',
#     'Nationality': 'American'},
#    {'@driverId': 'bueb',
#     '@url': 'http://en.wikipedia.org/wiki/Ivor_Bueb',
#     'GivenName': 'Ivor',
#     'FamilyName': 'Bueb',
#     'DateOfBirth': '1923-06-06',
#     'Nationality': 'British'},
#    {'@driverId': 'buemi',
#     '@code': 'BUE',
#     '@url': 'http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi',
#     'GivenName': 'Sébastien',
#     'FamilyName': 'Buemi',
#     'DateOfBirth': '1988-10-31',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'bueno',
#     '@url': 'http://en.wikipedia.org/wiki/Luiz_Bueno',
#     'GivenName': 'Luiz',
#     'FamilyName': 'Bueno',
#     'DateOfBirth': '1937-01-16',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'burgess',
#     '@url': 'http://en.wikipedia.org/wiki/Ian_Burgess',
#     'GivenName': 'Ian',
#     'FamilyName': 'Burgess',
#     'DateOfBirth': '1930-07-06',
#     'Nationality': 'British'},
#    {'@driverId': 'burti',
#     '@url': 'http://en.wikipedia.org/wiki/Luciano_Burti',
#     'GivenName': 'Luciano',
#     'FamilyName': 'Burti',
#     'DateOfBirth': '1975-03-05',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'bussinello',
#     '@url': 'http://en.wikipedia.org/wiki/Roberto_Bussinello',
#     'GivenName': 'Roberto',
#     'FamilyName': 'Bussinello',
#     'DateOfBirth': '1927-10-04',
#     'Nationality': 'Italian'},
#    {'@driverId': 'button',
#     '@code': 'BUT',
#     '@url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#     'PermanentNumber': '22',
#     'GivenName': 'Jenson',
#     'FamilyName': 'Button',
#     'DateOfBirth': '1980-01-19',
#     'Nationality': 'British'},
#    {'@driverId': 'byrne',
#     '@url': 'http://en.wikipedia.org/wiki/Tommy_Byrne_%28racing_driver%29',
#     'GivenName': 'Tommy',
#     'FamilyName': 'Byrne',
#     'DateOfBirth': '1958-05-06',
#     'Nationality': 'Irish'},
#    {'@driverId': 'cabantous',
#     '@url': 'http://en.wikipedia.org/wiki/Yves_Giraud_Cabantous',
#     'GivenName': 'Yves',
#     'FamilyName': 'Cabantous',
#     'DateOfBirth': '1904-10-08',
#     'Nationality': 'French'},
#    {'@driverId': 'cabianca',
#     '@url': 'http://en.wikipedia.org/wiki/Giulio_Cabianca',
#     'GivenName': 'Giulio',
#     'FamilyName': 'Cabianca',
#     'DateOfBirth': '1923-02-19',
#     'Nationality': 'Italian'},
#    {'@driverId': 'cabral',
#     '@url': 'http://en.wikipedia.org/wiki/Mario_de_Araujo_Cabral',
#     'GivenName': 'Mário de Araújo',
#     'FamilyName': 'Cabral',
#     'DateOfBirth': '1934-01-15',
#     'Nationality': 'Portuguese'},
#    {'@driverId': 'cade',
#     '@url': 'http://en.wikipedia.org/wiki/Phil_Cade',
#     'GivenName': 'Phil',
#     'FamilyName': 'Cade',
#     'DateOfBirth': '1916-06-12',
#     'Nationality': 'American'},
#    {'@driverId': 'caffi',
#     '@url': 'http://en.wikipedia.org/wiki/Alex_Caffi',
#     'GivenName': 'Alex',
#     'FamilyName': 'Caffi',
#     'DateOfBirth': '1964-03-18',
#     'Nationality': 'Italian'},
#    {'@driverId': 'campbell-jones',
#     '@url': 'http://en.wikipedia.org/wiki/John_Campbell-Jones',
#     'GivenName': 'John',
#     'FamilyName': 'Campbell-Jones',
#     'DateOfBirth': '1930-01-21',
#     'Nationality': 'British'},
#    {'@driverId': 'campos',
#     '@url': 'http://en.wikipedia.org/wiki/Adri%C3%A1n_Campos',
#     'GivenName': 'Adrián',
#     'FamilyName': 'Campos',
#     'DateOfBirth': '1960-06-17',
#     'Nationality': 'Spanish'},
#    {'@driverId': 'Cannoc',
#     '@url': 'http://en.wikipedia.org/wiki/John_Cannon_(auto_racer)',
#     'GivenName': 'John',
#     'FamilyName': 'Cannon',
#     'DateOfBirth': '1933-06-21',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'cantoni',
#     '@url': 'http://en.wikipedia.org/wiki/Eitel_Cantoni',
#     'GivenName': 'Eitel',
#     'FamilyName': 'Cantoni',
#     'DateOfBirth': '1906-10-04',
#     'Nationality': 'Uruguayan'},
#    {'@driverId': 'cantrell',
#     '@url': 'http://en.wikipedia.org/wiki/William_Cantrell',
#     'GivenName': 'Bill',
#     'FamilyName': 'Cantrell',
#     'DateOfBirth': '1908-01-31',
#     'Nationality': 'American'},
#    {'@driverId': 'capelli',
#     '@url': 'http://en.wikipedia.org/wiki/Ivan_Capelli',
#     'GivenName': 'Ivan',
#     'FamilyName': 'Capelli',
#     'DateOfBirth': '1963-05-24',
#     'Nationality': 'Italian'},
#    {'@driverId': 'carini',
#     '@url': 'http://en.wikipedia.org/wiki/Piero_Carini',
#     'GivenName': 'Piero',
#     'FamilyName': 'Carini',
#     'DateOfBirth': '1921-03-06',
#     'Nationality': 'Italian'},
#    {'@driverId': 'darter',
#     '@url': 'http://en.wikipedia.org/wiki/Duane_Carter',
#     'GivenName': 'Duane',
#     'FamilyName': 'Carter',
#     'DateOfBirth': '1913-05-05',
#     'Nationality': 'American'},
#    {'@driverId': 'castellotti',
#     '@url': 'http://en.wikipedia.org/wiki/Eugenio_Castellotti',
#     'GivenName': 'Eugenio',
#     'FamilyName': 'Castellotti',
#     'DateOfBirth': '1930-10-10',
#     'Nationality': 'Italian'},
#    {'@driverId': 'cecotto',
#     '@url': 'http://en.wikipedia.org/wiki/Johnny_Cecotto',
#     'GivenName': 'Johnny',
#     'FamilyName': 'Cecotto',
#     'DateOfBirth': '1956-01-25',
#     'Nationality': 'Venezuelan'},
#    {'@driverId': 'cevert',
#     '@url': 'http://en.wikipedia.org/wiki/Fran%C3%A7ois_Cevert',
#     'GivenName': 'François',
#     'FamilyName': 'Cevert',
#     'DateOfBirth': '1944-02-25',
#     'Nationality': 'French'},
#    {'@driverId': 'chaboud',
#     '@url': 'http://en.wikipedia.org/wiki/Eug%C3%A8ne_Chaboud',
#     'GivenName': 'Eugène',
#     'FamilyName': 'Chaboud',
#     'DateOfBirth': '1907-04-12',
#     'Nationality': 'French'},
#    {'@driverId': 'chamberlain',
#     '@url': 'http://en.wikipedia.org/wiki/Jay_Chamberlain',
#     'GivenName': 'Jay',
#     'FamilyName': 'Chamberlain',
#     'DateOfBirth': '1925-12-29',
#     'Nationality': 'American'},
#    {'@driverId': 'chandhok',
#     '@code': 'CHA',
#     '@url': 'http://en.wikipedia.org/wiki/Karun_Chandhok',
#     'GivenName': 'Karun',
#     'FamilyName': 'Chandhok',
#     'DateOfBirth': '1984-01-19',
#     'Nationality': 'Indian'},
#    {'@driverId': 'chapman',
#     '@url': 'http://en.wikipedia.org/wiki/Colin_Chapman',
#     'GivenName': 'Colin',
#     'FamilyName': 'Chapman',
#     'DateOfBirth': '1928-05-19',
#     'Nationality': 'British'},
#    {'@driverId': 'charlton',
#     '@url': 'http://en.wikipedia.org/wiki/Dave_Charlton',
#     'GivenName': 'Dave',
#     'FamilyName': 'Charlton',
#     'DateOfBirth': '1936-10-27',
#     'Nationality': 'South African'},
#    {'@driverId': 'chaves',
#     '@url': 'http://en.wikipedia.org/wiki/Pedro_Chaves',
#     'GivenName': 'Pedro',
#     'FamilyName': 'Chaves',
#     'DateOfBirth': '1965-02-27',
#     'Nationality': 'Portuguese'},
#    {'@driverId': 'cheesbourg',
#     '@url': 'http://en.wikipedia.org/wiki/Bill_Cheesbourg',
#     'GivenName': 'Bill',
#     'FamilyName': 'Cheesbourg',
#     'DateOfBirth': '1927-06-12',
#     'Nationality': 'American'},
#    {'@driverId': 'cheever',
#     '@url': 'http://en.wikipedia.org/wiki/Eddie_Cheever',
#     'GivenName': 'Eddie',
#     'FamilyName': 'Cheever',
#     'DateOfBirth': '1958-01-10',
#     'Nationality': 'American'},
#    {'@driverId': 'chiesa',
#     '@url': 'http://en.wikipedia.org/wiki/Andrea_Chiesa',
#     'GivenName': 'Andrea',
#     'FamilyName': 'Chiesa',
#     'DateOfBirth': '1964-05-06',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'chilton',
#     '@code': 'CHI',
#     '@url': 'http://en.wikipedia.org/wiki/Max_Chilton',
#     'PermanentNumber': '4',
#     'GivenName': 'Max',
#     'FamilyName': 'Chilton',
#     'DateOfBirth': '1991-04-21',
#     'Nationality': 'British'},
#    {'@driverId': 'chimeri',
#     '@url': 'http://en.wikipedia.org/wiki/Ettore_Chimeri',
#     'GivenName': 'Ettore',
#     'FamilyName': 'Chimeri',
#     'DateOfBirth': '1921-06-04',
#     'Nationality': 'Venezuelan'},
#    {'@driverId': 'chiron',
#     '@url': 'http://en.wikipedia.org/wiki/Louis_Chiron',
#     'GivenName': 'Louis',
#     'FamilyName': 'Chiron',
#     'DateOfBirth': '1899-08-03',
#     'Nationality': 'Monegasque'},
#    {'@driverId': 'chitwood',
#     '@url': 'http://en.wikipedia.org/wiki/Joie_Chitwood',
#     'GivenName': 'Joie',
#     'FamilyName': 'Chitwood',
#     'DateOfBirth': '1912-04-14',
#     'Nationality': 'American'},
#    {'@driverId': 'christie',
#     '@url': 'http://en.wikipedia.org/wiki/Bob_Christie_(racing_driver)',
#     'GivenName': 'Bob',
#     'FamilyName': 'Christie',
#     'DateOfBirth': '1924-04-04',
#     'Nationality': 'American'},
#    {'@driverId': 'claes',
#     '@url': 'http://en.wikipedia.org/wiki/Johnny_Claes',
#     'GivenName': 'Johnny',
#     'FamilyName': 'Claes',
#     'DateOfBirth': '1916-08-11',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'clapham',
#     '@url': 'http://en.wikipedia.org/wiki/David_Clapham',
#     'GivenName': 'David',
#     'FamilyName': 'Clapham',
#     'DateOfBirth': '1931-05-18',
#     'Nationality': 'South African'},
#    {'@driverId': 'clark',
#     '@url': 'http://en.wikipedia.org/wiki/Jim_Clark',
#     'GivenName': 'Jim',
#     'FamilyName': 'Clark',
#     'DateOfBirth': '1936-03-04',
#     'Nationality': 'British'},
#    {'@driverId': 'cogan',
#     '@url': 'http://en.wikipedia.org/wiki/Kevin_Cogan',
#     'GivenName': 'Kevin',
#     'FamilyName': 'Cogan',
#     'DateOfBirth': '1956-03-31',
#     'Nationality': 'American'},
#    {'@driverId': 'collins',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Collins_(racing_driver)',
#     'GivenName': 'Peter',
#     'FamilyName': 'Collins',
#     'DateOfBirth': '1931-11-06',
#     'Nationality': 'British'},
#    {'@driverId': 'collomb',
#     '@url': 'http://en.wikipedia.org/wiki/Bernard_Collomb',
#     'GivenName': 'Bernard',
#     'FamilyName': 'Collomb',
#     'DateOfBirth': '1930-10-07',
#     'Nationality': 'French'},
#    {'@driverId': 'colombo',
#     '@url': 'http://en.wikipedia.org/wiki/Alberto_Colombo',
#     'GivenName': 'Alberto',
#     'FamilyName': 'Colombo',
#     'DateOfBirth': '1946-02-23',
#     'Nationality': 'Italian'},
#    {'@driverId': 'comas',
#     '@url': 'http://en.wikipedia.org/wiki/%C3%89rik_Comas',
#     'GivenName': 'Érik',
#     'FamilyName': 'Comas',
#     'DateOfBirth': '1963-09-28',
#     'Nationality': 'French'},
#    {'@driverId': 'comotti',
#     '@url': 'http://en.wikipedia.org/wiki/Franco_Comotti',
#     'GivenName': 'Franco',
#     'FamilyName': 'Comotti',
#     'DateOfBirth': '1906-07-24',
#     'Nationality': 'Italian'},
#    {'@driverId': 'george_connor',
#     '@url': 'http://en.wikipedia.org/wiki/George_Connor_(driver)',
#     'GivenName': 'George',
#     'FamilyName': 'Connor',
#     'DateOfBirth': '1906-08-16',
#     'Nationality': 'American'},
#    {'@driverId': 'constantine',
#     '@url': 'http://en.wikipedia.org/wiki/George_Constantine',
#     'GivenName': 'George',
#     'FamilyName': 'Constantine',
#     'DateOfBirth': '1918-02-22',
#     'Nationality': 'American'},
#    {'@driverId': 'cordts',
#     '@url': 'http://en.wikipedia.org/wiki/John_Cordts',
#     'GivenName': 'John',
#     'FamilyName': 'Cordts',
#     'DateOfBirth': '1935-07-23',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'coulthard',
#     '@code': 'COU',
#     '@url': 'http://en.wikipedia.org/wiki/David_Coulthard',
#     'GivenName': 'David',
#     'FamilyName': 'Coulthard',
#     'DateOfBirth': '1971-03-27',
#     'Nationality': 'British'},
#    {'@driverId': 'courage',
#     '@url': 'http://en.wikipedia.org/wiki/Piers_Courage',
#     'GivenName': 'Piers',
#     'FamilyName': 'Courage',
#     'DateOfBirth': '1942-05-27',
#     'Nationality': 'British'},
#    {'@driverId': 'craft',
#     '@url': 'http://en.wikipedia.org/wiki/Chris_Craft_(racing_driver)',
#     'GivenName': 'Chris',
#     'FamilyName': 'Craft',
#     'DateOfBirth': '1939-11-17',
#     'Nationality': 'British'},
#    {'@driverId': 'crawford',
#     '@url': 'http://en.wikipedia.org/wiki/Jim_Crawford_(driver)',
#     'GivenName': 'Jim',
#     'FamilyName': 'Crawford',
#     'DateOfBirth': '1948-02-13',
#     'Nationality': 'British'},
#    {'@driverId': 'ray_crawford',
#     '@url': 'http://en.wikipedia.org/wiki/Ray_Crawford',
#     'GivenName': 'Ray',
#     'FamilyName': 'Crawford',
#     'DateOfBirth': '1915-10-26',
#     'Nationality': 'American'},
#    {'@driverId': 'crespo',
#     '@url': 'http://en.wikipedia.org/wiki/Alberto_Crespo',
#     'GivenName': 'Alberto',
#     'FamilyName': 'Crespo',
#     'DateOfBirth': '1920-01-16',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'creus',
#     '@url': 'http://en.wikipedia.org/wiki/Antonio_Creus',
#     'GivenName': 'Antonio',
#     'FamilyName': 'Creus',
#     'DateOfBirth': '1924-10-28',
#     'Nationality': 'Spanish'},
#    {'@driverId': 'crockett',
#     '@url': 'http://en.wikipedia.org/wiki/Larry_Crockett',
#     'GivenName': 'Larry',
#     'FamilyName': 'Crockett',
#     'DateOfBirth': '1926-10-23',
#     'Nationality': 'American'},
#    {'@driverId': 'crook',
#     '@url': 'http://en.wikipedia.org/wiki/Tony_Crook',
#     'GivenName': 'Tony',
#     'FamilyName': 'Crook',
#     'DateOfBirth': '1920-02-16',
#     'Nationality': 'British'},
#    {'@driverId': 'cross',
#     '@url': 'http://en.wikipedia.org/wiki/Art_Cross',
#     'GivenName': 'Art',
#     'FamilyName': 'Cross',
#     'DateOfBirth': '1918-01-24',
#     'Nationality': 'American'},
#    {'@driverId': 'crossley',
#     '@url': 'http://en.wikipedia.org/wiki/Geoff_Crossley',
#     'GivenName': 'Geoff',
#     'FamilyName': 'Crossley',
#     'DateOfBirth': '1921-05-11',
#     'Nationality': 'British'},
#    {'@driverId': 'cruz',
#     '@url': 'http://en.wikipedia.org/wiki/Adolfo_Schewelm_Cruz',
#     'GivenName': 'Adolfo',
#     'FamilyName': 'Cruz',
#     'DateOfBirth': '1923-06-28',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'ambrosio',
#     '@code': 'DAM',
#     '@url': 'http://en.wikipedia.org/wiki/J%C3%A9r%C3%B4me_d%27Ambrosio',
#     'GivenName': 'Jérôme',
#     'FamilyName': "d'Ambrosio",
#     'DateOfBirth': '1985-12-27',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'orey',
#     '@url': 'http://en.wikipedia.org/wiki/Fritz_d%27Orey',
#     'GivenName': 'Fritz',
#     'FamilyName': "d'Orey",
#     'DateOfBirth': '1938-03-25',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'matta',
#     '@url': 'http://en.wikipedia.org/wiki/Cristiano_da_Matta',
#     'GivenName': 'Cristiano',
#     'FamilyName': 'da Matta',
#     'DateOfBirth': '1973-09-19',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'ramos',
#     '@url': 'http://en.wikipedia.org/wiki/Hernando_da_Silva_Ramos',
#     'GivenName': 'Hernando',
#     'FamilyName': 'da Silva Ramos',
#     'DateOfBirth': '1925-12-07',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'daigh',
#     '@url': 'http://en.wikipedia.org/wiki/Chuck_Daigh',
#     'GivenName': 'Chuck',
#     'FamilyName': 'Daigh',
#     'DateOfBirth': '1923-11-29',
#     'Nationality': 'American'},
#    {'@driverId': 'dalmas',
#     '@url': 'http://en.wikipedia.org/wiki/Yannick_Dalmas',
#     'GivenName': 'Yannick',
#     'FamilyName': 'Dalmas',
#     'DateOfBirth': '1961-07-28',
#     'Nationality': 'French'},
#    {'@driverId': 'daly',
#     '@url': 'http://en.wikipedia.org/wiki/Derek_Daly',
#     'GivenName': 'Derek',
#     'FamilyName': 'Daly',
#     'DateOfBirth': '1953-03-11',
#     'Nationality': 'Irish'},
#    {'@driverId': 'danner',
#     '@url': 'http://en.wikipedia.org/wiki/Christian_Danner',
#     'GivenName': 'Christian',
#     'FamilyName': 'Danner',
#     'DateOfBirth': '1958-04-04',
#     'Nationality': 'German'},
#    {'@driverId': 'daponte',
#     '@url': 'http://en.wikipedia.org/wiki/Jorge_Daponte',
#     'GivenName': 'Jorge',
#     'FamilyName': 'Daponte',
#     'DateOfBirth': '1923-06-05',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'davidson',
#     '@code': 'DAV',
#     '@url': 'http://en.wikipedia.org/wiki/Anthony_Davidson',
#     'GivenName': 'Anthony',
#     'FamilyName': 'Davidson',
#     'DateOfBirth': '1979-04-18',
#     'Nationality': 'British'},
#    {'@driverId': 'davies',
#     '@url': 'http://en.wikipedia.org/wiki/Jimmy_Davies',
#     'GivenName': 'Jimmy',
#     'FamilyName': 'Davies',
#     'DateOfBirth': '1929-08-08',
#     'Nationality': 'American'},
#    {'@driverId': 'davis',
#     '@url': 'http://en.wikipedia.org/wiki/Colin_Davis_(driver)',
#     'GivenName': 'Colin',
#     'FamilyName': 'Davis',
#     'DateOfBirth': '1933-07-29',
#     'Nationality': 'British'},
#    {'@driverId': 'daywalt',
#     '@url': 'http://en.wikipedia.org/wiki/Jimmy_Daywalt',
#     'GivenName': 'Jimmy',
#     'FamilyName': 'Daywalt',
#     'DateOfBirth': '1924-08-28',
#     'Nationality': 'American'},
#    {'@driverId': 'adamich',
#     '@url': 'http://en.wikipedia.org/wiki/Andrea_de_Adamich',
#     'GivenName': 'Andrea',
#     'FamilyName': 'de Adamich',
#     'DateOfBirth': '1941-10-03',
#     'Nationality': 'Italian'},
#    {'@driverId': 'angelis',
#     '@url': 'http://en.wikipedia.org/wiki/Elio_de_Angelis',
#     'GivenName': 'Elio',
#     'FamilyName': 'de Angelis',
#     'DateOfBirth': '1958-03-26',
#     'Nationality': 'Italian'},
#    {'@driverId': 'beaufort',
#     '@url': 'http://en.wikipedia.org/wiki/Carel_Godin_de_Beaufort',
#     'GivenName': 'Carel Godin',
#     'FamilyName': 'de Beaufort',
#     'DateOfBirth': '1934-04-10',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'cesaris',
#     '@url': 'http://en.wikipedia.org/wiki/Andrea_de_Cesaris',
#     'GivenName': 'Andrea',
#     'FamilyName': 'de Cesaris',
#     'DateOfBirth': '1959-05-31',
#     'Nationality': 'Italian'},
#    {'@driverId': 'Changy',
#     '@url': 'http://en.wikipedia.org/wiki/Alain_de_Changy',
#     'GivenName': 'Alain',
#     'FamilyName': 'de Changy',
#     'DateOfBirth': '1922-02-05',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'dryver',
#     '@url': 'http://en.wikipedia.org/wiki/Bernard_de_Dryver',
#     'GivenName': 'Bernard',
#     'FamilyName': 'de Dryver',
#     'DateOfBirth': '1952-09-19',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'filippis',
#     '@url': 'http://en.wikipedia.org/wiki/Maria_Teresa_de_Filippis',
#     'GivenName': 'Maria',
#     'FamilyName': 'de Filippis',
#     'DateOfBirth': '1926-11-11',
#     'Nationality': 'Italian'},
#    {'@driverId': 'graffenried',
#     '@url': 'http://en.wikipedia.org/wiki/Toulo_de_Graffenried',
#     'GivenName': 'Toulo',
#     'FamilyName': 'de Graffenried',
#     'DateOfBirth': '1914-05-18',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'klerk',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_de_Klerk',
#     'GivenName': 'Peter',
#     'FamilyName': 'de Klerk',
#     'DateOfBirth': '1935-03-16',
#     'Nationality': 'South African'},
#    {'@driverId': 'rosa',
#     '@code': 'DLR',
#     '@url': 'http://en.wikipedia.org/wiki/Pedro_de_la_Rosa',
#     'GivenName': 'Pedro',
#     'FamilyName': 'de la Rosa',
#     'DateOfBirth': '1971-02-24',
#     'Nationality': 'Spanish'},
#    {'@driverId': 'portago',
#     '@url': 'http://en.wikipedia.org/wiki/Alfonso_de_Portago',
#     'GivenName': 'Alfonso',
#     'FamilyName': 'de Portago',
#     'DateOfBirth': '1928-10-11',
#     'Nationality': 'Spanish'},
#    {'@driverId': 'riu',
#     '@url': 'http://en.wikipedia.org/wiki/Giovanni_de_Riu',
#     'GivenName': 'Giovanni',
#     'FamilyName': 'de Riu',
#     'DateOfBirth': '1925-03-10',
#     'Nationality': 'Italian'},
#    {'@driverId': 'terra',
#     '@url': 'http://en.wikipedia.org/wiki/Max_de_Terra',
#     'GivenName': 'Max',
#     'FamilyName': 'de Terra',
#     'DateOfBirth': '1918-10-06',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'tomaso',
#     '@url': 'http://en.wikipedia.org/wiki/Alessandro_de_Tomaso',
#     'GivenName': 'Alessandro',
#     'FamilyName': 'de Tomaso',
#     'DateOfBirth': '1928-07-10',
#     'Nationality': 'Argentine-Italian'},
#    {'@driverId': 'tornaco',
#     '@url': 'http://en.wikipedia.org/wiki/Charles_de_Tornaco',
#     'GivenName': 'Charles',
#     'FamilyName': 'de Tornaco',
#     'DateOfBirth': '1927-06-07',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'villota',
#     '@url': 'http://en.wikipedia.org/wiki/Emilio_de_Villota',
#     'GivenName': 'Emilio',
#     'FamilyName': 'de Villota',
#     'DateOfBirth': '1946-07-26',
#     'Nationality': 'Spanish'},
#    {'@driverId': 'vos',
#     '@url': 'http://en.wikipedia.org/wiki/Ernie_de_Vos',
#     'GivenName': 'Ernie',
#     'FamilyName': 'de Vos',
#     'DateOfBirth': '1941-07-01',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'deletraz',
#     '@url': 'http://en.wikipedia.org/wiki/Jean-Denis_Deletraz',
#     'GivenName': 'Jean-Denis',
#     'FamilyName': 'Délétraz',
#     'DateOfBirth': '1963-10-01',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'depailler',
#     '@url': 'http://en.wikipedia.org/wiki/Patrick_Depailler',
#     'GivenName': 'Patrick',
#     'FamilyName': 'Depailler',
#     'DateOfBirth': '1944-08-09',
#     'Nationality': 'French'},
#    {'@driverId': 'grassi',
#     '@code': 'DIG',
#     '@url': 'http://en.wikipedia.org/wiki/Lucas_di_Grassi',
#     'GivenName': 'Lucas',
#     'FamilyName': 'di Grassi',
#     'DateOfBirth': '1984-08-11',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'resta',
#     '@code': 'DIR',
#     '@url': 'http://en.wikipedia.org/wiki/Paul_di_Resta',
#     'GivenName': 'Paul',
#     'FamilyName': 'di Resta',
#     'DateOfBirth': '1986-04-16',
#     'Nationality': 'British'},
#    {'@driverId': 'diniz',
#     '@url': 'http://en.wikipedia.org/wiki/Pedro_Diniz',
#     'GivenName': 'Pedro',
#     'FamilyName': 'Diniz',
#     'DateOfBirth': '1970-05-22',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'dinsmore',
#     '@url': 'http://en.wikipedia.org/wiki/Duke_Dinsmore',
#     'GivenName': 'Duke',
#     'FamilyName': 'Dinsmore',
#     'DateOfBirth': '1913-04-10',
#     'Nationality': 'American'},
#    {'@driverId': 'dochnal',
#     '@url': 'http://en.wikipedia.org/wiki/Frank_Dochnal',
#     'GivenName': 'Frank',
#     'FamilyName': 'Dochnal',
#     'DateOfBirth': '1920-10-08',
#     'Nationality': 'American'},
#    {'@driverId': 'dolhem',
#     '@url': 'http://en.wikipedia.org/wiki/Jos%C3%A9_Dolhem',
#     'GivenName': 'José',
#     'FamilyName': 'Dolhem',
#     'DateOfBirth': '1944-04-26',
#     'Nationality': 'French'},
#    {'@driverId': 'donnelly',
#     '@url': 'http://en.wikipedia.org/wiki/Martin_Donnelly_(racing_driver)',
#     'GivenName': 'Martin',
#     'FamilyName': 'Donnelly',
#     'DateOfBirth': '1964-03-26',
#     'Nationality': 'British'},
#    {'@driverId': 'donohue',
#     '@url': 'http://en.wikipedia.org/wiki/Mark_Donohue',
#     'GivenName': 'Mark',
#     'FamilyName': 'Donohue',
#     'DateOfBirth': '1937-03-18',
#     'Nationality': 'American'},
#    {'@driverId': 'doornbos',
#     '@code': 'DOO',
#     '@url': 'http://en.wikipedia.org/wiki/Robert_Doornbos',
#     'GivenName': 'Robert',
#     'FamilyName': 'Doornbos',
#     'DateOfBirth': '1981-09-23',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'downing',
#     '@url': 'http://en.wikipedia.org/wiki/Ken_Downing',
#     'GivenName': 'Ken',
#     'FamilyName': 'Downing',
#     'DateOfBirth': '1917-12-05',
#     'Nationality': 'British'},
#    {'@driverId': 'drake',
#     '@url': 'http://en.wikipedia.org/wiki/Bob_Drake_(Formula_One)',
#     'GivenName': 'Bob',
#     'FamilyName': 'Drake',
#     'DateOfBirth': '1919-12-14',
#     'Nationality': 'American'},
#    {'@driverId': 'driver',
#     '@url': 'http://en.wikipedia.org/wiki/Paddy_Driver',
#     'GivenName': 'Paddy',
#     'FamilyName': 'Driver',
#     'DateOfBirth': '1934-05-13',
#     'Nationality': 'South African'},
#    {'@driverId': 'drogo',
#     '@url': 'http://en.wikipedia.org/wiki/Piero_Drogo',
#     'GivenName': 'Piero',
#     'FamilyName': 'Drogo',
#     'DateOfBirth': '1926-08-08',
#     'Nationality': 'Italian'},
#    {'@driverId': 'duke',
#     '@url': 'http://en.wikipedia.org/wiki/Geoff_Duke',
#     'GivenName': 'Geoff',
#     'FamilyName': 'Duke',
#     'DateOfBirth': '1923-03-29',
#     'Nationality': 'British'},
#    {'@driverId': 'dumfries',
#     '@url': 'http://en.wikipedia.org/wiki/Johnny_Dumfries',
#     'GivenName': 'Johnny',
#     'FamilyName': 'Dumfries',
#     'DateOfBirth': '1958-04-26',
#     'Nationality': 'British'},
#    {'@driverId': 'duncan',
#     '@url': 'http://en.wikipedia.org/wiki/Len_Duncan',
#     'GivenName': 'Len',
#     'FamilyName': 'Duncan',
#     'DateOfBirth': '1911-07-25',
#     'Nationality': 'American'},
#    {'@driverId': 'dusio',
#     '@url': 'http://en.wikipedia.org/wiki/Piero_Dusio',
#     'GivenName': 'Piero',
#     'FamilyName': 'Dusio',
#     'DateOfBirth': '1899-10-13',
#     'Nationality': 'Italian'},
#    {'@driverId': 'eaton',
#     '@url': 'http://en.wikipedia.org/wiki/George_Eaton',
#     'GivenName': 'George',
#     'FamilyName': 'Eaton',
#     'DateOfBirth': '1945-11-12',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'ecclestone',
#     '@url': 'http://en.wikipedia.org/wiki/Bernie_Ecclestone',
#     'GivenName': 'Bernie',
#     'FamilyName': 'Ecclestone',
#     'DateOfBirth': '1930-10-28',
#     'Nationality': 'British'},
#    {'@driverId': 'edmunds',
#     '@url': 'http://en.wikipedia.org/wiki/Don_Edmunds',
#     'GivenName': 'Don',
#     'FamilyName': 'Edmunds',
#     'DateOfBirth': '1930-09-23',
#     'Nationality': 'American'},
#    {'@driverId': 'edwards',
#     '@url': 'http://en.wikipedia.org/wiki/Guy_Edwards',
#     'GivenName': 'Guy',
#     'FamilyName': 'Edwards',
#     'DateOfBirth': '1942-12-30',
#     'Nationality': 'British'},
#    {'@driverId': 'elford',
#     '@url': 'http://en.wikipedia.org/wiki/Vic_Elford',
#     'GivenName': 'Vic',
#     'FamilyName': 'Elford',
#     'DateOfBirth': '1935-06-10',
#     'Nationality': 'British'},
#    {'@driverId': 'elisian',
#     '@url': 'http://en.wikipedia.org/wiki/Ed_Elisian',
#     'GivenName': 'Ed',
#     'FamilyName': 'Elisian',
#     'DateOfBirth': '1926-12-09',
#     'Nationality': 'American'},
#    {'@driverId': 'emery',
#     '@url': 'http://en.wikipedia.org/wiki/Paul_Emery',
#     'GivenName': 'Paul',
#     'FamilyName': 'Emery',
#     'DateOfBirth': '1916-11-12',
#     'Nationality': 'British'},
#    {'@driverId': 'enge',
#     '@url': 'http://en.wikipedia.org/wiki/Tom%C3%A1%C5%A1_Enge',
#     'GivenName': 'Tomáš',
#     'FamilyName': 'Enge',
#     'DateOfBirth': '1976-09-11',
#     'Nationality': 'Czech'},
#    {'@driverId': 'england',
#     '@url': 'http://en.wikipedia.org/wiki/Paul_England',
#     'GivenName': 'Paul',
#     'FamilyName': 'England',
#     'DateOfBirth': '1929-03-28',
#     'Nationality': 'Australian'},
#    {'@driverId': 'ericsson',
#     '@code': 'ERI',
#     '@url': 'http://en.wikipedia.org/wiki/Marcus_Ericsson',
#     'PermanentNumber': '9',
#     'GivenName': 'Marcus',
#     'FamilyName': 'Ericsson',
#     'DateOfBirth': '1990-09-02',
#     'Nationality': 'Swedish'},
#    {'@driverId': 'ertl',
#     '@url': 'http://en.wikipedia.org/wiki/Harald_Ertl',
#     'GivenName': 'Harald',
#     'FamilyName': 'Ertl',
#     'DateOfBirth': '1948-08-31',
#     'Nationality': 'Austrian'},
#    {'@driverId': 'estefano',
#     '@url': 'http://en.wikipedia.org/wiki/Nasif_Est%C3%A9fano',
#     'GivenName': 'Nasif',
#     'FamilyName': 'Estéfano',
# ...
#    {'@driverId': 'tsunoda',
#     '@code': 'TSU',
#     '@url': 'http://en.wikipedia.org/wiki/Yuki_Tsunoda',
#     'PermanentNumber': '22',
#     'GivenName': 'Yuki',
#     'FamilyName': 'Tsunoda',
#     'DateOfBirth': '2000-05-11',
#     'Nationality': 'Japanese'},
#    {'@driverId': 'tuero',
#     '@url': 'http://en.wikipedia.org/wiki/Esteban_Tuero',
#     'GivenName': 'Esteban',
#     'FamilyName': 'Tuero',
#     'DateOfBirth': '1978-04-22',
#     'Nationality': 'Argentine'},
#    {'@driverId': 'tunmer',
#     '@url': 'http://en.wikipedia.org/wiki/Guy_Tunmer',
#     'GivenName': 'Guy',
#     'FamilyName': 'Tunmer',
#     'DateOfBirth': '1948-12-01',
#     'Nationality': 'South African'},
#    {'@driverId': 'turner',
#     '@url': 'http://en.wikipedia.org/wiki/Jack_Turner_(driver)',
#     'GivenName': 'Jack',
#     'FamilyName': 'Turner',
#     'DateOfBirth': '1920-02-12',
#     'Nationality': 'American'},
#    {'@driverId': 'ulmen',
#     '@url': 'http://en.wikipedia.org/wiki/Toni_Ulmen',
#     'GivenName': 'Toni',
#     'FamilyName': 'Ulmen',
#     'DateOfBirth': '1906-01-25',
#     'Nationality': 'German'},
#    {'@driverId': 'unser',
#     '@url': 'http://en.wikipedia.org/wiki/Bobby_Unser',
#     'GivenName': 'Bobby',
#     'FamilyName': 'Unser',
#     'DateOfBirth': '1934-02-20',
#     'Nationality': 'American'},
#    {'@driverId': 'jerry_unser',
#     '@url': 'http://en.wikipedia.org/wiki/Jerry_Unser',
#     'GivenName': 'Jerry',
#     'FamilyName': 'Unser',
#     'DateOfBirth': '1932-11-15',
#     'Nationality': 'American'},
#    {'@driverId': 'uria',
#     '@url': 'http://en.wikipedia.org/wiki/Alberto_Uria',
#     'GivenName': 'Alberto',
#     'FamilyName': 'Uria',
#     'DateOfBirth': '1924-07-11',
#     'Nationality': 'Uruguayan'},
#    {'@driverId': 'vaccarella',
#     '@url': 'http://en.wikipedia.org/wiki/Nino_Vaccarella',
#     'GivenName': 'Nino',
#     'FamilyName': 'Vaccarella',
#     'DateOfBirth': '1933-03-04',
#     'Nationality': 'Italian'},
#    {'@driverId': 'poele',
#     '@url': 'http://en.wikipedia.org/wiki/Eric_van_de_Poele',
#     'GivenName': 'Eric',
#     'FamilyName': 'van de Poele',
#     'DateOfBirth': '1961-09-30',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'garde',
#     '@code': 'VDG',
#     '@url': 'http://en.wikipedia.org/wiki/Giedo_van_der_Garde',
#     'GivenName': 'Giedo',
#     'FamilyName': 'van der Garde',
#     'DateOfBirth': '1985-04-25',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'lof',
#     '@url': 'http://en.wikipedia.org/wiki/Dries_van_der_Lof',
#     'GivenName': 'Dries',
#     'FamilyName': 'van der Lof',
#     'DateOfBirth': '1919-08-23',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'vyver',
#     '@url': 'http://en.wikipedia.org/wiki/Syd_van_der_Vyver',
#     'GivenName': 'Syd',
#     'FamilyName': 'van der Vyver',
#     'DateOfBirth': '1920-06-01',
#     'Nationality': 'South African'},
#    {'@driverId': 'lennep',
#     '@url': 'http://en.wikipedia.org/wiki/Gijs_Van_Lennep',
#     'GivenName': 'Gijs',
#     'FamilyName': 'van Lennep',
#     'DateOfBirth': '1942-03-16',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'rooyen',
#     '@url': 'http://en.wikipedia.org/wiki/Basil_van_Rooyen',
#     'GivenName': 'Basil',
#     'FamilyName': 'van Rooyen',
#     'DateOfBirth': '1939-04-19',
#     'Nationality': 'South African'},
#    {'@driverId': 'vandoorne',
#     '@code': 'VAN',
#     '@url': 'http://en.wikipedia.org/wiki/Stoffel_Vandoorne',
#     'PermanentNumber': '2',
#     'GivenName': 'Stoffel',
#     'FamilyName': 'Vandoorne',
#     'DateOfBirth': '1992-03-26',
#     'Nationality': 'Belgian'},
#    {'@driverId': 'veith',
#     '@url': 'http://en.wikipedia.org/wiki/Bob_Veith',
#     'GivenName': 'Bob',
#     'FamilyName': 'Veith',
#     'DateOfBirth': '1926-11-01',
#     'Nationality': 'American'},
#    {'@driverId': 'vergne',
#     '@code': 'VER',
#     '@url': 'http://en.wikipedia.org/wiki/Jean-%C3%89ric_Vergne',
#     'PermanentNumber': '25',
#     'GivenName': 'Jean-Éric',
#     'FamilyName': 'Vergne',
#     'DateOfBirth': '1990-04-25',
#     'Nationality': 'French'},
#    {'@driverId': 'verstappen',
#     '@url': 'http://en.wikipedia.org/wiki/Jos_Verstappen',
#     'GivenName': 'Jos',
#     'FamilyName': 'Verstappen',
#     'DateOfBirth': '1972-03-04',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'max_verstappen',
#     '@code': 'VER',
#     '@url': 'http://en.wikipedia.org/wiki/Max_Verstappen',
#     'PermanentNumber': '33',
#     'GivenName': 'Max',
#     'FamilyName': 'Verstappen',
#     'DateOfBirth': '1997-09-30',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'vettel',
#     '@code': 'VET',
#     '@url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#     'PermanentNumber': '5',
#     'GivenName': 'Sebastian',
#     'FamilyName': 'Vettel',
#     'DateOfBirth': '1987-07-03',
#     'Nationality': 'German'},
#    {'@driverId': 'villeneuve',
#     '@code': 'VIL',
#     '@url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve',
#     'GivenName': 'Jacques',
#     'FamilyName': 'Villeneuve',
#     'DateOfBirth': '1971-04-09',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'gilles_villeneuve',
#     '@url': 'http://en.wikipedia.org/wiki/Gilles_Villeneuve',
#     'GivenName': 'Gilles',
#     'FamilyName': 'Villeneuve',
#     'DateOfBirth': '1950-01-18',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'villeneuve_sr',
#     '@url': 'http://en.wikipedia.org/wiki/Jacques_Villeneuve_(elder)',
#     'GivenName': 'Jacques',
#     'FamilyName': 'Villeneuve Sr.',
#     'DateOfBirth': '1953-11-04',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'villoresi',
#     '@url': 'http://en.wikipedia.org/wiki/Luigi_Villoresi',
#     'GivenName': 'Luigi',
#     'FamilyName': 'Villoresi',
#     'DateOfBirth': '1909-05-16',
#     'Nationality': 'Italian'},
#    {'@driverId': 'volonterio',
#     '@url': 'http://en.wikipedia.org/wiki/Ottorino_Volonterio',
#     'GivenName': 'Ottorino',
#     'FamilyName': 'Volonterio',
#     'DateOfBirth': '1917-12-07',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'opel',
#     '@url': 'http://en.wikipedia.org/wiki/Rikky_von_Opel',
#     'GivenName': 'Rikky',
#     'FamilyName': 'von Opel',
#     'DateOfBirth': '1947-10-14',
#     'Nationality': 'Liechtensteiner'},
#    {'@driverId': 'hans_stuck',
#     '@url': 'http://en.wikipedia.org/wiki/Hans_Von_Stuck',
#     'GivenName': 'Hans',
#     'FamilyName': 'von Stuck',
#     'DateOfBirth': '1900-12-27',
#     'Nationality': 'German'},
#    {'@driverId': 'trips',
#     '@url': 'http://en.wikipedia.org/wiki/Wolfgang_Graf_Berghe_von_Trips',
#     'GivenName': 'Wolfgang',
#     'FamilyName': 'von Trips',
#     'DateOfBirth': '1928-05-04',
#     'Nationality': 'German'},
#    {'@driverId': 'vonlanthen',
#     '@url': 'http://en.wikipedia.org/wiki/Jo_Vonlanthen',
#     'GivenName': 'Jo',
#     'FamilyName': 'Vonlanthen',
#     'DateOfBirth': '1942-05-31',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'vukovich',
#     '@url': 'http://en.wikipedia.org/wiki/Bill_Vukovich',
#     'GivenName': 'Bill',
#     'FamilyName': 'Vukovich',
#     'DateOfBirth': '1918-12-13',
#     'Nationality': 'American'},
#    {'@driverId': 'wacker',
#     '@url': 'http://en.wikipedia.org/wiki/Fred_Wacker',
#     'GivenName': 'Fred',
#     'FamilyName': 'Wacker',
#     'DateOfBirth': '1918-07-10',
#     'Nationality': 'American'},
#    {'@driverId': 'walker',
#     '@url': 'http://en.wikipedia.org/wiki/David_Walker_(racing_driver)',
#     'GivenName': 'David',
#     'FamilyName': 'Walker',
#     'DateOfBirth': '1941-06-10',
#     'Nationality': 'Australian'},
#    {'@driverId': 'peter_walker',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Walker_(driver)',
#     'GivenName': 'Peter',
#     'FamilyName': 'Walker',
#     'DateOfBirth': '1912-10-07',
#     'Nationality': 'British'},
#    {'@driverId': 'wallard',
#     '@url': 'http://en.wikipedia.org/wiki/Lee_Wallard',
#     'GivenName': 'Lee',
#     'FamilyName': 'Wallard',
#     'DateOfBirth': '1910-09-07',
#     'Nationality': 'American'},
#    {'@driverId': 'walter',
#     '@url': 'http://en.wikipedia.org/wiki/Heini_Walter',
#     'GivenName': 'Heini',
#     'FamilyName': 'Walter',
#     'DateOfBirth': '1927-07-28',
#     'Nationality': 'Swiss'},
#    {'@driverId': 'ward',
#     '@url': 'http://en.wikipedia.org/wiki/Rodger_Ward',
#     'GivenName': 'Rodger',
#     'FamilyName': 'Ward',
#     'DateOfBirth': '1921-01-10',
#     'Nationality': 'American'},
#    {'@driverId': 'warwick',
#     '@url': 'http://en.wikipedia.org/wiki/Derek_Warwick',
#     'GivenName': 'Derek',
#     'FamilyName': 'Warwick',
#     'DateOfBirth': '1954-08-27',
#     'Nationality': 'British'},
#    {'@driverId': 'watson',
#     '@url': 'http://en.wikipedia.org/wiki/John_Watson_(racing_driver)',
#     'GivenName': 'John',
#     'FamilyName': 'Watson',
#     'DateOfBirth': '1946-05-04',
#     'Nationality': 'British'},
#    {'@driverId': 'webb',
#     '@url': 'http://en.wikipedia.org/wiki/Travis_Webb',
#     'GivenName': 'Travis',
#     'FamilyName': 'Webb',
#     'DateOfBirth': '1910-10-08',
#     'Nationality': 'American'},
#    {'@driverId': 'webber',
#     '@code': 'WEB',
#     '@url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#     'GivenName': 'Mark',
#     'FamilyName': 'Webber',
#     'DateOfBirth': '1976-08-27',
#     'Nationality': 'Australian'},
#    {'@driverId': 'wehrlein',
#     '@code': 'WEH',
#     '@url': 'http://en.wikipedia.org/wiki/Pascal_Wehrlein',
#     'PermanentNumber': '94',
#     'GivenName': 'Pascal',
#     'FamilyName': 'Wehrlein',
#     'DateOfBirth': '1994-10-18',
#     'Nationality': 'German'},
#    {'@driverId': 'weidler',
#     '@url': 'http://en.wikipedia.org/wiki/Volker_Weidler',
#     'GivenName': 'Volker',
#     'FamilyName': 'Weidler',
#     'DateOfBirth': '1962-03-18',
#     'Nationality': 'German'},
#    {'@driverId': 'weiler',
#     '@url': 'http://en.wikipedia.org/wiki/Wayne_Weiler',
#     'GivenName': 'Wayne',
#     'FamilyName': 'Weiler',
#     'DateOfBirth': '1934-12-09',
#     'Nationality': 'American'},
#    {'@driverId': 'wendlinger',
#     '@url': 'http://en.wikipedia.org/wiki/Karl_Wendlinger',
#     'GivenName': 'Karl',
#     'FamilyName': 'Wendlinger',
#     'DateOfBirth': '1968-12-20',
#     'Nationality': 'Austrian'},
#    {'@driverId': 'westbury',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Westbury',
#     'GivenName': 'Peter',
#     'FamilyName': 'Westbury',
#     'DateOfBirth': '1938-05-26',
#     'Nationality': 'British'},
#    {'@driverId': 'weyant',
#     '@url': 'http://en.wikipedia.org/wiki/Chuck_Weyant',
#     'GivenName': 'Chuck',
#     'FamilyName': 'Weyant',
#     'DateOfBirth': '1923-04-03',
#     'Nationality': 'American'},
#    {'@driverId': 'wharton',
#     '@url': 'http://en.wikipedia.org/wiki/Ken_Wharton',
#     'GivenName': 'Ken',
#     'FamilyName': 'Wharton',
#     'DateOfBirth': '1916-03-21',
#     'Nationality': 'British'},
#    {'@driverId': 'whiteaway',
#     '@url': 'http://en.wikipedia.org/wiki/Ted_Whiteaway',
#     'GivenName': 'Ted',
#     'FamilyName': 'Whiteaway',
#     'DateOfBirth': '1928-11-01',
#     'Nationality': 'British'},
#    {'@driverId': 'whitehead',
#     '@url': 'http://en.wikipedia.org/wiki/Peter_Whitehead_(racing_driver)',
#     'GivenName': 'Peter',
#     'FamilyName': 'Whitehead',
#     'DateOfBirth': '1914-11-12',
#     'Nationality': 'British'},
#    {'@driverId': 'graham_whitehead',
#     '@url': 'http://en.wikipedia.org/wiki/Graham_Whitehead',
#     'GivenName': 'Graham',
#     'FamilyName': 'Whitehead',
#     'DateOfBirth': '1922-04-15',
#     'Nationality': 'British'},
#    {'@driverId': 'whitehouse',
#     '@url': 'http://en.wikipedia.org/wiki/Bill_Whitehouse',
#     'GivenName': 'Bill',
#     'FamilyName': 'Whitehouse',
#     'DateOfBirth': '1909-04-01',
#     'Nationality': 'British'},
#    {'@driverId': 'widdows',
#     '@url': 'http://en.wikipedia.org/wiki/Robin_Widdows',
#     'GivenName': 'Robin',
#     'FamilyName': 'Widdows',
#     'DateOfBirth': '1942-05-27',
#     'Nationality': 'British'},
#    {'@driverId': 'wietzes',
#     '@url': 'http://en.wikipedia.org/wiki/Eppie_Wietzes',
#     'GivenName': 'Eppie',
#     'FamilyName': 'Wietzes',
#     'DateOfBirth': '1938-05-28',
#     'Nationality': 'Canadian'},
#    {'@driverId': 'wilds',
#     '@url': 'http://en.wikipedia.org/wiki/Mike_Wilds',
#     'GivenName': 'Mike',
#     'FamilyName': 'Wilds',
#     'DateOfBirth': '1946-01-07',
#     'Nationality': 'British'},
#    {'@driverId': 'williams',
#     '@url': 'http://en.wikipedia.org/wiki/Jonathan_Williams_(racing_driver)',
#     'GivenName': 'Jonathan',
#     'FamilyName': 'Williams',
#     'DateOfBirth': '1942-10-26',
#     'Nationality': 'British'},
#    {'@driverId': 'williamson',
#     '@url': 'http://en.wikipedia.org/wiki/Roger_Williamson',
#     'GivenName': 'Roger',
#     'FamilyName': 'Williamson',
#     'DateOfBirth': '1948-02-02',
#     'Nationality': 'British'},
#    {'@driverId': 'wilson',
#     '@url': 'http://en.wikipedia.org/wiki/Justin_Wilson_(racing_driver)',
#     'GivenName': 'Justin',
#     'FamilyName': 'Wilson',
#     'DateOfBirth': '1978-07-31',
#     'Nationality': 'British'},
#    {'@driverId': 'desire_wilson',
#     '@url': 'http://en.wikipedia.org/wiki/Desir%C3%A9_Wilson',
#     'GivenName': 'Desiré',
#     'FamilyName': 'Wilson',
#     'DateOfBirth': '1953-11-26',
#     'Nationality': 'South African'},
#    {'@driverId': 'vic_wilson',
#     '@url': 'http://en.wikipedia.org/wiki/Vic_Wilson_(motor_racing_driver)',
#     'GivenName': 'Vic',
#     'FamilyName': 'Wilson',
#     'DateOfBirth': '1931-04-14',
#     'Nationality': 'British'},
#    {'@driverId': 'dempsey_wilson',
#     '@url': 'http://en.wikipedia.org/wiki/Dempsey_Wilson',
#     'GivenName': 'Dempsey',
#     'FamilyName': 'Wilson',
#     'DateOfBirth': '1927-03-11',
#     'Nationality': 'American'},
#    {'@driverId': 'markus_winkelhock',
#     '@code': 'WIN',
#     '@url': 'http://en.wikipedia.org/wiki/Markus_Winkelhock',
#     'GivenName': 'Markus',
#     'FamilyName': 'Winkelhock',
#     'DateOfBirth': '1980-06-13',
#     'Nationality': 'German'},
#    {'@driverId': 'joachim_winkelhock',
#     '@url': 'http://en.wikipedia.org/wiki/Joachim_Winkelhock',
#     'GivenName': 'Joachim',
#     'FamilyName': 'Winkelhock',
#     'DateOfBirth': '1960-10-24',
#     'Nationality': 'German'},
#    {'@driverId': 'manfred_winkelhock',
#     '@url': 'http://en.wikipedia.org/wiki/Manfred_Winkelhock',
#     'GivenName': 'Manfred',
#     'FamilyName': 'Winkelhock',
#     'DateOfBirth': '1951-10-06',
#     'Nationality': 'German'},
#    {'@driverId': 'wisell',
#     '@url': 'http://en.wikipedia.org/wiki/Reine_Wisell',
#     'GivenName': 'Reine',
#     'FamilyName': 'Wisell',
#     'DateOfBirth': '1941-09-30',
#     'Nationality': 'Swedish'},
#    {'@driverId': 'wunderink',
#     '@url': 'http://en.wikipedia.org/wiki/Roelof_Wunderink',
#     'GivenName': 'Roelof',
#     'FamilyName': 'Wunderink',
#     'DateOfBirth': '1948-12-12',
#     'Nationality': 'Dutch'},
#    {'@driverId': 'wurz',
#     '@code': 'WUR',
#     '@url': 'http://en.wikipedia.org/wiki/Alexander_Wurz',
#     'GivenName': 'Alexander',
#     'FamilyName': 'Wurz',
#     'DateOfBirth': '1974-02-15',
#     'Nationality': 'Austrian'},
#    {'@driverId': 'yamamoto',
#     '@code': 'YAM',
#     '@url': 'http://en.wikipedia.org/wiki/Sakon_Yamamoto',
#     'GivenName': 'Sakon',
#     'FamilyName': 'Yamamoto',
#     'DateOfBirth': '1982-07-09',
#     'Nationality': 'Japanese'},
#    {'@driverId': 'yoong',
#     '@url': 'http://en.wikipedia.org/wiki/Alex_Yoong',
#     'GivenName': 'Alex',
#     'FamilyName': 'Yoong',
#     'DateOfBirth': '1976-07-20',
#     'Nationality': 'Malaysian'},
#    {'@driverId': 'zanardi',
#     '@url': 'http://en.wikipedia.org/wiki/Alex_Zanardi',
#     'GivenName': 'Alessandro',
#     'FamilyName': 'Zanardi',
#     'DateOfBirth': '1966-10-23',
#     'Nationality': 'Italian'},
#    {'@driverId': 'zapico',
#     '@url': 'http://en.wikipedia.org/wiki/Emilio_Zapico',
#     'GivenName': 'Emilio',
#     'FamilyName': 'Zapico',
#     'DateOfBirth': '1944-05-27',
#     'Nationality': 'Spanish'},
#    {'@driverId': 'zonta',
#     '@code': 'ZON',
#     '@url': 'http://en.wikipedia.org/wiki/Ricardo_Zonta',
#     'GivenName': 'Ricardo',
#     'FamilyName': 'Zonta',
#     'DateOfBirth': '1976-03-23',
#     'Nationality': 'Brazilian'},
#    {'@driverId': 'zorzi',
#     '@url': 'http://en.wikipedia.org/wiki/Renzo_Zorzi',
#     'GivenName': 'Renzo',
#     'FamilyName': 'Zorzi',
#     'DateOfBirth': '1946-12-12',
#     'Nationality': 'Italian'},
#    {'@driverId': 'zunino',
#     '@url': 'http://en.wikipedia.org/wiki/Ricardo_Zunino',
#     'GivenName': 'Ricardo',
#     'FamilyName': 'Zunino',
#     'DateOfBirth': '1949-04-13',
#     'Nationality': 'Argentine'}]}}

# %%
url = "http://ergast.com/api/f1/current/last/results.json"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
db = eval(response.text)

# %%
db
# Out:
# {'MRData': {'xmlns': 'http:\\/\\/ergast.com\\/mrd\\/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/current/last/results.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '20',
#   'RaceTable': {'season': '2021',
#    'round': '11',
#    'Races': [{'season': '2021',
#      'round': '11',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/2021_Hungarian_Grand_Prix',
#      'raceName': 'Hungarian Grand Prix',
#      'Circuit': {'circuitId': 'hungaroring',
#       'url': 'http://en.wikipedia.org/wiki/Hungaroring',
#       'circuitName': 'Hungaroring',
#       'Location': {'lat': '47.5789',
#        'long': '19.2486',
#        'locality': 'Budapest',
#        'country': 'Hungary'}},
#      'date': '2021-08-01',
#      'time': '13:00:00Z',
#      'Results': [{'number': '31',
#        'position': '1',
#        'positionText': '1',
#        'points': '25',
#        'Driver': {'driverId': 'ocon',
#         'permanentNumber': '31',
#         'code': 'OCO',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Esteban_Ocon',
#         'givenName': 'Esteban',
#         'familyName': 'Ocon',
#         'dateOfBirth': '1996-09-17',
#         'nationality': 'French'},
#        'Constructor': {'constructorId': 'alpine',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alpine_F1_Team',
#         'name': 'Alpine F1 Team',
#         'nationality': 'French'},
#        'grid': '8',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7483199', 'time': '2:04:43.199'},
#        'FastestLap': {'rank': '5',
#         'lap': '54',
#         'Time': {'time': '1:21.421'},
#         'AverageSpeed': {'units': 'kph', 'speed': '193.704'}}},
#       {'number': '44',
#        'position': '2',
#        'positionText': '2',
#        'points': '18',
#        'Driver': {'driverId': 'hamilton',
#         'permanentNumber': '44',
#         'code': 'HAM',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lewis_Hamilton',
#         'givenName': 'Lewis',
#         'familyName': 'Hamilton',
#         'dateOfBirth': '1985-01-07',
#         'nationality': 'British'},
#        'Constructor': {'constructorId': 'mercedes',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mercedes-Benz_in_Formula_One',
#         'name': 'Mercedes',
#         'nationality': 'German'},
#        'grid': '1',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7485935', 'time': '+2.736'},
#        'FastestLap': {'rank': '7',
#         'lap': '60',
#         'Time': {'time': '1:21.459'},
#         'AverageSpeed': {'units': 'kph', 'speed': '193.613'}}},
#       {'number': '55',
#        'position': '3',
#        'positionText': '3',
#        'points': '15',
#        'Driver': {'driverId': 'sainz',
#         'permanentNumber': '55',
#         'code': 'SAI',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Carlos_Sainz_Jr.',
#         'givenName': 'Carlos',
#         'familyName': 'Sainz',
#         'dateOfBirth': '1994-09-01',
#         'nationality': 'Spanish'},
#        'Constructor': {'constructorId': 'ferrari',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_Ferrari',
#         'name': 'Ferrari',
#         'nationality': 'Italian'},
#        'grid': '15',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7498217', 'time': '+15.018'},
#        'FastestLap': {'rank': '2',
#         'lap': '49',
#         'Time': {'time': '1:18.715'},
#         'AverageSpeed': {'units': 'kph', 'speed': '200.363'}}},
#       {'number': '14',
#        'position': '4',
#        'positionText': '4',
#        'points': '12',
#        'Driver': {'driverId': 'alonso',
#         'permanentNumber': '14',
#         'code': 'ALO',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Fernando_Alonso',
#         'givenName': 'Fernando',
#         'familyName': 'Alonso',
#         'dateOfBirth': '1981-07-29',
#         'nationality': 'Spanish'},
#        'Constructor': {'constructorId': 'alpine',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alpine_F1_Team',
#         'name': 'Alpine F1 Team',
#         'nationality': 'French'},
#        'grid': '9',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7498850', 'time': '+15.651'},
#        'FastestLap': {'rank': '6',
#         'lap': '54',
#         'Time': {'time': '1:21.423'},
#         'AverageSpeed': {'units': 'kph', 'speed': '193.699'}}},
#       {'number': '10',
#        'position': '5',
#        'positionText': '5',
#        'points': '11',
#        'Driver': {'driverId': 'gasly',
#         'permanentNumber': '10',
#         'code': 'GAS',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Pierre_Gasly',
#         'givenName': 'Pierre',
#         'familyName': 'Gasly',
#         'dateOfBirth': '1996-02-07',
#         'nationality': 'French'},
#        'Constructor': {'constructorId': 'alphatauri',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_AlphaTauri',
#         'name': 'AlphaTauri',
#         'nationality': 'Italian'},
#        'grid': '5',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7546813', 'time': '+1:03.614'},
#        'FastestLap': {'rank': '3',
#         'lap': '41',
#         'Time': {'time': '1:20.359'},
#         'AverageSpeed': {'units': 'kph', 'speed': '196.264'}}},
#       {'number': '22',
#        'position': '6',
#        'positionText': '6',
#        'points': '8',
#        'Driver': {'driverId': 'tsunoda',
#         'permanentNumber': '22',
#         'code': 'TSU',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Yuki_Tsunoda',
#         'givenName': 'Yuki',
#         'familyName': 'Tsunoda',
#         'dateOfBirth': '2000-05-11',
#         'nationality': 'Japanese'},
#        'Constructor': {'constructorId': 'alphatauri',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_AlphaTauri',
#         'name': 'AlphaTauri',
#         'nationality': 'Italian'},
#        'grid': '16',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7559002', 'time': '+1:15.803'},
#        'FastestLap': {'rank': '1',
#         'lap': '70',
#         'Time': {'time': '1:18.394'},
#         'AverageSpeed': {'units': 'kph', 'speed': '201.183'}}},
#       {'number': '6',
#        'position': '7',
#        'positionText': '7',
#        'points': '6',
#        'Driver': {'driverId': 'latifi',
#         'permanentNumber': '6',
#         'code': 'LAT',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nicholas_Latifi',
#         'givenName': 'Nicholas',
#         'familyName': 'Latifi',
#         'dateOfBirth': '1995-06-29',
#         'nationality': 'Canadian'},
#        'Constructor': {'constructorId': 'williams',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Williams_Grand_Prix_Engineering',
#         'name': 'Williams',
#         'nationality': 'British'},
#        'grid': '18',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7561109', 'time': '+1:17.910'},
#        'FastestLap': {'rank': '10',
#         'lap': '43',
#         'Time': {'time': '1:22.450'},
#         'AverageSpeed': {'units': 'kph', 'speed': '191.286'}}},
#       {'number': '63',
#        'position': '8',
#        'positionText': '8',
#        'points': '4',
#        'Driver': {'driverId': 'russell',
#         'permanentNumber': '63',
#         'code': 'RUS',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/George_Russell_%28racing_driver%29',
#         'givenName': 'George',
#         'familyName': 'Russell',
#         'dateOfBirth': '1998-02-15',
#         'nationality': 'British'},
#        'Constructor': {'constructorId': 'williams',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Williams_Grand_Prix_Engineering',
#         'name': 'Williams',
#         'nationality': 'British'},
#        'grid': '17',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7562293', 'time': '+1:19.094'},
#        'FastestLap': {'rank': '14',
#         'lap': '62',
#         'Time': {'time': '1:22.831'},
#         'AverageSpeed': {'units': 'kph', 'speed': '190.406'}}},
#       {'number': '33',
#        'position': '9',
#        'positionText': '9',
#        'points': '2',
#        'Driver': {'driverId': 'max_verstappen',
#         'permanentNumber': '33',
#         'code': 'VER',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Max_Verstappen',
#         'givenName': 'Max',
#         'familyName': 'Verstappen',
#         'dateOfBirth': '1997-09-30',
#         'nationality': 'Dutch'},
#        'Constructor': {'constructorId': 'red_bull',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Red_Bull_Racing',
#         'name': 'Red Bull',
#         'nationality': 'Austrian'},
#        'grid': '3',
#        'laps': '70',
#        'status': 'Finished',
#        'Time': {'millis': '7563443', 'time': '+1:20.244'},
#        'FastestLap': {'rank': '9',
#         'lap': '62',
#         'Time': {'time': '1:22.112'},
#         'AverageSpeed': {'units': 'kph', 'speed': '192.074'}}},
#       {'number': '7',
#        'position': '10',
#        'positionText': '10',
#        'points': '1',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructor': {'constructorId': 'alfa',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alfa_Romeo_in_Formula_One',
#         'name': 'Alfa Romeo',
#         'nationality': 'Swiss'},
#        'grid': '13',
#        'laps': '69',
#        'status': '+1 Lap',
#        'FastestLap': {'rank': '4',
#         'lap': '43',
#         'Time': {'time': '1:20.945'},
#         'AverageSpeed': {'units': 'kph', 'speed': '194.843'}}},
#       {'number': '3',
#        'position': '11',
#        'positionText': '11',
#        'points': '0',
#        'Driver': {'driverId': 'ricciardo',
#         'permanentNumber': '3',
#         'code': 'RIC',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Daniel_Ricciardo',
#         'givenName': 'Daniel',
#         'familyName': 'Ricciardo',
#         'dateOfBirth': '1989-07-01',
#         'nationality': 'Australian'},
#        'Constructor': {'constructorId': 'mclaren',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/McLaren',
#         'name': 'McLaren',
#         'nationality': 'British'},
#        'grid': '11',
#        'laps': '69',
#        'status': '+1 Lap',
#        'FastestLap': {'rank': '8',
#         'lap': '58',
#         'Time': {'time': '1:21.518'},
#         'AverageSpeed': {'units': 'kph', 'speed': '193.473'}}},
#       {'number': '47',
#        'position': '12',
#        'positionText': '12',
#        'points': '0',
#        'Driver': {'driverId': 'mick_schumacher',
#         'permanentNumber': '47',
#         'code': 'MSC',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mick_Schumacher',
#         'givenName': 'Mick',
#         'familyName': 'Schumacher',
#         'dateOfBirth': '1999-03-22',
#         'nationality': 'German'},
#        'Constructor': {'constructorId': 'haas',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Haas_F1_Team',
#         'name': 'Haas F1 Team',
#         'nationality': 'American'},
#        'grid': '20',
#        'laps': '69',
#        'status': '+1 Lap',
#        'FastestLap': {'rank': '13',
#         'lap': '58',
#         'Time': {'time': '1:22.802'},
#         'AverageSpeed': {'units': 'kph', 'speed': '190.473'}}},
#       {'number': '99',
#        'position': '13',
#        'positionText': '13',
#        'points': '0',
#        'Driver': {'driverId': 'giovinazzi',
#         'permanentNumber': '99',
#         'code': 'GIO',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Antonio_Giovinazzi',
#         'givenName': 'Antonio',
#         'familyName': 'Giovinazzi',
#         'dateOfBirth': '1993-12-14',
#         'nationality': 'Italian'},
#        'Constructor': {'constructorId': 'alfa',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alfa_Romeo_in_Formula_One',
#         'name': 'Alfa Romeo',
#         'nationality': 'Swiss'},
#        'grid': '0',
#        'laps': '69',
#        'status': '+1 Lap',
#        'FastestLap': {'rank': '11',
#         'lap': '44',
#         'Time': {'time': '1:22.711'},
#         'AverageSpeed': {'units': 'kph', 'speed': '190.683'}}},
#       {'number': '9',
#        'position': '14',
#        'positionText': 'R',
#        'points': '0',
#        'Driver': {'driverId': 'mazepin',
#         'permanentNumber': '9',
#         'code': 'MAZ',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nikita_Mazepin',
#         'givenName': 'Nikita',
#         'familyName': 'Mazepin',
#         'dateOfBirth': '1999-03-02',
#         'nationality': 'Russian'},
#        'Constructor': {'constructorId': 'haas',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Haas_F1_Team',
#         'name': 'Haas F1 Team',
#         'nationality': 'American'},
#        'grid': '19',
#        'laps': '3',
#        'status': 'Collision',
#        'FastestLap': {'rank': '12',
#         'lap': '44',
#         'Time': {'time': '1:22.736'},
#         'AverageSpeed': {'units': 'kph', 'speed': '190.625'}}},
#       {'number': '4',
#        'position': '15',
#        'positionText': 'R',
#        'points': '0',
#        'Driver': {'driverId': 'norris',
#         'permanentNumber': '4',
#         'code': 'NOR',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lando_Norris',
#         'givenName': 'Lando',
#         'familyName': 'Norris',
#         'dateOfBirth': '1999-11-13',
#         'nationality': 'British'},
#        'Constructor': {'constructorId': 'mclaren',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/McLaren',
#         'name': 'McLaren',
#         'nationality': 'British'},
#        'grid': '6',
#        'laps': '2',
#        'status': 'Collision'},
#       {'number': '77',
#        'position': '16',
#        'positionText': 'R',
#        'points': '0',
#        'Driver': {'driverId': 'bottas',
#         'permanentNumber': '77',
#         'code': 'BOT',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Valtteri_Bottas',
#         'givenName': 'Valtteri',
#         'familyName': 'Bottas',
#         'dateOfBirth': '1989-08-28',
#         'nationality': 'Finnish'},
#        'Constructor': {'constructorId': 'mercedes',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mercedes-Benz_in_Formula_One',
#         'name': 'Mercedes',
#         'nationality': 'German'},
#        'grid': '2',
#        'laps': '0',
#        'status': 'Collision'},
#       {'number': '11',
#        'position': '17',
#        'positionText': 'R',
#        'points': '0',
#        'Driver': {'driverId': 'perez',
#         'permanentNumber': '11',
#         'code': 'PER',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Sergio_P%C3%A9rez',
#         'givenName': 'Sergio',
#         'familyName': 'Pérez',
#         'dateOfBirth': '1990-01-26',
#         'nationality': 'Mexican'},
#        'Constructor': {'constructorId': 'red_bull',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Red_Bull_Racing',
#         'name': 'Red Bull',
#         'nationality': 'Austrian'},
#        'grid': '4',
#        'laps': '0',
#        'status': 'Collision'},
#       {'number': '16',
#        'position': '18',
#        'positionText': 'R',
#        'points': '0',
#        'Driver': {'driverId': 'leclerc',
#         'permanentNumber': '16',
#         'code': 'LEC',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Charles_Leclerc',
#         'givenName': 'Charles',
#         'familyName': 'Leclerc',
#         'dateOfBirth': '1997-10-16',
#         'nationality': 'Monegasque'},
#        'Constructor': {'constructorId': 'ferrari',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_Ferrari',
#         'name': 'Ferrari',
#         'nationality': 'Italian'},
#        'grid': '7',
#        'laps': '0',
#        'status': 'Collision'},
#       {'number': '18',
#        'position': '19',
#        'positionText': 'R',
#        'points': '0',
#        'Driver': {'driverId': 'stroll',
#         'permanentNumber': '18',
#         'code': 'STR',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lance_Stroll',
#         'givenName': 'Lance',
#         'familyName': 'Stroll',
#         'dateOfBirth': '1998-10-29',
#         'nationality': 'Canadian'},
#        'Constructor': {'constructorId': 'aston_martin',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Aston_Martin_in_Formula_One',
#         'name': 'Aston Martin',
#         'nationality': 'British'},
#        'grid': '12',
#        'laps': '0',
#        'status': 'Collision'},
#       {'number': '5',
#        'position': '20',
#        'positionText': 'D',
#        'points': '0',
#        'Driver': {'driverId': 'vettel',
#         'permanentNumber': '5',
#         'code': 'VET',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Sebastian_Vettel',
#         'givenName': 'Sebastian',
#         'familyName': 'Vettel',
#         'dateOfBirth': '1987-07-03',
#         'nationality': 'German'},
#        'Constructor': {'constructorId': 'aston_martin',
#         'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Aston_Martin_in_Formula_One',
#         'name': 'Aston Martin',
#         'nationality': 'British'},
#        'grid': '10',
#        'laps': '70',
#        'status': 'Disqualified'}]}]}}}

# %%
db['MRData']['RaceTable']['Races'][0]['Results'][10]
# Out:
# {'number': '3',
#  'position': '11',
#  'positionText': '11',
#  'points': '0',
#  'Driver': {'driverId': 'ricciardo',
#   'permanentNumber': '3',
#   'code': 'RIC',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Daniel_Ricciardo',
#   'givenName': 'Daniel',
#   'familyName': 'Ricciardo',
#   'dateOfBirth': '1989-07-01',
#   'nationality': 'Australian'},
#  'Constructor': {'constructorId': 'mclaren',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/McLaren',
#   'name': 'McLaren',
#   'nationality': 'British'},
#  'grid': '11',
#  'laps': '69',
#  'status': '+1 Lap',
#  'FastestLap': {'rank': '8',
#   'lap': '58',
#   'Time': {'time': '1:21.518'},
#   'AverageSpeed': {'units': 'kph', 'speed': '193.473'}}}

# %%
z=db['MRData']['RaceTable']['Races'][0]['Results']

# %%
z[10]
# Out:
# {'number': '3',
#  'position': '11',
#  'positionText': '11',
#  'points': '0',
#  'Driver': {'driverId': 'ricciardo',
#   'permanentNumber': '3',
#   'code': 'RIC',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Daniel_Ricciardo',
#   'givenName': 'Daniel',
#   'familyName': 'Ricciardo',
#   'dateOfBirth': '1989-07-01',
#   'nationality': 'Australian'},
#  'Constructor': {'constructorId': 'mclaren',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/McLaren',
#   'name': 'McLaren',
#   'nationality': 'British'},
#  'grid': '11',
#  'laps': '69',
#  'status': '+1 Lap',
#  'FastestLap': {'rank': '8',
#   'lap': '58',
#   'Time': {'time': '1:21.518'},
#   'AverageSpeed': {'units': 'kph', 'speed': '193.473'}}}

# %%
h=["pos","no","driver","laps","time","points"]
print ("{:<8} {:<8} {:<20} {:<10} {:<15} {:<10}".format('Pos','No','Driver','Laps','Time','Points'))
for key in z:
    try:
        a1=key['position']
        a2=key['number']
        a3=key['Driver']['givenName']+" " +key['Driver']['familyName']
        a4=key['laps']
        a5=key['Time']['time']
        a6=key['points']
        print ("{:<8} {:<8} {:<20} {:<10} {:<15} {:<10}".format(a1,a2,a3,a4,a5,a6))
    except:
        if key['status']=="Disqualified":
            status="DQ"
        elif key['status']=='Collision':
            status="DNF"
        else:
            status=key['status']
        a1=key['position']
        a2=key['number']
        a3=key['Driver']['givenName']+" " +key['Driver']['familyName']
        a4=key['laps']
        a5=status
        a6=key['points']
        print ("{:<8} {:<8} {:<20} {:<10} {:<15} {:<10}".format(a1,a2,a3,a4,a5,a6))
# Out:
# Pos      No       Driver               Laps       Time            Points
# 1        31       Esteban Ocon         70         2:04:43.199     25
# 2        44       Lewis Hamilton       70         +2.736          18
# 3        55       Carlos Sainz         70         +15.018         15
# 4        14       Fernando Alonso      70         +15.651         12
# 5        10       Pierre Gasly         70         +1:03.614       11
# 6        22       Yuki Tsunoda         70         +1:15.803       8
# 7        6        Nicholas Latifi      70         +1:17.910       6
# 8        63       George Russell       70         +1:19.094       4
# 9        33       Max Verstappen       70         +1:20.244       2
# 10       7        Kimi Räikkönen       69         +1 Lap          1
# 11       3        Daniel Ricciardo     69         +1 Lap          0
# 12       47       Mick Schumacher      69         +1 Lap          0
# 13       99       Antonio Giovinazzi   69         +1 Lap          0
# 14       9        Nikita Mazepin       3          DNF             0
# 15       4        Lando Norris         2          DNF             0
# 16       77       Valtteri Bottas      0          DNF             0
# 17       11       Sergio Pérez         0          DNF             0
# 18       16       Charles Leclerc      0          DNF             0
# 19       18       Lance Stroll         0          DNF             0
# 20       5        Sebastian Vettel     70         DQ              0

# %%
url = "http://ergast.com/api/f1/current/driverStandings.json"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

db=eval(response.text)

# %%
db['MRData']['StandingsTable']['StandingsLists'][0]
# Out:
# {'season': '2021',
#  'round': '11',
#  'DriverStandings': [{'position': '1',
#    'positionText': '1',
#    'points': '195',
#    'wins': '4',
#    'Driver': {'driverId': 'hamilton',
#     'permanentNumber': '44',
#     'code': 'HAM',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lewis_Hamilton',
#     'givenName': 'Lewis',
#     'familyName': 'Hamilton',
#     'dateOfBirth': '1985-01-07',
#     'nationality': 'British'},
#    'Constructors': [{'constructorId': 'mercedes',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mercedes-Benz_in_Formula_One',
#      'name': 'Mercedes',
#      'nationality': 'German'}]},
#   {'position': '2',
#    'positionText': '2',
#    'points': '187',
#    'wins': '5',
#    'Driver': {'driverId': 'max_verstappen',
#     'permanentNumber': '33',
#     'code': 'VER',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Max_Verstappen',
#     'givenName': 'Max',
#     'familyName': 'Verstappen',
#     'dateOfBirth': '1997-09-30',
#     'nationality': 'Dutch'},
#    'Constructors': [{'constructorId': 'red_bull',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Red_Bull_Racing',
#      'name': 'Red Bull',
#      'nationality': 'Austrian'}]},
#   {'position': '3',
#    'positionText': '3',
#    'points': '113',
#    'wins': '0',
#    'Driver': {'driverId': 'norris',
#     'permanentNumber': '4',
#     'code': 'NOR',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lando_Norris',
#     'givenName': 'Lando',
#     'familyName': 'Norris',
#     'dateOfBirth': '1999-11-13',
#     'nationality': 'British'},
#    'Constructors': [{'constructorId': 'mclaren',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/McLaren',
#      'name': 'McLaren',
#      'nationality': 'British'}]},
#   {'position': '4',
#    'positionText': '4',
#    'points': '108',
#    'wins': '0',
#    'Driver': {'driverId': 'bottas',
#     'permanentNumber': '77',
#     'code': 'BOT',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Valtteri_Bottas',
#     'givenName': 'Valtteri',
#     'familyName': 'Bottas',
#     'dateOfBirth': '1989-08-28',
#     'nationality': 'Finnish'},
#    'Constructors': [{'constructorId': 'mercedes',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mercedes-Benz_in_Formula_One',
#      'name': 'Mercedes',
#      'nationality': 'German'}]},
#   {'position': '5',
#    'positionText': '5',
#    'points': '104',
#    'wins': '1',
#    'Driver': {'driverId': 'perez',
#     'permanentNumber': '11',
#     'code': 'PER',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Sergio_P%C3%A9rez',
#     'givenName': 'Sergio',
#     'familyName': 'Pérez',
#     'dateOfBirth': '1990-01-26',
#     'nationality': 'Mexican'},
#    'Constructors': [{'constructorId': 'red_bull',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Red_Bull_Racing',
#      'name': 'Red Bull',
#      'nationality': 'Austrian'}]},
#   {'position': '6',
#    'positionText': '6',
#    'points': '83',
#    'wins': '0',
#    'Driver': {'driverId': 'sainz',
#     'permanentNumber': '55',
#     'code': 'SAI',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Carlos_Sainz_Jr.',
#     'givenName': 'Carlos',
#     'familyName': 'Sainz',
#     'dateOfBirth': '1994-09-01',
#     'nationality': 'Spanish'},
#    'Constructors': [{'constructorId': 'ferrari',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_Ferrari',
#      'name': 'Ferrari',
#      'nationality': 'Italian'}]},
#   {'position': '7',
#    'positionText': '7',
#    'points': '80',
#    'wins': '0',
#    'Driver': {'driverId': 'leclerc',
#     'permanentNumber': '16',
#     'code': 'LEC',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Charles_Leclerc',
#     'givenName': 'Charles',
#     'familyName': 'Leclerc',
#     'dateOfBirth': '1997-10-16',
#     'nationality': 'Monegasque'},
#    'Constructors': [{'constructorId': 'ferrari',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_Ferrari',
#      'name': 'Ferrari',
#      'nationality': 'Italian'}]},
#   {'position': '8',
#    'positionText': '8',
#    'points': '50',
#    'wins': '0',
#    'Driver': {'driverId': 'gasly',
#     'permanentNumber': '10',
#     'code': 'GAS',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Pierre_Gasly',
#     'givenName': 'Pierre',
#     'familyName': 'Gasly',
#     'dateOfBirth': '1996-02-07',
#     'nationality': 'French'},
#    'Constructors': [{'constructorId': 'alphatauri',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_AlphaTauri',
#      'name': 'AlphaTauri',
#      'nationality': 'Italian'}]},
#   {'position': '9',
#    'positionText': '9',
#    'points': '50',
#    'wins': '0',
#    'Driver': {'driverId': 'ricciardo',
#     'permanentNumber': '3',
#     'code': 'RIC',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Daniel_Ricciardo',
#     'givenName': 'Daniel',
#     'familyName': 'Ricciardo',
#     'dateOfBirth': '1989-07-01',
#     'nationality': 'Australian'},
#    'Constructors': [{'constructorId': 'mclaren',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/McLaren',
#      'name': 'McLaren',
#      'nationality': 'British'}]},
#   {'position': '10',
#    'positionText': '10',
#    'points': '39',
#    'wins': '1',
#    'Driver': {'driverId': 'ocon',
#     'permanentNumber': '31',
#     'code': 'OCO',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Esteban_Ocon',
#     'givenName': 'Esteban',
#     'familyName': 'Ocon',
#     'dateOfBirth': '1996-09-17',
#     'nationality': 'French'},
#    'Constructors': [{'constructorId': 'alpine',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alpine_F1_Team',
#      'name': 'Alpine F1 Team',
#      'nationality': 'French'}]},
#   {'position': '11',
#    'positionText': '11',
#    'points': '38',
#    'wins': '0',
#    'Driver': {'driverId': 'alonso',
#     'permanentNumber': '14',
#     'code': 'ALO',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Fernando_Alonso',
#     'givenName': 'Fernando',
#     'familyName': 'Alonso',
#     'dateOfBirth': '1981-07-29',
#     'nationality': 'Spanish'},
#    'Constructors': [{'constructorId': 'alpine',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alpine_F1_Team',
#      'name': 'Alpine F1 Team',
#      'nationality': 'French'}]},
#   {'position': '12',
#    'positionText': '12',
#    'points': '30',
#    'wins': '0',
#    'Driver': {'driverId': 'vettel',
#     'permanentNumber': '5',
#     'code': 'VET',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Sebastian_Vettel',
#     'givenName': 'Sebastian',
#     'familyName': 'Vettel',
#     'dateOfBirth': '1987-07-03',
#     'nationality': 'German'},
#    'Constructors': [{'constructorId': 'aston_martin',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Aston_Martin_in_Formula_One',
#      'name': 'Aston Martin',
#      'nationality': 'British'}]},
#   {'position': '13',
#    'positionText': '13',
#    'points': '18',
#    'wins': '0',
#    'Driver': {'driverId': 'tsunoda',
#     'permanentNumber': '22',
#     'code': 'TSU',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Yuki_Tsunoda',
#     'givenName': 'Yuki',
#     'familyName': 'Tsunoda',
#     'dateOfBirth': '2000-05-11',
#     'nationality': 'Japanese'},
#    'Constructors': [{'constructorId': 'alphatauri',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Scuderia_AlphaTauri',
#      'name': 'AlphaTauri',
#      'nationality': 'Italian'}]},
#   {'position': '14',
#    'positionText': '14',
#    'points': '18',
#    'wins': '0',
#    'Driver': {'driverId': 'stroll',
#     'permanentNumber': '18',
#     'code': 'STR',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lance_Stroll',
#     'givenName': 'Lance',
#     'familyName': 'Stroll',
#     'dateOfBirth': '1998-10-29',
#     'nationality': 'Canadian'},
#    'Constructors': [{'constructorId': 'aston_martin',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Aston_Martin_in_Formula_One',
#      'name': 'Aston Martin',
#      'nationality': 'British'}]},
#   {'position': '15',
#    'positionText': '15',
#    'points': '6',
#    'wins': '0',
#    'Driver': {'driverId': 'latifi',
#     'permanentNumber': '6',
#     'code': 'LAT',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nicholas_Latifi',
#     'givenName': 'Nicholas',
#     'familyName': 'Latifi',
#     'dateOfBirth': '1995-06-29',
#     'nationality': 'Canadian'},
#    'Constructors': [{'constructorId': 'williams',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Williams_Grand_Prix_Engineering',
#      'name': 'Williams',
#      'nationality': 'British'}]},
#   {'position': '16',
#    'positionText': '16',
#    'points': '4',
#    'wins': '0',
#    'Driver': {'driverId': 'russell',
#     'permanentNumber': '63',
#     'code': 'RUS',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/George_Russell_%28racing_driver%29',
#     'givenName': 'George',
#     'familyName': 'Russell',
#     'dateOfBirth': '1998-02-15',
#     'nationality': 'British'},
#    'Constructors': [{'constructorId': 'williams',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Williams_Grand_Prix_Engineering',
#      'name': 'Williams',
#      'nationality': 'British'}]},
#   {'position': '17',
#    'positionText': '17',
#    'points': '2',
#    'wins': '0',
#    'Driver': {'driverId': 'raikkonen',
#     'permanentNumber': '7',
#     'code': 'RAI',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Kimi_R%C3%A4ikk%C3%B6nen',
#     'givenName': 'Kimi',
#     'familyName': 'Räikkönen',
#     'dateOfBirth': '1979-10-17',
#     'nationality': 'Finnish'},
#    'Constructors': [{'constructorId': 'alfa',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alfa_Romeo_in_Formula_One',
#      'name': 'Alfa Romeo',
#      'nationality': 'Swiss'}]},
#   {'position': '18',
#    'positionText': '18',
#    'points': '1',
#    'wins': '0',
#    'Driver': {'driverId': 'giovinazzi',
#     'permanentNumber': '99',
#     'code': 'GIO',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Antonio_Giovinazzi',
#     'givenName': 'Antonio',
#     'familyName': 'Giovinazzi',
#     'dateOfBirth': '1993-12-14',
#     'nationality': 'Italian'},
#    'Constructors': [{'constructorId': 'alfa',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Alfa_Romeo_in_Formula_One',
#      'name': 'Alfa Romeo',
#      'nationality': 'Swiss'}]},
#   {'position': '19',
#    'positionText': '19',
#    'points': '0',
#    'wins': '0',
#    'Driver': {'driverId': 'mick_schumacher',
#     'permanentNumber': '47',
#     'code': 'MSC',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mick_Schumacher',
#     'givenName': 'Mick',
#     'familyName': 'Schumacher',
#     'dateOfBirth': '1999-03-22',
#     'nationality': 'German'},
#    'Constructors': [{'constructorId': 'haas',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Haas_F1_Team',
#      'name': 'Haas F1 Team',
#      'nationality': 'American'}]},
#   {'position': '20',
#    'positionText': '20',
#    'points': '0',
#    'wins': '0',
#    'Driver': {'driverId': 'mazepin',
#     'permanentNumber': '9',
#     'code': 'MAZ',
#     'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Nikita_Mazepin',
#     'givenName': 'Nikita',
#     'familyName': 'Mazepin',
#     'dateOfBirth': '1999-03-02',
#     'nationality': 'Russian'},
#    'Constructors': [{'constructorId': 'haas',
#      'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Haas_F1_Team',
#      'name': 'Haas F1 Team',
#      'nationality': 'American'}]}]}

# %%
url = "http://ergast.com/api/f1/{}/driverStandings.json".format(2021)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
dz=eval(response.text)

# %%
dz['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'][0]
# Out:
# {'position': '1',
#  'positionText': '1',
#  'points': '195',
#  'wins': '4',
#  'Driver': {'driverId': 'hamilton',
#   'permanentNumber': '44',
#   'code': 'HAM',
#   'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Lewis_Hamilton',
#   'givenName': 'Lewis',
#   'familyName': 'Hamilton',
#   'dateOfBirth': '1985-01-07',
#   'nationality': 'British'},
#  'Constructors': [{'constructorId': 'mercedes',
#    'url': 'http:\\/\\/en.wikipedia.org\\/wiki\\/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'}]}

# %%
url = "http://ergast.com/api/f1/{}/constructorStandings.json".format(2021)

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
dz=eval(response.text)

# %%
dz['MRData']['StandingsTable']['StandingsLists'][0]['ConstructorStandings'][0]
# Out:
# {'position': '1',
#  'positionText': '1',
#  'points': '303',
#  'wins': '4',
#  'Constructor': {'constructorId': 'mercedes',
#   'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#   'name': 'Mercedes',
#   'nationality': 'German'}}

# %%
url = "http://ergast.com/api/f1/driverStandings/1?limit=71.json"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
db=json.dumps(xmltodict.parse(response.text))
dz=eval(db)

# %%
dz['MRData']['StandingsTable']['StandingsList'][60]['DriverStanding']['Constructor']['Name']
# Out:
# 'Red Bull'

# %%
from datetime import date

# %%
2010-2020

# %%
date.today().year-1950
# Out:
# 71

# %%
y1=2010-1950

# %%
y2=2020-1950

# %%
a=dz['MRData']['StandingsTable']['StandingsList']

# %%
for i in range(y1,y2):
        print(a[i]['DriverStanding']['Driver']['FamilyName'])
# Out:
# Vettel
# Vettel
# Vettel
# Vettel
# Hamilton
# Hamilton
# Rosberg
# Hamilton
# Hamilton
# Hamilton

# %%
url = "http://ergast.com/api/f1/constructorStandings/1?limit=71.json"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
db=json.dumps(xmltodict.parse(response.text))
dz=eval(db)

# %%
dz['MRData']['StandingsTable']['StandingsList'][52]
# Out:
# {'@season': '2010',
#  '@round': '19',
#  'ConstructorStanding': {'@position': '1',
#   '@positionText': '1',
#   '@points': '498',
#   '@wins': '9',
#   'Constructor': {'@constructorId': 'red_bull',
#    '@url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'Name': 'Red Bull',
#    'Nationality': 'Austrian'}}}

# %%
2010-1958
# Out:
# 52

# %%
url = "http://ergast.com/api/f1/drivers/{}.json".format("alonso")

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"MRData":{"xmlns":"http:\/\/ergast.com\/mrd\/1.4","series":"f1","url":"http://ergast.com/api/f1/drivers/alonso.json","limit":"30","offset":"0","total":"1","DriverTable":{"driverId":"alonso","Drivers":[{"driverId":"alonso","permanentNumber":"14","code":"ALO","url":"http:\/\/en.wikipedia.org\/wiki\/Fernando_Alonso","givenName":"Fernando","familyName":"Alonso","dateOfBirth":"1981-07-29","nationality":"Spanish"}]}}}

# %%
import vlc

# %%
url = "https://www.youtube.com/watch?v=uXwu169W-CQ"

# %%
import ffmpeg_streaming

# %%
video = ffmpeg_streaming.input(url)

# %%
from PIL import Image
from io import BytesIO
import io

# %%
response = requests.get(url)
#img = Image.open(BytesIO(response.content))

# %%
byteImgIO = io.BytesIO()
byteImg = Image.open(response.content)
byteImg.save(byteImgIO, "PNG")
byteImgIO.seek(0)
byteImg = byteImgIO.read()


# Non test code
dataBytesIO = io.BytesIO(byteImg)
Image.open(dataBytesIO)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-169-a6563ed67764> in <module>
#       1 byteImgIO = io.BytesIO()
# ----> 2 byteImg = Image.open(response.content)
#       3 byteImg.save(byteImgIO, "PNG")
#       4 byteImgIO.seek(0)
#       5 byteImg = byteImgIO.read()
#
# /usr/lib/python3.9/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
#    2913         exclusive_fp = True
#    2914
#
# OSError: [Errno 36] File name too long: b'<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" typography typography-spacing><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><script nonce="RS0G1MDKzMQxVF44PUTQTQ">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20210806.00.00\');</script><script nonce="RS0G1MDKzMQxVF44PUTQTQ">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;img.onload=img.onerror=function(){delete window.emergencyTimeoutImg};\nvar combinedLineAndColumn=err.lineNumber;if(!isNaN(err["columnNumber"]))combinedLineAndColumn+=":"+err["columnNumber"];var stack=err.stack||"";var values={"msg":message,"type":err.name,"client.params":"unhandled window error","file":err.fileName,"line":combinedLineAndColumn,"stack":stack.substr(0,500)};var thirdPartyScript=!err.fileName||err.fileName==="<anonymous>"||stack.indexOf("extension://")>=0;var replaced=stack.replace(/https:\\/\\/www.youtube.com\\//g,"");if(replaced.match(/https?:\\/\\/[^/]+\\//))thirdPartyScript=\ntrue;else if(stack.indexOf("trapProp")>=0&&stack.indexOf("trapChain")>=0)thirdPartyScript=true;else if(message.indexOf("redefine non-configurable")>=0&&message.indexOf("userAgent")>=0)thirdPartyScript=true;var baseUrl=window["ytcfg"].get("EMERGENCY_BASE_URL","https://www.youtube.com/error_204?t=jserror&level=ERROR");var unsupported=message.indexOf("window.customElements is undefined")>=0;if(thirdPartyScript||unsupported)baseUrl=baseUrl.replace("level=ERROR","level=WARNING");var parts=[baseUrl];for(var key in values){var value=\nvalues[key];if(value)parts.push(key+"="+encodeURIComponent(value))}img.src=parts.join("&")};\n(function(){function _getExtendedNativePrototype(tag){var p=this._nativePrototypes[tag];if(!p){p=Object.create(this.getNativePrototype(tag));var p$=Object.getOwnPropertyNames(window["Polymer"].Base);for(var i=0,n=undefined;i<p$.length&&(n=p$[i]);i++)if(!window["Polymer"].BaseDescriptors[n])try{p[n]=window["Polymer"].Base[n]}catch(e){throw new Error("Error while copying property: "+n+". Tag is "+tag);}try{Object.defineProperties(p,window["Polymer"].BaseDescriptors)}catch(e$0){throw new Error("Polymer define property failed for "+\nObject.keys(p));}this._nativePrototypes[tag]=p}return p}function handlePolymerError(msg){window.onerror(msg,window.location.href,0,0,new Error(Array.prototype.join.call(arguments,",")))}var origPolymer=window["Polymer"];var newPolymer=function(config){if(!origPolymer._ytIntercepted&&window["Polymer"].Base){origPolymer._ytIntercepted=true;window["Polymer"].Base._getExtendedNativePrototype=_getExtendedNativePrototype;window["Polymer"].Base._error=handlePolymerError;window["Polymer"].Base._warn=handlePolymerError}return origPolymer.apply(this,\narguments)};var origDescriptor=Object.getOwnPropertyDescriptor(window,"Polymer");Object.defineProperty(window,"Polymer",{set:function(p){if(origDescriptor&&origDescriptor.set&&origDescriptor.get){origDescriptor.set(p);origPolymer=origDescriptor.get()}else origPolymer=p;if(typeof origPolymer==="function")Object.defineProperty(window,"Polymer",{value:origPolymer,configurable ...
